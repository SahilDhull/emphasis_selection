# %%
from collections import Counter
import codecs
import itertools
from functools import reduce
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init
from torch.nn.utils.rnn import pack_padded_sequence
import torch.utils.data as data_utils
import time
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
#from torchsummary import summary

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def read_words_tags(file, word_ind, tag_ind, prob_ind, caseless=True):
    
    with codecs.open(file, 'r', 'utf-8') as f:
        lines = f.readlines()
    #print(lines)
    words = []
    tags = []
    probs = []
    temp_w = []
    temp_t = []
    temp_p = []
    
    for line in lines:
        if not (line.isspace()):
            feats = line.strip().split()
            temp_w.append(feats[word_ind].lower() if caseless else feats[word_ind])
            temp_t.append(feats[tag_ind])
            temp_p.append((float)(feats[prob_ind]))
        elif len(temp_w) > 0:
            assert len(temp_w) == len(temp_t)
            words.append(temp_w)
            tags.append(temp_t)
            probs.append(temp_p)
            temp_w = []
            temp_t = []
            temp_p = []
            
    if len(temp_w) > 0:
        assert len(temp_w) == len(temp_t)
        words.append(temp_w)
        tags.append(temp_t)
        probs.append(temp_p)
            
    assert len(words) == len(tags) == len(probs)
    #print(probs)
    
    return words, tags, probs

# %%
train_file = "datasets/train.txt"
dev_file = "datasets/dev.txt"

word_index = 1
tag_index = 5
prob_index = 4

caseless=True

t_words , t_tags , t_probs = read_words_tags(train_file,word_index,tag_index,prob_index,caseless)
d_words , d_tags , d_probs = read_words_tags(dev_file,word_index,tag_index,prob_index,caseless)

# %%
def create_maps(words, tags, min_word_freq=5, min_char_freq=1):
    
    word_freq = Counter()
    char_freq = Counter()
    tag_map = set()
    for w, t in zip(words, tags):
        word_freq.update(w)
        char_freq.update(list(reduce(lambda x, y: list(x) + [' '] + list(y), w)))
        tag_map.update(t)
    #print(word_freq)
    
    word_map = {k: v + 1 for v, k in enumerate([w for w in word_freq.keys() if word_freq[w] > min_word_freq])}
    char_map = {k: v + 1 for v, k in enumerate([c for c in char_freq.keys() if char_freq[c] > min_char_freq])}
    tag_map = {k: v + 1 for v, k in enumerate(tag_map)}

    word_map['<pad>'] = 0
    word_map['<end>'] = len(word_map)
    word_map['<unk>'] = len(word_map)
    char_map['<pad>'] = 0
    char_map['<end>'] = len(char_map)
    char_map['<unk>'] = len(char_map)
    tag_map['<pad>'] = 0
    tag_map['<start>'] = len(tag_map)
    tag_map['<end>'] = len(tag_map)
    #print(word_map)
    
    return word_map, char_map, tag_map

# %%
min_word_freq=1
min_char_freq=1

word_map, char_map, tag_map = create_maps(t_words+d_words,t_tags+d_tags,min_word_freq, min_char_freq)

# %%
print(len(word_map))
# Out:
# 2009

# %%
def create_input_tensors(words, tags, probs, word_map, char_map, tag_map):
   
    # Encode sentences into word maps with <end> at the end
    # [['dunston', 'checks', 'in', '<end>']] -> [[4670, 4670, 185, 4669]]
    wmaps = list(map(lambda s: list(map(lambda w: word_map.get(w, word_map['<unk>']), s)) + [word_map['<end>']], words))

    # Forward and backward character streams
    # [['d', 'u', 'n', 's', 't', 'o', 'n', ' ', 'c', 'h', 'e', 'c', 'k', 's', ' ', 'i', 'n', ' ']]
    chars_f = list(map(lambda s: list(reduce(lambda x, y: list(x) + [' '] + list(y), s)) + [' '], words))
    # [['n', 'i', ' ', 's', 'k', 'c', 'e', 'h', 'c', ' ', 'n', 'o', 't', 's', 'n', 'u', 'd', ' ']]
    chars_b = list(
        map(lambda s: list(reversed([' '] + list(reduce(lambda x, y: list(x) + [' '] + list(y), s)))), words))

    # Encode streams into forward and backward character maps with <end> at the end
    # [[29, 2, 12, 8, 7, 14, 12, 3, 6, 18, 1, 6, 21, 8, 3, 17, 12, 3, 60]]
    cmaps_f = list(
        map(lambda s: list(map(lambda c: char_map.get(c, char_map['<unk>']), s)) + [char_map['<end>']], chars_f))
    # [[12, 17, 3, 8, 21, 6, 1, 18, 6, 3, 12, 14, 7, 8, 12, 2, 29, 3, 60]]
    cmaps_b = list(
        map(lambda s: list(map(lambda c: char_map.get(c, char_map['<unk>']), s)) + [char_map['<end>']], chars_b))

    # Positions of spaces and <end> character
    # Words are predicted or encoded at these places in the language and tagging models respectively
    # [[7, 14, 17, 18]] are points after '...dunston', '...checks', '...in', '...<end>' respectively
    cmarkers_f = list(map(lambda s: [ind for ind in range(len(s)) if s[ind] == char_map[' ']] + [len(s) - 1], cmaps_f))
    # Reverse the markers for the backward stream before adding <end>, so the words of the f and b markers coincide
    # i.e., [[17, 9, 2, 18]] are points after '...notsnud', '...skcehc', '...ni', '...<end>' respectively
    cmarkers_b = list(
        map(lambda s: list(reversed([ind for ind in range(len(s)) if s[ind] == char_map[' ']])) + [len(s) - 1],
            cmaps_b))

    # Encode tags into tag maps with <end> at the end
    tmaps = list(map(lambda s: list(map(lambda t: tag_map[t], s)) + [tag_map['<end>']], tags))
    
    # Since we're using CRF scores of size (prev_tags, cur_tags), find indices of target sequence in the unrolled scores
    # This will be row_index (i.e. prev_tag) * n_columns (i.e. tagset_size) + column_index (i.e. cur_tag)
    #tmaps = list(map(lambda s: [tag_map['<start>'] * len(tag_map) + s[0]] + [s[i - 1] * len(tag_map) + s[i] for i in range(1, len(s))], tmaps))
    # Note - the actual tag indices can be recovered with tmaps % len(tag_map)

    # Pad, because need fixed length to be passed around by DataLoaders and other layers
    word_pad_len = max(list(map(lambda s: len(s), wmaps)))
    char_pad_len = max(list(map(lambda s: len(s), cmaps_f)))

    # Sanity check
    assert word_pad_len == max(list(map(lambda s: len(s), tmaps)))

    padded_wmaps = []
    padded_cmaps_f = []
    padded_cmaps_b = []
    padded_cmarkers_f = []
    padded_cmarkers_b = []
    padded_tmaps = []
    wmap_lengths = []
    cmap_lengths = []
    padded_probs = []

    for w, cf, cb, cmf, cmb, t,p in zip(wmaps, cmaps_f, cmaps_b, cmarkers_f, cmarkers_b, tmaps,probs):
        # Sanity  checks
        assert len(w) == len(cmf) == len(cmb) == len(t)
        assert len(cmaps_f) == len(cmaps_b)

        # Pad
        # A note -  it doesn't really matter what we pad with, as long as it's a valid index
        # i.e., we'll extract output at those pad points (to extract equal lengths), but never use them

        padded_wmaps.append(w + [word_map['<pad>']] * (word_pad_len - len(w)))
        padded_cmaps_f.append(cf + [char_map['<pad>']] * (char_pad_len - len(cf)))
        padded_cmaps_b.append(cb + [char_map['<pad>']] * (char_pad_len - len(cb)))

        # 0 is always a valid index to pad markers with (-1 is too but torch.gather has some issues with it)
        padded_cmarkers_f.append(cmf + [0] * (word_pad_len - len(w)))
        padded_cmarkers_b.append(cmb + [0] * (word_pad_len - len(w)))

        padded_tmaps.append(t + [tag_map['<pad>']] * (word_pad_len - len(t)))
        padded_probs.append(p + [0] * (word_pad_len - len(p)))

        wmap_lengths.append(len(w))
        cmap_lengths.append(len(cf))

        # Sanity check
        assert len(padded_wmaps[-1]) == len(padded_tmaps[-1]) == len(padded_cmarkers_f[-1]) == len(
            padded_cmarkers_b[-1]) == word_pad_len == len(padded_probs[-1])
        assert len(padded_cmaps_f[-1]) == len(padded_cmaps_b[-1]) == char_pad_len

    padded_wmaps = torch.LongTensor(padded_wmaps)
    padded_cmaps_f = torch.LongTensor(padded_cmaps_f)
    padded_cmaps_b = torch.LongTensor(padded_cmaps_b)
    padded_cmarkers_f = torch.LongTensor(padded_cmarkers_f)
    padded_cmarkers_b = torch.LongTensor(padded_cmarkers_b)
    padded_tmaps = torch.LongTensor(padded_tmaps)
    wmap_lengths = torch.LongTensor(wmap_lengths)
    cmap_lengths = torch.LongTensor(cmap_lengths)
    padded_probs = torch.FloatTensor(padded_probs)
    
    return padded_wmaps, padded_cmaps_f, padded_cmaps_b, padded_cmarkers_f, padded_cmarkers_b, padded_tmaps, wmap_lengths, cmap_lengths , padded_probs

# %%
batch_size = 10
workers = 1

padded_wmaps, padded_cmaps_f, padded_cmaps_b, padded_cmarkers_f, padded_cmarkers_b, padded_tmaps, wmap_lengths, cmap_lengths , padded_probs = create_input_tensors(t_words, t_tags,t_probs, word_map, char_map, tag_map)
#print(wmap_lengths)
t_inputs = data_utils.TensorDataset(padded_wmaps, padded_cmaps_f, padded_cmaps_b, padded_cmarkers_f, padded_cmarkers_b, padded_tmaps, wmap_lengths, cmap_lengths , padded_probs)
train_loader = torch.utils.data.DataLoader(t_inputs, batch_size = batch_size, shuffle=True, num_workers=workers, pin_memory=False)

padded_wmaps, padded_cmaps_f, padded_cmaps_b, padded_cmarkers_f, padded_cmarkers_b, padded_tmaps, wmap_lengths, cmap_lengths , padded_probs = create_input_tensors(d_words, d_tags,d_probs, word_map, char_map, tag_map)
d_inputs = data_utils.TensorDataset(padded_wmaps, padded_cmaps_f, padded_cmaps_b, padded_cmarkers_f, padded_cmarkers_b, padded_tmaps, wmap_lengths, cmap_lengths , padded_probs)
val_loader = torch.utils.data.DataLoader(d_inputs, batch_size = batch_size, shuffle=True, num_workers=workers, pin_memory=False)

# %%
def init_embedding(input_embedding):
    """
    Initialize embedding tensor with values from the uniform distribution.
    :param input_embedding: embedding tensor
    :return:
    """
    bias = np.sqrt(3.0 / input_embedding.size(1))
    nn.init.uniform_(input_embedding, -bias, bias)

def load_embeddings(emb_file, word_map, expand_vocab=True):
    """
    Load pre-trained embeddings for words in the word map.
    :param emb_file: file with pre-trained embeddings (in the GloVe format)
    :param word_map: word map
    :param expand_vocab: expand vocabulary of word map to vocabulary of pre-trained embeddings?
    :return: embeddings for words in word map, (possibly expanded) word map,
            number of words in word map that are in-corpus (subject to word frequency threshold)
    """
    with open(emb_file, 'r') as f:
        emb_len = len(f.readline().split(' ')) - 1

    print("Embedding length is %d." % emb_len)

    # Create tensor to hold embeddings for words that are in-corpus
    ic_embs = torch.FloatTensor(len(word_map), emb_len)
    init_embedding(ic_embs)

    if expand_vocab:
        print("You have elected to include embeddings that are out-of-corpus.")
        ooc_words = []
        ooc_embs = []
    else:
        print("You have elected NOT to include embeddings that are out-of-corpus.")

    # Read embedding file
    print("\nLoading embeddings...")
    for line in open(emb_file, 'r',encoding="utf8"):
        line = line.split(' ')
        emb_word = line[0]
        embedding = list(map(lambda t: float(t), filter(lambda n: n and not n.isspace(), line[1:])))

        if not expand_vocab and emb_word not in word_map:
            continue

        # If word is in train_vocab, store at the correct index (as in the word_map)
        if emb_word in word_map:
            ic_embs[word_map[emb_word]] = torch.FloatTensor(embedding)

        # If word is in dev or test vocab, store it and its embedding into lists
        elif expand_vocab:
            ooc_words.append(emb_word)
            ooc_embs.append(embedding)

    lm_vocab_size = len(word_map)  # keep track of lang. model's output vocab size (no out-of-corpus words)

    if expand_vocab:
        print("'word_map' is being updated accordingly.")
        for word in ooc_words:
            word_map[word] = len(word_map)
        ooc_embs = torch.FloatTensor(np.asarray(ooc_embs))
        embeddings = torch.cat([ic_embs, ooc_embs], 0)

    else:
        embeddings = ic_embs

    # Sanity check
    assert embeddings.size(0) == len(word_map)

    print("\nDone.\n Embedding vocabulary: %d\n Language Model vocabulary: %d.\n" % (len(word_map), lm_vocab_size))

    return embeddings, word_map, lm_vocab_size

# %%
emb_file = "glove.6B/glove.6B.100d.txt"
expand_vocab = False
word_emb_dim = 100

embeddings, word_map, lm_vocab_size = load_embeddings(emb_file, word_map,expand_vocab)
# Out:
# Embedding length is 100.
# You have elected NOT to include embeddings that are out-of-corpus.
#
# Loading embeddings...
#
# Done.
#  Embedding vocabulary: 2009
#  Language Model vocabulary: 2009.

# %%
print(embeddings.size())
print(lm_vocab_size)
# Out:
# torch.Size([2009, 100])
# 2009

# %%
class Attention(nn.Module):
    """Attention mechanism written by Gustavo Aguilar https://github.com/gaguilar"""
    def __init__(self,  hidden_size):
        super(Attention, self).__init__()
        self.da = hidden_size
        self.dh = hidden_size

        self.W = nn.Linear(self.dh, self.da)        # (feat_dim, attn_dim)
        self.v = nn.Linear(self.da, 1)              # (attn_dim, 1)

    def forward(self, inputs, mask):
        # Raw scores
        u = self.v(torch.tanh(self.W(inputs)))      # (batch, seq, hidden) -> (batch, seq, attn) -> (batch, seq, 1)

        # Masked softmax
        u = u.exp().to(device)                                 # exp to calculate softmax
        u = mask.unsqueeze(2).float().to(device) * u           # (batch, seq, 1) * (batch, seq, 1) to zerout out-of-mask numbers
        sums = torch.sum(u, dim=1, keepdim=True)    # now we are sure only in-mask values are in sum
        a = u / sums                                # the probability distribution only goes to in-mask values now

        # Weighted vectors
        z = inputs * a

        return  z,  a.view(inputs.size(0), inputs.size(1))


class LM_LSTM_CRF(nn.Module):

    def __init__(self, target_size, hidden_size, vocab_size, word_emb_dim, word_rnn_dim, dropout):
        
        super(LM_LSTM_CRF, self).__init__()

        self.target_size = target_size  # this is the size of the output vocab of the tagging model
        self.hidden_size = hidden_size

        self.wordset_size = lm_vocab_size  # this is the size of the input vocab (embedding layer) of the tagging model
        self.word_emb_dim = word_emb_dim
        self.word_rnn_dim = word_rnn_dim
        self.word_rnn_layers = 2

        self.dropout = nn.Dropout(p=dropout)

        self.word_embeds = nn.Embedding(self.wordset_size, self.word_emb_dim)  # word embedding layer
        self.word_blstm = nn.LSTM(self.word_emb_dim, self.word_rnn_dim, num_layers=self.word_rnn_layers, bidirectional=True, dropout=dropout)  # word BLSTM
        
        self.attention = Attention(self.word_rnn_dim*2)
        
        self.fc1 = nn.Linear(self.word_rnn_dim*2, self.hidden_size)  
        self.fc2 = nn.Linear(self.hidden_size, self.target_size)
        
    def init_word_embeddings(self, embeddings):
        """
        Initialize embeddings with pre-trained embeddings.
        :param embeddings: pre-trained embeddings
        """
        self.word_embeds.weight = nn.Parameter(embeddings)

    def fine_tune_word_embeddings(self, fine_tune=False):
        """
        Fine-tune embedding layer? (Not fine-tuning only makes sense if using pre-trained embeddings).
        :param fine_tune: Fine-tune?
        """
        for p in self.word_embeds.parameters():
            p.requires_grad = fine_tune

    def forward(self, wmaps, probs, wmap_lengths):
        
        self.batch_size = wmaps.size(0)
        self.word_pad_len = wmaps.size(1)

        # Sort by decreasing true word sequence length
        wmap_lengths, word_sort_ind = wmap_lengths.sort(dim=0, descending=True)
        wmaps = wmaps[word_sort_ind]
        probs = probs[word_sort_ind]
        
        # Embedding look-up for words
        w = self.word_embeds(wmaps)  # (batch_size, word_pad_len, word_emb_dim)
        w = self.dropout(w)

        # Pack padded sequence
        w = pack_padded_sequence(w, list(wmap_lengths), batch_first=True)  # packed sequence of word_emb_dim + 2 * char_rnn_dim, with real sequence lengths
        
        # LSTM
        w, _ = self.word_blstm(w)  # packed sequence of word_rnn_dim, with real sequence lengths

        # Unpack packed sequence
        w, _ = pad_packed_sequence(w, batch_first=True)  # (batch_size, max_word_len_in_batch, word_rnn_dim)
        w = self.dropout(w)
        
        mask = []
        for i in range(len(wmap_lengths)):
            mask_row = (np.concatenate([np.ones(wmap_lengths[i]),np.zeros(len(wmaps[i])-wmap_lengths[i])])).tolist()
            mask.append(mask_row)
        #Attention
        att_output, att_weights = self.attention(w, torch.from_numpy(np.asarray(mask)).float())
        
        # fc layers
        w = torch.relu(self.fc1(att_output)) 
        w = self.dropout(w)
        
        # final score
        scores = torch.sigmoid(self.fc2(w)) 
                
        return scores, wmaps, probs, wmap_lengths, word_sort_ind

# %%
word_rnn_dim = 50 
dropout = 0.3
fine_tune_word_embeddings = False

# if torch.cuda.is_available():
    
model = LM_LSTM_CRF(1, 20, lm_vocab_size, word_emb_dim, word_rnn_dim, dropout).to(device)
print(model)
        
model.init_word_embeddings(embeddings.to(device))  # initialize embedding layer with pre-trained embeddings
model.fine_tune_word_embeddings(fine_tune_word_embeddings)  # fine-tune
optimizer = optim.Adam(params=filter(lambda p: p.requires_grad, model.parameters()), lr=0.0001)

loss_fn = nn.BCELoss().to(device)
# Out:
# LM_LSTM_CRF(
#   (dropout): Dropout(p=0.3)
#   (word_embeds): Embedding(2009, 100)
#   (word_blstm): LSTM(100, 50, num_layers=2, dropout=0.3, bidirectional=True)
#   (attention): Attention(
#     (W): Linear(in_features=100, out_features=100, bias=True)
#     (v): Linear(in_features=100, out_features=1, bias=True)
#   )
#   (fc1): Linear(in_features=100, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
class AverageMeter(object):
    """
    Keeps track of most recent, average, sum, and count of a metric.
    """

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
def train(train_loader, model, loss_fn, optimizer, epoch, print_freq = 25):
    
    model.train()  # training mode enables dropout

    batch_time = AverageMeter()  # forward prop. + back prop. time per batch
    data_time = AverageMeter()  # data loading time per batch
    losses = AverageMeter()  # cross entropy loss
    f1s = AverageMeter()  # f1 score

    start = time.time()

    # Batches
    for i, (wmaps, cmaps_f, cmaps_b, cmarkers_f, cmarkers_b, tmaps, wmap_lengths, cmap_lengths, probs) in enumerate(train_loader):
        
        data_time.update(time.time() - start)
        max_word_len = max(wmap_lengths.tolist())

        # Reduce batch's padded length to maximum in-batch sequence
        # This saves some compute on nn.Linear layers (RNNs are unaffected, since they don't compute over the pads)
        wmaps = wmaps[:, :max_word_len].to(device)
        probs = probs[:, :max_word_len].to(device)
        wmap_lengths = wmap_lengths.to(device)
        
        
        # Forward prop.
        scores, wmaps_sorted, probs_sorted, wmap_lengths_sorted, _ = model(wmaps, probs, wmap_lengths)
               
        # We don't predict the next word at the pads or <end> tokens
        # We will only predict at [dunston, checks, in] among [dunston, checks, in, <end>, <pad>, <pad>, ...]
        # So, prediction lengths are word sequence lengths - 1
        lm_lengths = wmap_lengths_sorted - 1
        lm_lengths = lm_lengths.tolist()
        
        # loss
        probs_sorted.resize_(scores.size())  
        
        scores = pack_padded_sequence(scores, lm_lengths, batch_first=True).data
        targets = pack_padded_sequence(probs_sorted, lm_lengths, batch_first=True).data
        loss = loss_fn(scores,targets)

        # Back prop.
        optimizer.zero_grad()
        loss.backward()

#         grad_clip = True
#         if grad_clip is not None:
#             clip_gradient(optimizer, grad_clip)

        optimizer.step()

        # Keep track of metrics
        losses.update(loss.item(), sum(lm_lengths))
        batch_time.update(time.time() - start)

        start = time.time()

        # Print training status
        if i % print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Batch Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Data Load Time {data_time.val:.3f} ({data_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'.format(epoch, i, len(train_loader),
                                                          batch_time=batch_time,
                                                          data_time=data_time, loss=losses))

# %%
epochs = 100
for epoch in range(0, epochs):

        # One epoch's training
        train(train_loader, model, loss_fn, optimizer, epoch)
        print("\n")
# Out:
# Epoch: [0][0/275]	Batch Time 1.410 (1.410)	Data Load Time 1.312 (1.312)	Loss 0.7305 (0.7305)
# Epoch: [0][25/275]	Batch Time 0.131 (0.150)	Data Load Time 0.003 (0.053)	Loss 0.7217 (0.7269)
# Epoch: [0][50/275]	Batch Time 0.085 (0.127)	Data Load Time 0.002 (0.028)	Loss 0.7247 (0.7251)
# Epoch: [0][75/275]	Batch Time 0.083 (0.113)	Data Load Time 0.003 (0.020)	Loss 0.7145 (0.7227)
# Epoch: [0][100/275]	Batch Time 0.087 (0.105)	Data Load Time 0.002 (0.015)	Loss 0.7091 (0.7196)
# Epoch: [0][125/275]	Batch Time 0.111 (0.101)	Data Load Time 0.003 (0.013)	Loss 0.6960 (0.7158)
# Epoch: [0][150/275]	Batch Time 0.081 (0.101)	Data Load Time 0.002 (0.011)	Loss 0.6837 (0.7117)
# Epoch: [0][175/275]	Batch Time 0.098 (0.100)	Data Load Time 0.002 (0.010)	Loss 0.6818 (0.7076)
# Epoch: [0][200/275]	Batch Time 0.094 (0.100)	Data Load Time 0.002 (0.009)	Loss 0.6692 (0.7035)
# Epoch: [0][225/275]	Batch Time 0.083 (0.099)	Data Load Time 0.002 (0.008)	Loss 0.6743 (0.6995)
# Epoch: [0][250/275]	Batch Time 0.078 (0.097)	Data Load Time 0.002 (0.008)	Loss 0.6619 (0.6958)
#
#
# Epoch: [1][0/275]	Batch Time 1.185 (1.185)	Data Load Time 1.097 (1.097)	Loss 0.6281 (0.6281)
# Epoch: [1][25/275]	Batch Time 0.076 (0.124)	Data Load Time 0.002 (0.044)	Loss 0.6350 (0.6457)
# Epoch: [1][50/275]	Batch Time 0.084 (0.103)	Data Load Time 0.002 (0.024)	Loss 0.6529 (0.6438)
# Epoch: [1][75/275]	Batch Time 0.082 (0.096)	Data Load Time 0.002 (0.016)	Loss 0.6264 (0.6432)
# Epoch: [1][100/275]	Batch Time 0.084 (0.092)	Data Load Time 0.002 (0.013)	Loss 0.6439 (0.6410)
# Epoch: [1][125/275]	Batch Time 0.095 (0.092)	Data Load Time 0.002 (0.011)	Loss 0.6266 (0.6391)
# Epoch: [1][150/275]	Batch Time 0.092 (0.093)	Data Load Time 0.002 (0.009)	Loss 0.6347 (0.6359)
# Epoch: [1][175/275]	Batch Time 0.094 (0.093)	Data Load Time 0.002 (0.008)	Loss 0.6020 (0.6341)
# Epoch: [1][200/275]	Batch Time 0.116 (0.095)	Data Load Time 0.002 (0.008)	Loss 0.5887 (0.6315)
# Epoch: [1][225/275]	Batch Time 0.085 (0.095)	Data Load Time 0.002 (0.007)	Loss 0.5684 (0.6292)
# Epoch: [1][250/275]	Batch Time 0.093 (0.096)	Data Load Time 0.003 (0.007)	Loss 0.5968 (0.6271)
#
#
# Epoch: [2][0/275]	Batch Time 1.274 (1.274)	Data Load Time 1.190 (1.190)	Loss 0.6087 (0.6087)
# Epoch: [2][25/275]	Batch Time 0.080 (0.127)	Data Load Time 0.002 (0.048)	Loss 0.5718 (0.5957)
# Epoch: [2][50/275]	Batch Time 0.115 (0.106)	Data Load Time 0.002 (0.025)	Loss 0.5916 (0.5983)
# Epoch: [2][75/275]	Batch Time 0.089 (0.101)	Data Load Time 0.002 (0.018)	Loss 0.5452 (0.5961)
# Epoch: [2][100/275]	Batch Time 0.091 (0.102)	Data Load Time 0.002 (0.014)	Loss 0.5586 (0.5926)
# Epoch: [2][125/275]	Batch Time 0.099 (0.100)	Data Load Time 0.002 (0.012)	Loss 0.5677 (0.5906)
# Epoch: [2][150/275]	Batch Time 0.100 (0.099)	Data Load Time 0.002 (0.010)	Loss 0.5589 (0.5887)
# Epoch: [2][175/275]	Batch Time 0.092 (0.099)	Data Load Time 0.003 (0.009)	Loss 0.5809 (0.5875)
# Epoch: [2][200/275]	Batch Time 0.084 (0.098)	Data Load Time 0.002 (0.008)	Loss 0.6095 (0.5862)
# Epoch: [2][225/275]	Batch Time 0.081 (0.096)	Data Load Time 0.002 (0.007)	Loss 0.5998 (0.5851)
# Epoch: [2][250/275]	Batch Time 0.077 (0.095)	Data Load Time 0.002 (0.007)	Loss 0.5763 (0.5836)
#
#
# Epoch: [3][0/275]	Batch Time 1.396 (1.396)	Data Load Time 1.304 (1.304)	Loss 0.5943 (0.5943)
# Epoch: [3][25/275]	Batch Time 0.078 (0.135)	Data Load Time 0.002 (0.052)	Loss 0.5750 (0.5619)
# Epoch: [3][50/275]	Batch Time 0.073 (0.108)	Data Load Time 0.002 (0.028)	Loss 0.6199 (0.5608)
# Epoch: [3][75/275]	Batch Time 0.103 (0.100)	Data Load Time 0.002 (0.019)	Loss 0.5601 (0.5618)
# Epoch: [3][100/275]	Batch Time 0.085 (0.099)	Data Load Time 0.002 (0.015)	Loss 0.5788 (0.5628)
# Epoch: [3][125/275]	Batch Time 0.102 (0.098)	Data Load Time 0.002 (0.012)	Loss 0.5728 (0.5638)
# Epoch: [3][150/275]	Batch Time 0.102 (0.098)	Data Load Time 0.002 (0.011)	Loss 0.5497 (0.5639)
# Epoch: [3][175/275]	Batch Time 0.104 (0.098)	Data Load Time 0.002 (0.010)	Loss 0.5429 (0.5629)
# Epoch: [3][200/275]	Batch Time 0.094 (0.097)	Data Load Time 0.002 (0.009)	Loss 0.5765 (0.5638)
# Epoch: [3][225/275]	Batch Time 0.093 (0.097)	Data Load Time 0.002 (0.008)	Loss 0.5092 (0.5637)
# Epoch: [3][250/275]	Batch Time 0.090 (0.097)	Data Load Time 0.002 (0.007)	Loss 0.5396 (0.5631)
#
#
# Epoch: [4][0/275]	Batch Time 1.254 (1.254)	Data Load Time 1.174 (1.174)	Loss 0.5316 (0.5316)
# Epoch: [4][25/275]	Batch Time 0.073 (0.125)	Data Load Time 0.002 (0.047)	Loss 0.6177 (0.5634)
# Epoch: [4][50/275]	Batch Time 0.082 (0.103)	Data Load Time 0.002 (0.025)	Loss 0.5148 (0.5586)
# Epoch: [4][75/275]	Batch Time 0.071 (0.096)	Data Load Time 0.001 (0.017)	Loss 0.5736 (0.5538)
# Epoch: [4][100/275]	Batch Time 0.082 (0.093)	Data Load Time 0.002 (0.014)	Loss 0.5500 (0.5533)
# Epoch: [4][125/275]	Batch Time 0.078 (0.090)	Data Load Time 0.002 (0.011)	Loss 0.5545 (0.5547)
# Epoch: [4][150/275]	Batch Time 0.076 (0.089)	Data Load Time 0.002 (0.010)	Loss 0.6142 (0.5533)
# Epoch: [4][175/275]	Batch Time 0.103 (0.088)	Data Load Time 0.003 (0.009)	Loss 0.5453 (0.5541)
# Epoch: [4][200/275]	Batch Time 0.095 (0.089)	Data Load Time 0.002 (0.008)	Loss 0.5096 (0.5534)
# Epoch: [4][225/275]	Batch Time 0.087 (0.090)	Data Load Time 0.003 (0.007)	Loss 0.5737 (0.5538)
# Epoch: [4][250/275]	Batch Time 0.092 (0.091)	Data Load Time 0.002 (0.007)	Loss 0.5660 (0.5539)
#
#
# Epoch: [5][0/275]	Batch Time 1.172 (1.172)	Data Load Time 1.093 (1.093)	Loss 0.5306 (0.5306)
# Epoch: [5][25/275]	Batch Time 0.088 (0.122)	Data Load Time 0.002 (0.044)	Loss 0.4999 (0.5450)
# Epoch: [5][50/275]	Batch Time 0.076 (0.103)	Data Load Time 0.002 (0.023)	Loss 0.5749 (0.5453)
# Epoch: [5][75/275]	Batch Time 0.104 (0.097)	Data Load Time 0.002 (0.016)	Loss 0.5836 (0.5454)
# Epoch: [5][100/275]	Batch Time 0.085 (0.096)	Data Load Time 0.002 (0.013)	Loss 0.5525 (0.5473)
# Epoch: [5][125/275]	Batch Time 0.074 (0.093)	Data Load Time 0.002 (0.011)	Loss 0.5605 (0.5483)
# Epoch: [5][150/275]	Batch Time 0.078 (0.091)	Data Load Time 0.003 (0.009)	Loss 0.5406 (0.5488)
# Epoch: [5][175/275]	Batch Time 0.093 (0.092)	Data Load Time 0.002 (0.008)	Loss 0.5585 (0.5485)
# Epoch: [5][200/275]	Batch Time 0.110 (0.093)	Data Load Time 0.002 (0.008)	Loss 0.5405 (0.5481)
# Epoch: [5][225/275]	Batch Time 0.089 (0.094)	Data Load Time 0.003 (0.007)	Loss 0.5578 (0.5473)
# Epoch: [5][250/275]	Batch Time 0.089 (0.094)	Data Load Time 0.002 (0.007)	Loss 0.5675 (0.5476)
#
#
# Epoch: [6][0/275]	Batch Time 1.176 (1.176)	Data Load Time 1.094 (1.094)	Loss 0.5681 (0.5681)
# Epoch: [6][25/275]	Batch Time 0.080 (0.127)	Data Load Time 0.002 (0.044)	Loss 0.5455 (0.5368)
# Epoch: [6][50/275]	Batch Time 0.080 (0.105)	Data Load Time 0.002 (0.024)	Loss 0.5483 (0.5373)
# Epoch: [6][75/275]	Batch Time 0.081 (0.098)	Data Load Time 0.002 (0.016)	Loss 0.5462 (0.5375)
# Epoch: [6][100/275]	Batch Time 0.086 (0.097)	Data Load Time 0.003 (0.013)	Loss 0.5628 (0.5413)
# Epoch: [6][125/275]	Batch Time 0.089 (0.095)	Data Load Time 0.002 (0.011)	Loss 0.6116 (0.5428)
# Epoch: [6][150/275]	Batch Time 0.102 (0.094)	Data Load Time 0.002 (0.009)	Loss 0.5270 (0.5444)
# Epoch: [6][175/275]	Batch Time 0.087 (0.094)	Data Load Time 0.002 (0.008)	Loss 0.5587 (0.5447)
# Epoch: [6][200/275]	Batch Time 0.094 (0.094)	Data Load Time 0.002 (0.008)	Loss 0.5937 (0.5439)
# Epoch: [6][225/275]	Batch Time 0.101 (0.094)	Data Load Time 0.003 (0.007)	Loss 0.4785 (0.5435)
# Epoch: [6][250/275]	Batch Time 0.079 (0.095)	Data Load Time 0.002 (0.007)	Loss 0.6091 (0.5438)
#
#
# Epoch: [7][0/275]	Batch Time 1.175 (1.175)	Data Load Time 1.096 (1.096)	Loss 0.5510 (0.5510)
# Epoch: [7][25/275]	Batch Time 0.085 (0.124)	Data Load Time 0.002 (0.044)	Loss 0.5332 (0.5385)
# Epoch: [7][50/275]	Batch Time 0.117 (0.106)	Data Load Time 0.002 (0.024)	Loss 0.5947 (0.5400)
# Epoch: [7][75/275]	Batch Time 0.080 (0.099)	Data Load Time 0.002 (0.017)	Loss 0.5036 (0.5396)
# Epoch: [7][100/275]	Batch Time 0.079 (0.095)	Data Load Time 0.002 (0.013)	Loss 0.5307 (0.5405)
# Epoch: [7][125/275]	Batch Time 0.080 (0.092)	Data Load Time 0.002 (0.011)	Loss 0.5212 (0.5397)
# Epoch: [7][150/275]	Batch Time 0.083 (0.092)	Data Load Time 0.002 (0.009)	Loss 0.4937 (0.5391)
# Epoch: [7][175/275]	Batch Time 0.086 (0.092)	Data Load Time 0.002 (0.008)	Loss 0.5114 (0.5399)
# Epoch: [7][200/275]	Batch Time 0.097 (0.095)	Data Load Time 0.002 (0.008)	Loss 0.5635 (0.5413)
# Epoch: [7][225/275]	Batch Time 0.091 (0.096)	Data Load Time 0.002 (0.007)	Loss 0.5554 (0.5413)
# Epoch: [7][250/275]	Batch Time 0.078 (0.095)	Data Load Time 0.002 (0.007)	Loss 0.5271 (0.5405)
#
#
# Epoch: [8][0/275]	Batch Time 1.189 (1.189)	Data Load Time 1.107 (1.107)	Loss 0.5242 (0.5242)
# Epoch: [8][25/275]	Batch Time 0.084 (0.124)	Data Load Time 0.003 (0.045)	Loss 0.5300 (0.5454)
# Epoch: [8][50/275]	Batch Time 0.079 (0.104)	Data Load Time 0.002 (0.024)	Loss 0.5523 (0.5378)
# Epoch: [8][75/275]	Batch Time 0.077 (0.096)	Data Load Time 0.002 (0.017)	Loss 0.6006 (0.5387)
# Epoch: [8][100/275]	Batch Time 0.077 (0.093)	Data Load Time 0.002 (0.013)	Loss 0.5605 (0.5385)
# Epoch: [8][125/275]	Batch Time 0.097 (0.092)	Data Load Time 0.002 (0.011)	Loss 0.5473 (0.5373)
# Epoch: [8][150/275]	Batch Time 0.120 (0.096)	Data Load Time 0.003 (0.010)	Loss 0.5127 (0.5376)
# Epoch: [8][175/275]	Batch Time 0.108 (0.098)	Data Load Time 0.002 (0.009)	Loss 0.5182 (0.5378)
# Epoch: [8][200/275]	Batch Time 0.103 (0.100)	Data Load Time 0.002 (0.008)	Loss 0.5659 (0.5387)
# Epoch: [8][225/275]	Batch Time 0.088 (0.100)	Data Load Time 0.003 (0.007)	Loss 0.5184 (0.5376)
# Epoch: [8][250/275]	Batch Time 0.088 (0.100)	Data Load Time 0.002 (0.007)	Loss 0.5439 (0.5371)
#
#
# Epoch: [9][0/275]	Batch Time 1.547 (1.547)	Data Load Time 1.446 (1.446)	Loss 0.5906 (0.5906)
# Epoch: [9][25/275]	Batch Time 0.110 (0.157)	Data Load Time 0.003 (0.058)	Loss 0.5227 (0.5325)
# Epoch: [9][50/275]	Batch Time 0.086 (0.127)	Data Load Time 0.002 (0.031)	Loss 0.5354 (0.5351)
# Epoch: [9][75/275]	Batch Time 0.105 (0.116)	Data Load Time 0.002 (0.021)	Loss 0.5475 (0.5330)
# Epoch: [9][100/275]	Batch Time 0.089 (0.111)	Data Load Time 0.002 (0.017)	Loss 0.5220 (0.5351)
# Epoch: [9][125/275]	Batch Time 0.121 (0.109)	Data Load Time 0.002 (0.014)	Loss 0.5417 (0.5358)
# Epoch: [9][150/275]	Batch Time 0.093 (0.106)	Data Load Time 0.002 (0.012)	Loss 0.4581 (0.5357)
# Epoch: [9][175/275]	Batch Time 0.107 (0.106)	Data Load Time 0.002 (0.011)	Loss 0.4877 (0.5360)
# Epoch: [9][200/275]	Batch Time 0.082 (0.104)	Data Load Time 0.002 (0.010)	Loss 0.5002 (0.5345)
# Epoch: [9][225/275]	Batch Time 0.081 (0.102)	Data Load Time 0.002 (0.009)	Loss 0.5949 (0.5349)
# Epoch: [9][250/275]	Batch Time 0.079 (0.100)	Data Load Time 0.002 (0.008)	Loss 0.5298 (0.5356)
#
#
# Epoch: [10][0/275]	Batch Time 1.229 (1.229)	Data Load Time 1.136 (1.136)	Loss 0.6202 (0.6202)
# Epoch: [10][25/275]	Batch Time 0.081 (0.128)	Data Load Time 0.002 (0.046)	Loss 0.5399 (0.5366)
# Epoch: [10][50/275]	Batch Time 0.093 (0.112)	Data Load Time 0.002 (0.024)	Loss 0.5345 (0.5309)
# Epoch: [10][75/275]	Batch Time 0.094 (0.107)	Data Load Time 0.002 (0.017)	Loss 0.5275 (0.5358)
# Epoch: [10][100/275]	Batch Time 0.089 (0.105)	Data Load Time 0.002 (0.014)	Loss 0.5389 (0.5354)
# Epoch: [10][125/275]	Batch Time 0.105 (0.104)	Data Load Time 0.003 (0.011)	Loss 0.5055 (0.5354)
# Epoch: [10][150/275]	Batch Time 0.109 (0.103)	Data Load Time 0.002 (0.010)	Loss 0.5168 (0.5356)
# Epoch: [10][175/275]	Batch Time 0.108 (0.103)	Data Load Time 0.002 (0.009)	Loss 0.5451 (0.5351)
# Epoch: [10][200/275]	Batch Time 0.113 (0.104)	Data Load Time 0.004 (0.008)	Loss 0.6107 (0.5344)
# Epoch: [10][225/275]	Batch Time 0.118 (0.105)	Data Load Time 0.003 (0.007)	Loss 0.5352 (0.5345)
# Epoch: [10][250/275]	Batch Time 0.079 (0.103)	Data Load Time 0.002 (0.007)	Loss 0.5209 (0.5348)
#
#
# Epoch: [11][0/275]	Batch Time 1.198 (1.198)	Data Load Time 1.099 (1.099)	Loss 0.5345 (0.5345)
# Epoch: [11][25/275]	Batch Time 0.093 (0.125)	Data Load Time 0.002 (0.044)	Loss 0.5382 (0.5357)
# Epoch: [11][50/275]	Batch Time 0.090 (0.105)	Data Load Time 0.002 (0.024)	Loss 0.4927 (0.5359)
# Epoch: [11][75/275]	Batch Time 0.082 (0.097)	Data Load Time 0.002 (0.016)	Loss 0.5715 (0.5374)
# Epoch: [11][100/275]	Batch Time 0.085 (0.094)	Data Load Time 0.002 (0.013)	Loss 0.5227 (0.5358)
# Epoch: [11][125/275]	Batch Time 0.088 (0.093)	Data Load Time 0.003 (0.011)	Loss 0.4941 (0.5333)
# Epoch: [11][150/275]	Batch Time 0.096 (0.094)	Data Load Time 0.003 (0.009)	Loss 0.5326 (0.5323)
# Epoch: [11][175/275]	Batch Time 0.110 (0.095)	Data Load Time 0.002 (0.008)	Loss 0.5129 (0.5329)
# Epoch: [11][200/275]	Batch Time 0.090 (0.096)	Data Load Time 0.002 (0.008)	Loss 0.5328 (0.5329)
# Epoch: [11][225/275]	Batch Time 0.097 (0.096)	Data Load Time 0.002 (0.007)	Loss 0.5102 (0.5331)
# Epoch: [11][250/275]	Batch Time 0.120 (0.097)	Data Load Time 0.003 (0.007)	Loss 0.5308 (0.5324)
#
#
# Epoch: [12][0/275]	Batch Time 1.477 (1.477)	Data Load Time 1.361 (1.361)	Loss 0.4849 (0.4849)
# Epoch: [12][25/275]	Batch Time 0.079 (0.149)	Data Load Time 0.002 (0.055)	Loss 0.5276 (0.5246)
# Epoch: [12][50/275]	Batch Time 0.080 (0.117)	Data Load Time 0.002 (0.029)	Loss 0.4884 (0.5243)
# Epoch: [12][75/275]	Batch Time 0.080 (0.106)	Data Load Time 0.002 (0.020)	Loss 0.5603 (0.5300)
# Epoch: [12][100/275]	Batch Time 0.078 (0.100)	Data Load Time 0.002 (0.016)	Loss 0.6214 (0.5304)
# Epoch: [12][125/275]	Batch Time 0.075 (0.096)	Data Load Time 0.002 (0.013)	Loss 0.5380 (0.5279)
# Epoch: [12][150/275]	Batch Time 0.095 (0.094)	Data Load Time 0.002 (0.011)	Loss 0.4971 (0.5282)
# Epoch: [12][175/275]	Batch Time 0.078 (0.092)	Data Load Time 0.002 (0.010)	Loss 0.5483 (0.5290)
# Epoch: [12][200/275]	Batch Time 0.125 (0.092)	Data Load Time 0.002 (0.009)	Loss 0.4818 (0.5282)
# Epoch: [12][225/275]	Batch Time 0.098 (0.093)	Data Load Time 0.003 (0.008)	Loss 0.5524 (0.5287)
# Epoch: [12][250/275]	Batch Time 0.116 (0.093)	Data Load Time 0.002 (0.008)	Loss 0.5728 (0.5300)
#
#
# Epoch: [13][0/275]	Batch Time 1.425 (1.425)	Data Load Time 1.315 (1.315)	Loss 0.5274 (0.5274)
# Epoch: [13][25/275]	Batch Time 0.093 (0.156)	Data Load Time 0.003 (0.053)	Loss 0.5095 (0.5282)
# Epoch: [13][50/275]	Batch Time 0.101 (0.129)	Data Load Time 0.003 (0.028)	Loss 0.5159 (0.5287)
# Epoch: [13][75/275]	Batch Time 0.110 (0.120)	Data Load Time 0.002 (0.020)	Loss 0.5037 (0.5306)
# Epoch: [13][100/275]	Batch Time 0.111 (0.115)	Data Load Time 0.002 (0.015)	Loss 0.5045 (0.5316)
# Epoch: [13][125/275]	Batch Time 0.076 (0.110)	Data Load Time 0.002 (0.013)	Loss 0.5115 (0.5316)
# Epoch: [13][150/275]	Batch Time 0.096 (0.106)	Data Load Time 0.002 (0.011)	Loss 0.5971 (0.5309)
# Epoch: [13][175/275]	Batch Time 0.089 (0.103)	Data Load Time 0.002 (0.010)	Loss 0.5092 (0.5301)
# Epoch: [13][200/275]	Batch Time 0.082 (0.101)	Data Load Time 0.002 (0.009)	Loss 0.5044 (0.5291)
# Epoch: [13][225/275]	Batch Time 0.077 (0.099)	Data Load Time 0.002 (0.008)	Loss 0.5609 (0.5293)
# Epoch: [13][250/275]	Batch Time 0.081 (0.097)	Data Load Time 0.002 (0.007)	Loss 0.5630 (0.5293)
#
#
# Epoch: [14][0/275]	Batch Time 1.422 (1.422)	Data Load Time 1.321 (1.321)	Loss 0.5554 (0.5554)
# Epoch: [14][25/275]	Batch Time 0.105 (0.150)	Data Load Time 0.002 (0.053)	Loss 0.6096 (0.5419)
# Epoch: [14][50/275]	Batch Time 0.104 (0.127)	Data Load Time 0.002 (0.028)	Loss 0.5710 (0.5383)
# Epoch: [14][75/275]	Batch Time 0.089 (0.118)	Data Load Time 0.003 (0.020)	Loss 0.4983 (0.5330)
# Epoch: [14][100/275]	Batch Time 0.077 (0.110)	Data Load Time 0.002 (0.015)	Loss 0.5303 (0.5322)
# Epoch: [14][125/275]	Batch Time 0.083 (0.104)	Data Load Time 0.002 (0.013)	Loss 0.4798 (0.5318)
# Epoch: [14][150/275]	Batch Time 0.076 (0.102)	Data Load Time 0.002 (0.011)	Loss 0.5577 (0.5325)
# Epoch: [14][175/275]	Batch Time 0.074 (0.099)	Data Load Time 0.002 (0.010)	Loss 0.5424 (0.5305)
# Epoch: [14][200/275]	Batch Time 0.081 (0.097)	Data Load Time 0.003 (0.009)	Loss 0.4995 (0.5295)
# Epoch: [14][225/275]	Batch Time 0.080 (0.096)	Data Load Time 0.002 (0.008)	Loss 0.5411 (0.5302)
# Epoch: [14][250/275]	Batch Time 0.080 (0.094)	Data Load Time 0.002 (0.007)	Loss 0.5226 (0.5283)
#
#
# Epoch: [15][0/275]	Batch Time 2.023 (2.023)	Data Load Time 1.917 (1.917)	Loss 0.5451 (0.5451)
# Epoch: [15][25/275]	Batch Time 0.093 (0.172)	Data Load Time 0.003 (0.076)	Loss 0.5267 (0.5368)
# Epoch: [15][50/275]	Batch Time 0.102 (0.138)	Data Load Time 0.003 (0.040)	Loss 0.5489 (0.5379)
# Epoch: [15][75/275]	Batch Time 0.095 (0.125)	Data Load Time 0.003 (0.028)	Loss 0.5079 (0.5364)
# Epoch: [15][100/275]	Batch Time 0.090 (0.115)	Data Load Time 0.002 (0.021)	Loss 0.5086 (0.5345)
# Epoch: [15][125/275]	Batch Time 0.085 (0.109)	Data Load Time 0.002 (0.018)	Loss 0.5449 (0.5300)
# Epoch: [15][150/275]	Batch Time 0.078 (0.105)	Data Load Time 0.002 (0.015)	Loss 0.5227 (0.5289)
# Epoch: [15][175/275]	Batch Time 0.101 (0.102)	Data Load Time 0.002 (0.013)	Loss 0.5647 (0.5285)
# Epoch: [15][200/275]	Batch Time 0.084 (0.100)	Data Load Time 0.002 (0.012)	Loss 0.5274 (0.5288)
# Epoch: [15][225/275]	Batch Time 0.081 (0.098)	Data Load Time 0.002 (0.011)	Loss 0.5004 (0.5289)
# Epoch: [15][250/275]	Batch Time 0.103 (0.098)	Data Load Time 0.002 (0.010)	Loss 0.4710 (0.5282)
#
#
# Epoch: [16][0/275]	Batch Time 1.430 (1.430)	Data Load Time 1.319 (1.319)	Loss 0.4962 (0.4962)
# Epoch: [16][25/275]	Batch Time 0.086 (0.151)	Data Load Time 0.003 (0.053)	Loss 0.5803 (0.5319)
# Epoch: [16][50/275]	Batch Time 0.114 (0.128)	Data Load Time 0.002 (0.028)	Loss 0.5342 (0.5283)
# Epoch: [16][75/275]	Batch Time 0.111 (0.124)	Data Load Time 0.003 (0.020)	Loss 0.5225 (0.5290)
# Epoch: [16][100/275]	Batch Time 0.091 (0.120)	Data Load Time 0.002 (0.016)	Loss 0.5787 (0.5276)
# Epoch: [16][125/275]	Batch Time 0.100 (0.119)	Data Load Time 0.003 (0.013)	Loss 0.5763 (0.5302)
# Epoch: [16][150/275]	Batch Time 0.100 (0.118)	Data Load Time 0.002 (0.011)	Loss 0.5464 (0.5293)
# Epoch: [16][175/275]	Batch Time 0.095 (0.115)	Data Load Time 0.002 (0.010)	Loss 0.5375 (0.5284)
# Epoch: [16][200/275]	Batch Time 0.089 (0.111)	Data Load Time 0.002 (0.009)	Loss 0.4781 (0.5277)
# Epoch: [16][225/275]	Batch Time 0.080 (0.108)	Data Load Time 0.003 (0.008)	Loss 0.5284 (0.5273)
# Epoch: [16][250/275]	Batch Time 0.111 (0.106)	Data Load Time 0.003 (0.008)	Loss 0.4964 (0.5271)
#
#
# Epoch: [17][0/275]	Batch Time 1.713 (1.713)	Data Load Time 1.613 (1.613)	Loss 0.5350 (0.5350)
# Epoch: [17][25/275]	Batch Time 0.160 (0.184)	Data Load Time 0.003 (0.065)	Loss 0.5680 (0.5125)
# Epoch: [17][50/275]	Batch Time 0.126 (0.156)	Data Load Time 0.002 (0.035)	Loss 0.5337 (0.5248)
# Epoch: [17][75/275]	Batch Time 0.116 (0.141)	Data Load Time 0.003 (0.024)	Loss 0.4593 (0.5243)
# Epoch: [17][100/275]	Batch Time 0.109 (0.130)	Data Load Time 0.003 (0.019)	Loss 0.5430 (0.5280)
# Epoch: [17][125/275]	Batch Time 0.102 (0.126)	Data Load Time 0.003 (0.016)	Loss 0.5514 (0.5280)
# Epoch: [17][150/275]	Batch Time 0.123 (0.125)	Data Load Time 0.003 (0.014)	Loss 0.5471 (0.5271)
# Epoch: [17][175/275]	Batch Time 0.103 (0.124)	Data Load Time 0.003 (0.012)	Loss 0.5044 (0.5269)
# Epoch: [17][200/275]	Batch Time 0.092 (0.122)	Data Load Time 0.003 (0.011)	Loss 0.4960 (0.5263)
# Epoch: [17][225/275]	Batch Time 0.099 (0.119)	Data Load Time 0.003 (0.010)	Loss 0.5190 (0.5260)
# Epoch: [17][250/275]	Batch Time 0.099 (0.117)	Data Load Time 0.002 (0.009)	Loss 0.4853 (0.5257)
#
#
# Epoch: [18][0/275]	Batch Time 1.405 (1.405)	Data Load Time 1.312 (1.312)	Loss 0.5073 (0.5073)
# Epoch: [18][25/275]	Batch Time 0.096 (0.149)	Data Load Time 0.002 (0.053)	Loss 0.4757 (0.5281)
# Epoch: [18][50/275]	Batch Time 0.086 (0.120)	Data Load Time 0.002 (0.028)	Loss 0.5314 (0.5267)
# Epoch: [18][75/275]	Batch Time 0.084 (0.108)	Data Load Time 0.002 (0.020)	Loss 0.4959 (0.5230)
# Epoch: [18][100/275]	Batch Time 0.077 (0.102)	Data Load Time 0.002 (0.015)	Loss 0.5918 (0.5285)
# Epoch: [18][125/275]	Batch Time 0.077 (0.098)	Data Load Time 0.002 (0.013)	Loss 0.4888 (0.5285)
# Epoch: [18][150/275]	Batch Time 0.079 (0.095)	Data Load Time 0.002 (0.011)	Loss 0.5373 (0.5268)
# Epoch: [18][175/275]	Batch Time 0.082 (0.094)	Data Load Time 0.002 (0.010)	Loss 0.5593 (0.5260)
# Epoch: [18][200/275]	Batch Time 0.084 (0.092)	Data Load Time 0.003 (0.009)	Loss 0.5279 (0.5255)
# Epoch: [18][225/275]	Batch Time 0.098 (0.093)	Data Load Time 0.003 (0.008)	Loss 0.5087 (0.5255)
# Epoch: [18][250/275]	Batch Time 0.103 (0.094)	Data Load Time 0.003 (0.007)	Loss 0.5033 (0.5250)
#
#
# Epoch: [19][0/275]	Batch Time 1.406 (1.406)	Data Load Time 1.312 (1.312)	Loss 0.5494 (0.5494)
# Epoch: [19][25/275]	Batch Time 0.100 (0.149)	Data Load Time 0.003 (0.053)	Loss 0.5861 (0.5190)
# Epoch: [19][50/275]	Batch Time 0.088 (0.124)	Data Load Time 0.002 (0.028)	Loss 0.5141 (0.5211)
# Epoch: [19][75/275]	Batch Time 0.094 (0.116)	Data Load Time 0.002 (0.020)	Loss 0.4890 (0.5224)
# Epoch: [19][100/275]	Batch Time 0.085 (0.112)	Data Load Time 0.002 (0.015)	Loss 0.5314 (0.5250)
# Epoch: [19][125/275]	Batch Time 0.101 (0.108)	Data Load Time 0.002 (0.013)	Loss 0.5642 (0.5231)
# Epoch: [19][150/275]	Batch Time 0.084 (0.106)	Data Load Time 0.002 (0.011)	Loss 0.5495 (0.5225)
# Epoch: [19][175/275]	Batch Time 0.084 (0.102)	Data Load Time 0.002 (0.010)	Loss 0.5594 (0.5224)
# Epoch: [19][200/275]	Batch Time 0.080 (0.100)	Data Load Time 0.002 (0.009)	Loss 0.5082 (0.5236)
# Epoch: [19][225/275]	Batch Time 0.085 (0.099)	Data Load Time 0.003 (0.008)	Loss 0.5208 (0.5239)
# Epoch: [19][250/275]	Batch Time 0.078 (0.097)	Data Load Time 0.002 (0.008)	Loss 0.5176 (0.5240)
#
#
# Epoch: [20][0/275]	Batch Time 1.321 (1.321)	Data Load Time 1.232 (1.232)	Loss 0.5471 (0.5471)
# Epoch: [20][25/275]	Batch Time 0.092 (0.154)	Data Load Time 0.002 (0.050)	Loss 0.5297 (0.5200)
# Epoch: [20][50/275]	Batch Time 0.109 (0.127)	Data Load Time 0.003 (0.027)	Loss 0.5258 (0.5181)
# Epoch: [20][75/275]	Batch Time 0.094 (0.118)	Data Load Time 0.002 (0.019)	Loss 0.5274 (0.5200)
# Epoch: [20][100/275]	Batch Time 0.091 (0.113)	Data Load Time 0.003 (0.015)	Loss 0.5759 (0.5202)
# Epoch: [20][125/275]	Batch Time 0.085 (0.110)	Data Load Time 0.002 (0.012)	Loss 0.5597 (0.5213)
# Epoch: [20][150/275]	Batch Time 0.105 (0.108)	Data Load Time 0.002 (0.011)	Loss 0.5762 (0.5221)
# Epoch: [20][175/275]	Batch Time 0.096 (0.107)	Data Load Time 0.002 (0.009)	Loss 0.4845 (0.5238)
# Epoch: [20][200/275]	Batch Time 0.111 (0.106)	Data Load Time 0.002 (0.009)	Loss 0.5081 (0.5217)
# Epoch: [20][225/275]	Batch Time 0.116 (0.106)	Data Load Time 0.003 (0.008)	Loss 0.5947 (0.5223)
# Epoch: [20][250/275]	Batch Time 0.097 (0.105)	Data Load Time 0.003 (0.007)	Loss 0.5082 (0.5228)
#
#
# Epoch: [21][0/275]	Batch Time 1.606 (1.606)	Data Load Time 1.500 (1.500)	Loss 0.4990 (0.4990)
# Epoch: [21][25/275]	Batch Time 0.084 (0.147)	Data Load Time 0.002 (0.060)	Loss 0.4931 (0.5164)
# Epoch: [21][50/275]	Batch Time 0.123 (0.130)	Data Load Time 0.003 (0.032)	Loss 0.5256 (0.5134)
# Epoch: [21][75/275]	Batch Time 0.102 (0.124)	Data Load Time 0.003 (0.022)	Loss 0.5605 (0.5116)
# Epoch: [21][100/275]	Batch Time 0.092 (0.121)	Data Load Time 0.002 (0.017)	Loss 0.5128 (0.5172)
# Epoch: [21][125/275]	Batch Time 0.113 (0.120)	Data Load Time 0.002 (0.015)	Loss 0.4974 (0.5198)
# Epoch: [21][150/275]	Batch Time 0.120 (0.119)	Data Load Time 0.002 (0.013)	Loss 0.5040 (0.5225)
# Epoch: [21][175/275]	Batch Time 0.113 (0.120)	Data Load Time 0.002 (0.011)	Loss 0.6065 (0.5223)
# Epoch: [21][200/275]	Batch Time 0.110 (0.119)	Data Load Time 0.003 (0.010)	Loss 0.4951 (0.5220)
# Epoch: [21][225/275]	Batch Time 0.106 (0.119)	Data Load Time 0.003 (0.009)	Loss 0.5291 (0.5227)
# Epoch: [21][250/275]	Batch Time 0.112 (0.120)	Data Load Time 0.003 (0.009)	Loss 0.4750 (0.5233)
#
#
# Epoch: [22][0/275]	Batch Time 1.865 (1.865)	Data Load Time 1.761 (1.761)	Loss 0.5336 (0.5336)
# Epoch: [22][25/275]	Batch Time 0.122 (0.176)	Data Load Time 0.004 (0.070)	Loss 0.5304 (0.5178)
# Epoch: [22][50/275]	Batch Time 0.095 (0.143)	Data Load Time 0.002 (0.037)	Loss 0.4638 (0.5130)
# Epoch: [22][75/275]	Batch Time 0.109 (0.130)	Data Load Time 0.003 (0.026)	Loss 0.4836 (0.5180)
# Epoch: [22][100/275]	Batch Time 0.118 (0.128)	Data Load Time 0.002 (0.020)	Loss 0.5521 (0.5198)
# Epoch: [22][125/275]	Batch Time 0.119 (0.124)	Data Load Time 0.002 (0.017)	Loss 0.5342 (0.5207)
# Epoch: [22][150/275]	Batch Time 0.117 (0.121)	Data Load Time 0.002 (0.014)	Loss 0.5216 (0.5224)
# Epoch: [22][175/275]	Batch Time 0.100 (0.121)	Data Load Time 0.003 (0.013)	Loss 0.5943 (0.5229)
# Epoch: [22][200/275]	Batch Time 0.124 (0.119)	Data Load Time 0.003 (0.012)	Loss 0.4797 (0.5224)
# Epoch: [22][225/275]	Batch Time 0.099 (0.120)	Data Load Time 0.003 (0.011)	Loss 0.5875 (0.5227)
# Epoch: [22][250/275]	Batch Time 0.090 (0.118)	Data Load Time 0.002 (0.010)	Loss 0.5145 (0.5231)
#
#
# Epoch: [23][0/275]	Batch Time 1.266 (1.266)	Data Load Time 1.189 (1.189)	Loss 0.5431 (0.5431)
# Epoch: [23][25/275]	Batch Time 0.084 (0.132)	Data Load Time 0.002 (0.048)	Loss 0.5014 (0.5316)
# Epoch: [23][50/275]	Batch Time 0.082 (0.108)	Data Load Time 0.002 (0.025)	Loss 0.5465 (0.5304)
# Epoch: [23][75/275]	Batch Time 0.092 (0.100)	Data Load Time 0.004 (0.018)	Loss 0.4984 (0.5260)
# Epoch: [23][100/275]	Batch Time 0.106 (0.098)	Data Load Time 0.003 (0.014)	Loss 0.5817 (0.5260)
# Epoch: [23][125/275]	Batch Time 0.153 (0.107)	Data Load Time 0.004 (0.012)	Loss 0.5319 (0.5234)
# Epoch: [23][150/275]	Batch Time 0.116 (0.111)	Data Load Time 0.003 (0.011)	Loss 0.4879 (0.5230)
# Epoch: [23][175/275]	Batch Time 0.114 (0.111)	Data Load Time 0.002 (0.009)	Loss 0.5355 (0.5231)
# Epoch: [23][200/275]	Batch Time 0.122 (0.111)	Data Load Time 0.002 (0.009)	Loss 0.5621 (0.5237)
# Epoch: [23][225/275]	Batch Time 0.104 (0.111)	Data Load Time 0.002 (0.008)	Loss 0.5526 (0.5229)
# Epoch: [23][250/275]	Batch Time 0.129 (0.111)	Data Load Time 0.003 (0.007)	Loss 0.6055 (0.5227)
#
#
# Epoch: [24][0/275]	Batch Time 1.646 (1.646)	Data Load Time 1.546 (1.546)	Loss 0.5231 (0.5231)
# Epoch: [24][25/275]	Batch Time 0.104 (0.175)	Data Load Time 0.002 (0.062)	Loss 0.5047 (0.5269)
# Epoch: [24][50/275]	Batch Time 0.111 (0.146)	Data Load Time 0.003 (0.033)	Loss 0.5077 (0.5269)
# Epoch: [24][75/275]	Batch Time 0.100 (0.138)	Data Load Time 0.003 (0.023)	Loss 0.5518 (0.5266)
# Epoch: [24][100/275]	Batch Time 0.089 (0.135)	Data Load Time 0.003 (0.018)	Loss 0.5246 (0.5237)
# Epoch: [24][125/275]	Batch Time 0.082 (0.129)	Data Load Time 0.002 (0.015)	Loss 0.4974 (0.5237)
# Epoch: [24][150/275]	Batch Time 0.087 (0.121)	Data Load Time 0.003 (0.013)	Loss 0.5263 (0.5230)
# Epoch: [24][175/275]	Batch Time 0.088 (0.117)	Data Load Time 0.003 (0.012)	Loss 0.5047 (0.5233)
# Epoch: [24][200/275]	Batch Time 0.086 (0.114)	Data Load Time 0.002 (0.010)	Loss 0.5390 (0.5226)
# Epoch: [24][225/275]	Batch Time 0.093 (0.113)	Data Load Time 0.002 (0.009)	Loss 0.5545 (0.5220)
# Epoch: [24][250/275]	Batch Time 0.089 (0.111)	Data Load Time 0.003 (0.009)	Loss 0.4967 (0.5222)
#
#
# Epoch: [25][0/275]	Batch Time 1.491 (1.491)	Data Load Time 1.397 (1.397)	Loss 0.5510 (0.5510)
# Epoch: [25][25/275]	Batch Time 0.107 (0.161)	Data Load Time 0.002 (0.056)	Loss 0.4808 (0.5230)
# Epoch: [25][50/275]	Batch Time 0.171 (0.144)	Data Load Time 0.003 (0.030)	Loss 0.5167 (0.5196)
# Epoch: [25][75/275]	Batch Time 0.128 (0.146)	Data Load Time 0.003 (0.022)	Loss 0.5030 (0.5201)
# Epoch: [25][100/275]	Batch Time 0.128 (0.141)	Data Load Time 0.003 (0.017)	Loss 0.5110 (0.5210)
# Epoch: [25][125/275]	Batch Time 0.131 (0.135)	Data Load Time 0.004 (0.014)	Loss 0.5483 (0.5210)
# Epoch: [25][150/275]	Batch Time 0.095 (0.130)	Data Load Time 0.002 (0.012)	Loss 0.4640 (0.5190)
# Epoch: [25][175/275]	Batch Time 0.090 (0.124)	Data Load Time 0.003 (0.011)	Loss 0.5416 (0.5166)
# Epoch: [25][200/275]	Batch Time 0.097 (0.120)	Data Load Time 0.002 (0.010)	Loss 0.4855 (0.5168)
# Epoch: [25][225/275]	Batch Time 0.085 (0.117)	Data Load Time 0.003 (0.009)	Loss 0.5317 (0.5187)
# Epoch: [25][250/275]	Batch Time 0.111 (0.115)	Data Load Time 0.002 (0.008)	Loss 0.4797 (0.5195)
#
#
# Epoch: [26][0/275]	Batch Time 1.335 (1.335)	Data Load Time 1.252 (1.252)	Loss 0.5839 (0.5839)
# Epoch: [26][25/275]	Batch Time 0.099 (0.153)	Data Load Time 0.003 (0.051)	Loss 0.4566 (0.5151)
# Epoch: [26][50/275]	Batch Time 0.132 (0.133)	Data Load Time 0.003 (0.027)	Loss 0.5136 (0.5116)
# Epoch: [26][75/275]	Batch Time 0.169 (0.144)	Data Load Time 0.005 (0.020)	Loss 0.5377 (0.5120)
# Epoch: [26][100/275]	Batch Time 0.110 (0.138)	Data Load Time 0.002 (0.016)	Loss 0.5074 (0.5146)
# Epoch: [26][125/275]	Batch Time 0.104 (0.131)	Data Load Time 0.003 (0.013)	Loss 0.5066 (0.5185)
# Epoch: [26][150/275]	Batch Time 0.149 (0.127)	Data Load Time 0.003 (0.011)	Loss 0.4897 (0.5203)
# Epoch: [26][175/275]	Batch Time 0.169 (0.125)	Data Load Time 0.003 (0.010)	Loss 0.5200 (0.5202)
# Epoch: [26][200/275]	Batch Time 0.109 (0.124)	Data Load Time 0.003 (0.009)	Loss 0.5844 (0.5198)
# Epoch: [26][225/275]	Batch Time 0.115 (0.123)	Data Load Time 0.003 (0.008)	Loss 0.5192 (0.5207)
# Epoch: [26][250/275]	Batch Time 0.095 (0.121)	Data Load Time 0.002 (0.008)	Loss 0.5451 (0.5202)
#
#
# Epoch: [27][0/275]	Batch Time 1.643 (1.643)	Data Load Time 1.551 (1.551)	Loss 0.5383 (0.5383)
# Epoch: [27][25/275]	Batch Time 0.092 (0.167)	Data Load Time 0.002 (0.062)	Loss 0.5642 (0.5206)
# Epoch: [27][50/275]	Batch Time 0.087 (0.133)	Data Load Time 0.002 (0.033)	Loss 0.5301 (0.5207)
# Epoch: [27][75/275]	Batch Time 0.129 (0.125)	Data Load Time 0.003 (0.023)	Loss 0.5151 (0.5212)
# Epoch: [27][100/275]	Batch Time 0.102 (0.118)	Data Load Time 0.002 (0.018)	Loss 0.4784 (0.5201)
# Epoch: [27][125/275]	Batch Time 0.090 (0.114)	Data Load Time 0.002 (0.015)	Loss 0.5222 (0.5179)
# Epoch: [27][150/275]	Batch Time 0.086 (0.112)	Data Load Time 0.002 (0.013)	Loss 0.5967 (0.5185)
# Epoch: [27][175/275]	Batch Time 0.089 (0.110)	Data Load Time 0.002 (0.011)	Loss 0.4961 (0.5182)
# Epoch: [27][200/275]	Batch Time 0.083 (0.108)	Data Load Time 0.002 (0.010)	Loss 0.4996 (0.5176)
# Epoch: [27][225/275]	Batch Time 0.115 (0.107)	Data Load Time 0.002 (0.009)	Loss 0.5233 (0.5174)
# Epoch: [27][250/275]	Batch Time 0.112 (0.106)	Data Load Time 0.002 (0.009)	Loss 0.4588 (0.5187)
#
#
# Epoch: [28][0/275]	Batch Time 1.392 (1.392)	Data Load Time 1.290 (1.290)	Loss 0.4717 (0.4717)
# Epoch: [28][25/275]	Batch Time 0.099 (0.147)	Data Load Time 0.003 (0.052)	Loss 0.5055 (0.5024)
# Epoch: [28][50/275]	Batch Time 0.118 (0.130)	Data Load Time 0.003 (0.028)	Loss 0.5408 (0.5124)
# Epoch: [28][75/275]	Batch Time 0.096 (0.127)	Data Load Time 0.003 (0.020)	Loss 0.5169 (0.5176)
# Epoch: [28][100/275]	Batch Time 0.101 (0.122)	Data Load Time 0.002 (0.016)	Loss 0.4847 (0.5151)
# Epoch: [28][125/275]	Batch Time 0.109 (0.122)	Data Load Time 0.004 (0.013)	Loss 0.5349 (0.5185)
# Epoch: [28][150/275]	Batch Time 0.111 (0.122)	Data Load Time 0.002 (0.011)	Loss 0.5330 (0.5175)
# Epoch: [28][175/275]	Batch Time 0.101 (0.120)	Data Load Time 0.003 (0.010)	Loss 0.5462 (0.5177)
# Epoch: [28][200/275]	Batch Time 0.102 (0.118)	Data Load Time 0.003 (0.009)	Loss 0.4755 (0.5202)
# Epoch: [28][225/275]	Batch Time 0.100 (0.118)	Data Load Time 0.003 (0.009)	Loss 0.4921 (0.5197)
# Epoch: [28][250/275]	Batch Time 0.121 (0.117)	Data Load Time 0.002 (0.008)	Loss 0.5476 (0.5199)
#
#
# Epoch: [29][0/275]	Batch Time 1.645 (1.645)	Data Load Time 1.543 (1.543)	Loss 0.5445 (0.5445)
# Epoch: [29][25/275]	Batch Time 0.103 (0.173)	Data Load Time 0.002 (0.062)	Loss 0.4829 (0.5139)
# Epoch: [29][50/275]	Batch Time 0.105 (0.141)	Data Load Time 0.003 (0.033)	Loss 0.5331 (0.5161)
# Epoch: [29][75/275]	Batch Time 0.106 (0.131)	Data Load Time 0.003 (0.023)	Loss 0.5124 (0.5157)
# Epoch: [29][100/275]	Batch Time 0.111 (0.126)	Data Load Time 0.002 (0.018)	Loss 0.4976 (0.5195)
# Epoch: [29][125/275]	Batch Time 0.102 (0.122)	Data Load Time 0.003 (0.015)	Loss 0.5157 (0.5186)
# Epoch: [29][150/275]	Batch Time 0.090 (0.120)	Data Load Time 0.003 (0.013)	Loss 0.4890 (0.5189)
# Epoch: [29][175/275]	Batch Time 0.086 (0.118)	Data Load Time 0.002 (0.011)	Loss 0.5400 (0.5194)
# Epoch: [29][200/275]	Batch Time 0.082 (0.114)	Data Load Time 0.002 (0.010)	Loss 0.4923 (0.5193)
# Epoch: [29][225/275]	Batch Time 0.074 (0.111)	Data Load Time 0.002 (0.009)	Loss 0.4904 (0.5181)
# Epoch: [29][250/275]	Batch Time 0.087 (0.108)	Data Load Time 0.002 (0.009)	Loss 0.5033 (0.5186)
#
#
# Epoch: [30][0/275]	Batch Time 1.239 (1.239)	Data Load Time 1.158 (1.158)	Loss 0.5379 (0.5379)
# Epoch: [30][25/275]	Batch Time 0.086 (0.129)	Data Load Time 0.002 (0.047)	Loss 0.5245 (0.5234)
# Epoch: [30][50/275]	Batch Time 0.093 (0.106)	Data Load Time 0.002 (0.025)	Loss 0.4935 (0.5152)
# Epoch: [30][75/275]	Batch Time 0.083 (0.098)	Data Load Time 0.004 (0.017)	Loss 0.5531 (0.5160)
# Epoch: [30][100/275]	Batch Time 0.109 (0.095)	Data Load Time 0.003 (0.014)	Loss 0.5443 (0.5176)
# Epoch: [30][125/275]	Batch Time 0.099 (0.095)	Data Load Time 0.002 (0.011)	Loss 0.5439 (0.5210)
# Epoch: [30][150/275]	Batch Time 0.085 (0.094)	Data Load Time 0.002 (0.010)	Loss 0.5296 (0.5211)
# Epoch: [30][175/275]	Batch Time 0.089 (0.092)	Data Load Time 0.002 (0.009)	Loss 0.5112 (0.5207)
# Epoch: [30][200/275]	Batch Time 0.107 (0.092)	Data Load Time 0.002 (0.008)	Loss 0.5469 (0.5206)
# Epoch: [30][225/275]	Batch Time 0.172 (0.097)	Data Load Time 0.005 (0.007)	Loss 0.5931 (0.5203)
# Epoch: [30][250/275]	Batch Time 0.104 (0.098)	Data Load Time 0.002 (0.007)	Loss 0.4874 (0.5185)
# Epoch: [31][0/275]	Batch Time 1.361 (1.361)	Data Load Time 1.268 (1.268)	Loss 0.4865 (0.4865)
# Epoch: [31][25/275]	Batch Time 0.084 (0.144)	Data Load Time 0.002 (0.051)	Loss 0.5313 (0.5155)
# Epoch: [31][50/275]	Batch Time 0.101 (0.120)	Data Load Time 0.004 (0.027)	Loss 0.5169 (0.5142)
# Epoch: [31][75/275]	Batch Time 0.143 (0.114)	Data Load Time 0.003 (0.019)	Loss 0.4468 (0.5146)
# Epoch: [31][100/275]	Batch Time 0.149 (0.115)	Data Load Time 0.003 (0.015)	Loss 0.5570 (0.5183)
# Epoch: [31][125/275]	Batch Time 0.092 (0.114)	Data Load Time 0.003 (0.013)	Loss 0.4445 (0.5184)
# Epoch: [31][150/275]	Batch Time 0.087 (0.111)	Data Load Time 0.002 (0.011)	Loss 0.5627 (0.5172)
# Epoch: [31][175/275]	Batch Time 0.104 (0.109)	Data Load Time 0.003 (0.010)	Loss 0.5023 (0.5171)
# Epoch: [31][200/275]	Batch Time 0.120 (0.109)	Data Load Time 0.003 (0.009)	Loss 0.5102 (0.5179)
# Epoch: [31][225/275]	Batch Time 0.122 (0.111)	Data Load Time 0.003 (0.008)	Loss 0.5154 (0.5178)
# Epoch: [31][250/275]	Batch Time 0.124 (0.111)	Data Load Time 0.003 (0.008)	Loss 0.5528 (0.5176)
#
#
# Epoch: [32][0/275]	Batch Time 1.715 (1.715)	Data Load Time 1.595 (1.595)	Loss 0.5127 (0.5127)
# Epoch: [32][25/275]	Batch Time 0.104 (0.171)	Data Load Time 0.002 (0.064)	Loss 0.5889 (0.5219)
# Epoch: [32][50/275]	Batch Time 0.100 (0.141)	Data Load Time 0.003 (0.034)	Loss 0.5081 (0.5199)
# Epoch: [32][75/275]	Batch Time 0.119 (0.131)	Data Load Time 0.004 (0.024)	Loss 0.5042 (0.5188)
# Epoch: [32][100/275]	Batch Time 0.101 (0.125)	Data Load Time 0.003 (0.019)	Loss 0.5289 (0.5174)
# Epoch: [32][125/275]	Batch Time 0.100 (0.122)	Data Load Time 0.003 (0.015)	Loss 0.4666 (0.5146)
# Epoch: [32][150/275]	Batch Time 0.101 (0.120)	Data Load Time 0.003 (0.013)	Loss 0.5528 (0.5152)
# Epoch: [32][175/275]	Batch Time 0.103 (0.119)	Data Load Time 0.003 (0.012)	Loss 0.4943 (0.5151)
# Epoch: [32][200/275]	Batch Time 0.111 (0.118)	Data Load Time 0.003 (0.011)	Loss 0.5623 (0.5168)
# Epoch: [32][225/275]	Batch Time 0.109 (0.117)	Data Load Time 0.002 (0.010)	Loss 0.4636 (0.5156)
# Epoch: [32][250/275]	Batch Time 0.102 (0.117)	Data Load Time 0.002 (0.009)	Loss 0.5399 (0.5176)
#
#
# Epoch: [33][0/275]	Batch Time 1.958 (1.958)	Data Load Time 1.861 (1.861)	Loss 0.5133 (0.5133)
# Epoch: [33][25/275]	Batch Time 0.093 (0.180)	Data Load Time 0.002 (0.074)	Loss 0.5579 (0.5220)
# Epoch: [33][50/275]	Batch Time 0.103 (0.140)	Data Load Time 0.002 (0.039)	Loss 0.5612 (0.5194)
# Epoch: [33][75/275]	Batch Time 0.097 (0.132)	Data Load Time 0.002 (0.027)	Loss 0.4421 (0.5208)
# Epoch: [33][100/275]	Batch Time 0.103 (0.124)	Data Load Time 0.003 (0.021)	Loss 0.4720 (0.5192)
# Epoch: [33][125/275]	Batch Time 0.080 (0.117)	Data Load Time 0.003 (0.017)	Loss 0.4502 (0.5197)
# Epoch: [33][150/275]	Batch Time 0.087 (0.112)	Data Load Time 0.003 (0.015)	Loss 0.5593 (0.5207)
# Epoch: [33][175/275]	Batch Time 0.104 (0.109)	Data Load Time 0.002 (0.013)	Loss 0.4788 (0.5186)
# Epoch: [33][200/275]	Batch Time 0.100 (0.106)	Data Load Time 0.003 (0.012)	Loss 0.4550 (0.5161)
# Epoch: [33][225/275]	Batch Time 0.096 (0.104)	Data Load Time 0.003 (0.011)	Loss 0.5022 (0.5159)
# Epoch: [33][250/275]	Batch Time 0.087 (0.103)	Data Load Time 0.003 (0.010)	Loss 0.5478 (0.5166)
#
#
# Epoch: [34][0/275]	Batch Time 1.277 (1.277)	Data Load Time 1.190 (1.190)	Loss 0.5690 (0.5690)
# Epoch: [34][25/275]	Batch Time 0.085 (0.135)	Data Load Time 0.003 (0.048)	Loss 0.5052 (0.5225)
# Epoch: [34][50/275]	Batch Time 0.094 (0.114)	Data Load Time 0.002 (0.026)	Loss 0.5281 (0.5173)
# Epoch: [34][75/275]	Batch Time 0.084 (0.106)	Data Load Time 0.002 (0.018)	Loss 0.5168 (0.5217)
# Epoch: [34][100/275]	Batch Time 0.133 (0.103)	Data Load Time 0.003 (0.014)	Loss 0.4803 (0.5225)
# Epoch: [34][125/275]	Batch Time 0.085 (0.101)	Data Load Time 0.003 (0.012)	Loss 0.5114 (0.5214)
# Epoch: [34][150/275]	Batch Time 0.139 (0.102)	Data Load Time 0.002 (0.010)	Loss 0.4971 (0.5197)
# Epoch: [34][175/275]	Batch Time 0.127 (0.104)	Data Load Time 0.003 (0.009)	Loss 0.4863 (0.5195)
# Epoch: [34][200/275]	Batch Time 0.119 (0.106)	Data Load Time 0.003 (0.008)	Loss 0.5660 (0.5191)
# Epoch: [34][225/275]	Batch Time 0.115 (0.107)	Data Load Time 0.003 (0.008)	Loss 0.5268 (0.5186)
# Epoch: [34][250/275]	Batch Time 0.120 (0.109)	Data Load Time 0.002 (0.007)	Loss 0.5070 (0.5185)
#
#
# Epoch: [35][0/275]	Batch Time 1.721 (1.721)	Data Load Time 1.600 (1.600)	Loss 0.4953 (0.4953)
# Epoch: [35][25/275]	Batch Time 0.114 (0.171)	Data Load Time 0.003 (0.064)	Loss 0.5237 (0.5038)
# Epoch: [35][50/275]	Batch Time 0.105 (0.142)	Data Load Time 0.003 (0.034)	Loss 0.5673 (0.5103)
# Epoch: [35][75/275]	Batch Time 0.105 (0.134)	Data Load Time 0.002 (0.024)	Loss 0.5174 (0.5154)
# Epoch: [35][100/275]	Batch Time 0.104 (0.129)	Data Load Time 0.003 (0.019)	Loss 0.4881 (0.5150)
# Epoch: [35][125/275]	Batch Time 0.107 (0.125)	Data Load Time 0.003 (0.016)	Loss 0.4565 (0.5141)
# Epoch: [35][150/275]	Batch Time 0.110 (0.122)	Data Load Time 0.003 (0.013)	Loss 0.5771 (0.5158)
# Epoch: [35][175/275]	Batch Time 0.108 (0.121)	Data Load Time 0.003 (0.012)	Loss 0.5116 (0.5164)
# Epoch: [35][200/275]	Batch Time 0.105 (0.120)	Data Load Time 0.002 (0.011)	Loss 0.5374 (0.5164)
# Epoch: [35][225/275]	Batch Time 0.117 (0.119)	Data Load Time 0.003 (0.010)	Loss 0.4604 (0.5165)
# Epoch: [35][250/275]	Batch Time 0.124 (0.118)	Data Load Time 0.003 (0.009)	Loss 0.4674 (0.5169)
#
#
# Epoch: [36][0/275]	Batch Time 1.742 (1.742)	Data Load Time 1.615 (1.615)	Loss 0.5044 (0.5044)
# Epoch: [36][25/275]	Batch Time 0.105 (0.170)	Data Load Time 0.002 (0.065)	Loss 0.4899 (0.5157)
# Epoch: [36][50/275]	Batch Time 0.107 (0.141)	Data Load Time 0.002 (0.034)	Loss 0.4868 (0.5183)
# Epoch: [36][75/275]	Batch Time 0.101 (0.130)	Data Load Time 0.003 (0.024)	Loss 0.4946 (0.5175)
# Epoch: [36][100/275]	Batch Time 0.121 (0.125)	Data Load Time 0.003 (0.019)	Loss 0.4495 (0.5174)
# Epoch: [36][125/275]	Batch Time 0.126 (0.123)	Data Load Time 0.003 (0.016)	Loss 0.4904 (0.5164)
# Epoch: [36][150/275]	Batch Time 0.120 (0.121)	Data Load Time 0.002 (0.013)	Loss 0.5190 (0.5155)
# Epoch: [36][175/275]	Batch Time 0.130 (0.120)	Data Load Time 0.002 (0.012)	Loss 0.5235 (0.5146)
# Epoch: [36][200/275]	Batch Time 0.112 (0.119)	Data Load Time 0.003 (0.011)	Loss 0.5049 (0.5149)
# Epoch: [36][225/275]	Batch Time 0.107 (0.119)	Data Load Time 0.003 (0.010)	Loss 0.5329 (0.5155)
# Epoch: [36][250/275]	Batch Time 0.102 (0.118)	Data Load Time 0.003 (0.009)	Loss 0.4817 (0.5164)
#
#
# Epoch: [37][0/275]	Batch Time 1.701 (1.701)	Data Load Time 1.599 (1.599)	Loss 0.5431 (0.5431)
# Epoch: [37][25/275]	Batch Time 0.107 (0.172)	Data Load Time 0.004 (0.064)	Loss 0.4547 (0.5086)
# Epoch: [37][50/275]	Batch Time 0.115 (0.143)	Data Load Time 0.003 (0.034)	Loss 0.4868 (0.5150)
# Epoch: [37][75/275]	Batch Time 0.101 (0.132)	Data Load Time 0.002 (0.024)	Loss 0.4790 (0.5152)
# Epoch: [37][100/275]	Batch Time 0.103 (0.127)	Data Load Time 0.002 (0.019)	Loss 0.6008 (0.5173)
# Epoch: [37][125/275]	Batch Time 0.112 (0.123)	Data Load Time 0.004 (0.016)	Loss 0.5685 (0.5181)
# Epoch: [37][150/275]	Batch Time 0.112 (0.122)	Data Load Time 0.003 (0.013)	Loss 0.5150 (0.5164)
# Epoch: [37][175/275]	Batch Time 0.103 (0.121)	Data Load Time 0.003 (0.012)	Loss 0.5270 (0.5156)
# Epoch: [37][200/275]	Batch Time 0.129 (0.120)	Data Load Time 0.002 (0.011)	Loss 0.5531 (0.5156)
# Epoch: [37][225/275]	Batch Time 0.102 (0.119)	Data Load Time 0.003 (0.010)	Loss 0.5782 (0.5156)
# Epoch: [37][250/275]	Batch Time 0.104 (0.118)	Data Load Time 0.003 (0.009)	Loss 0.4887 (0.5166)
#
#
# Epoch: [38][0/275]	Batch Time 1.708 (1.708)	Data Load Time 1.608 (1.608)	Loss 0.4988 (0.4988)
# Epoch: [38][25/275]	Batch Time 0.081 (0.162)	Data Load Time 0.002 (0.064)	Loss 0.5270 (0.5146)
# Epoch: [38][50/275]	Batch Time 0.166 (0.138)	Data Load Time 0.005 (0.034)	Loss 0.5391 (0.5119)
# Epoch: [38][75/275]	Batch Time 0.108 (0.131)	Data Load Time 0.003 (0.024)	Loss 0.4864 (0.5177)
# Epoch: [38][100/275]	Batch Time 0.107 (0.125)	Data Load Time 0.002 (0.019)	Loss 0.5103 (0.5174)
# Epoch: [38][125/275]	Batch Time 0.109 (0.122)	Data Load Time 0.002 (0.016)	Loss 0.5362 (0.5152)
# Epoch: [38][150/275]	Batch Time 0.110 (0.120)	Data Load Time 0.003 (0.013)	Loss 0.5081 (0.5171)
# Epoch: [38][175/275]	Batch Time 0.117 (0.119)	Data Load Time 0.002 (0.012)	Loss 0.4951 (0.5164)
# Epoch: [38][200/275]	Batch Time 0.129 (0.118)	Data Load Time 0.003 (0.011)	Loss 0.4949 (0.5162)
# Epoch: [38][225/275]	Batch Time 0.103 (0.118)	Data Load Time 0.003 (0.010)	Loss 0.5760 (0.5149)
# Epoch: [38][250/275]	Batch Time 0.102 (0.117)	Data Load Time 0.003 (0.009)	Loss 0.5148 (0.5157)
#
#
# Epoch: [39][0/275]	Batch Time 1.729 (1.729)	Data Load Time 1.624 (1.624)	Loss 0.5487 (0.5487)
# Epoch: [39][25/275]	Batch Time 0.110 (0.177)	Data Load Time 0.003 (0.065)	Loss 0.5449 (0.5223)
# Epoch: [39][50/275]	Batch Time 0.138 (0.147)	Data Load Time 0.003 (0.035)	Loss 0.5203 (0.5170)
# Epoch: [39][75/275]	Batch Time 0.134 (0.136)	Data Load Time 0.003 (0.024)	Loss 0.4967 (0.5129)
# Epoch: [39][100/275]	Batch Time 0.114 (0.131)	Data Load Time 0.003 (0.019)	Loss 0.5561 (0.5134)
# Epoch: [39][125/275]	Batch Time 0.107 (0.127)	Data Load Time 0.002 (0.016)	Loss 0.5021 (0.5120)
# Epoch: [39][150/275]	Batch Time 0.115 (0.124)	Data Load Time 0.002 (0.014)	Loss 0.5328 (0.5122)
# Epoch: [39][175/275]	Batch Time 0.148 (0.123)	Data Load Time 0.004 (0.012)	Loss 0.5097 (0.5140)
# Epoch: [39][200/275]	Batch Time 0.090 (0.120)	Data Load Time 0.002 (0.011)	Loss 0.4970 (0.5146)
# Epoch: [39][225/275]	Batch Time 0.127 (0.121)	Data Load Time 0.004 (0.010)	Loss 0.5513 (0.5152)
# Epoch: [39][250/275]	Batch Time 0.134 (0.120)	Data Load Time 0.003 (0.009)	Loss 0.5165 (0.5147)
#
#
# Epoch: [40][0/275]	Batch Time 1.665 (1.665)	Data Load Time 1.549 (1.549)	Loss 0.5601 (0.5601)
# Epoch: [40][25/275]	Batch Time 0.102 (0.169)	Data Load Time 0.003 (0.062)	Loss 0.5072 (0.5210)
# Epoch: [40][50/275]	Batch Time 0.139 (0.144)	Data Load Time 0.004 (0.033)	Loss 0.4748 (0.5168)
# Epoch: [40][75/275]	Batch Time 0.111 (0.135)	Data Load Time 0.002 (0.023)	Loss 0.5082 (0.5146)
# Epoch: [40][100/275]	Batch Time 0.106 (0.129)	Data Load Time 0.003 (0.018)	Loss 0.5482 (0.5171)
# Epoch: [40][125/275]	Batch Time 0.101 (0.126)	Data Load Time 0.003 (0.015)	Loss 0.5539 (0.5171)
# Epoch: [40][150/275]	Batch Time 0.118 (0.124)	Data Load Time 0.003 (0.013)	Loss 0.5582 (0.5169)
# Epoch: [40][175/275]	Batch Time 0.104 (0.122)	Data Load Time 0.003 (0.012)	Loss 0.5290 (0.5158)
# Epoch: [40][200/275]	Batch Time 0.105 (0.120)	Data Load Time 0.003 (0.011)	Loss 0.5068 (0.5152)
# Epoch: [40][225/275]	Batch Time 0.105 (0.120)	Data Load Time 0.003 (0.010)	Loss 0.4979 (0.5153)
# Epoch: [40][250/275]	Batch Time 0.101 (0.119)	Data Load Time 0.003 (0.009)	Loss 0.4812 (0.5153)
#
#
# Epoch: [41][0/275]	Batch Time 1.648 (1.648)	Data Load Time 1.546 (1.546)	Loss 0.5650 (0.5650)
# Epoch: [41][25/275]	Batch Time 0.115 (0.170)	Data Load Time 0.003 (0.062)	Loss 0.6067 (0.5221)
# Epoch: [41][50/275]	Batch Time 0.110 (0.141)	Data Load Time 0.003 (0.033)	Loss 0.4735 (0.5171)
# Epoch: [41][75/275]	Batch Time 0.104 (0.133)	Data Load Time 0.002 (0.023)	Loss 0.5311 (0.5187)
# Epoch: [41][100/275]	Batch Time 0.087 (0.125)	Data Load Time 0.002 (0.018)	Loss 0.4847 (0.5169)
# Epoch: [41][125/275]	Batch Time 0.098 (0.122)	Data Load Time 0.002 (0.015)	Loss 0.4657 (0.5146)
# Epoch: [41][150/275]	Batch Time 0.111 (0.120)	Data Load Time 0.002 (0.013)	Loss 0.5425 (0.5146)
# Epoch: [41][175/275]	Batch Time 0.108 (0.118)	Data Load Time 0.003 (0.011)	Loss 0.4870 (0.5133)
# Epoch: [41][200/275]	Batch Time 0.109 (0.118)	Data Load Time 0.002 (0.010)	Loss 0.4736 (0.5127)
# Epoch: [41][225/275]	Batch Time 0.106 (0.116)	Data Load Time 0.003 (0.010)	Loss 0.5427 (0.5135)
# Epoch: [41][250/275]	Batch Time 0.126 (0.116)	Data Load Time 0.003 (0.009)	Loss 0.5182 (0.5132)
#
#
# Epoch: [42][0/275]	Batch Time 2.086 (2.086)	Data Load Time 1.967 (1.967)	Loss 0.5486 (0.5486)
# Epoch: [42][25/275]	Batch Time 0.100 (0.189)	Data Load Time 0.003 (0.078)	Loss 0.5231 (0.5119)
# Epoch: [42][50/275]	Batch Time 0.098 (0.150)	Data Load Time 0.002 (0.041)	Loss 0.5237 (0.5183)
# Epoch: [42][75/275]	Batch Time 0.106 (0.136)	Data Load Time 0.004 (0.029)	Loss 0.5114 (0.5174)
# Epoch: [42][100/275]	Batch Time 0.120 (0.130)	Data Load Time 0.003 (0.022)	Loss 0.5295 (0.5196)
# Epoch: [42][125/275]	Batch Time 0.108 (0.126)	Data Load Time 0.002 (0.018)	Loss 0.5687 (0.5162)
# Epoch: [42][150/275]	Batch Time 0.113 (0.124)	Data Load Time 0.003 (0.016)	Loss 0.4999 (0.5169)
# Epoch: [42][175/275]	Batch Time 0.107 (0.122)	Data Load Time 0.002 (0.014)	Loss 0.5267 (0.5160)
# Epoch: [42][200/275]	Batch Time 0.122 (0.121)	Data Load Time 0.002 (0.013)	Loss 0.5228 (0.5159)
# Epoch: [42][225/275]	Batch Time 0.102 (0.120)	Data Load Time 0.003 (0.011)	Loss 0.4658 (0.5153)
# Epoch: [42][250/275]	Batch Time 0.134 (0.119)	Data Load Time 0.003 (0.011)	Loss 0.5429 (0.5138)
#
#
# Epoch: [43][0/275]	Batch Time 1.704 (1.704)	Data Load Time 1.586 (1.586)	Loss 0.5325 (0.5325)
# Epoch: [43][25/275]	Batch Time 0.113 (0.173)	Data Load Time 0.003 (0.064)	Loss 0.4980 (0.5104)
# Epoch: [43][50/275]	Batch Time 0.107 (0.142)	Data Load Time 0.003 (0.034)	Loss 0.5459 (0.5081)
# Epoch: [43][75/275]	Batch Time 0.104 (0.131)	Data Load Time 0.003 (0.024)	Loss 0.4705 (0.5082)
# Epoch: [43][100/275]	Batch Time 0.106 (0.127)	Data Load Time 0.004 (0.018)	Loss 0.4934 (0.5126)
# Epoch: [43][125/275]	Batch Time 0.109 (0.124)	Data Load Time 0.003 (0.015)	Loss 0.5065 (0.5127)
# Epoch: [43][150/275]	Batch Time 0.107 (0.121)	Data Load Time 0.003 (0.013)	Loss 0.5194 (0.5154)
# Epoch: [43][175/275]	Batch Time 0.105 (0.120)	Data Load Time 0.002 (0.012)	Loss 0.5051 (0.5140)
# Epoch: [43][200/275]	Batch Time 0.114 (0.119)	Data Load Time 0.003 (0.011)	Loss 0.5213 (0.5142)
# Epoch: [43][225/275]	Batch Time 0.103 (0.118)	Data Load Time 0.002 (0.010)	Loss 0.5287 (0.5149)
# Epoch: [43][250/275]	Batch Time 0.107 (0.117)	Data Load Time 0.003 (0.009)	Loss 0.4786 (0.5149)
#
#
# Epoch: [44][0/275]	Batch Time 1.699 (1.699)	Data Load Time 1.575 (1.575)	Loss 0.6173 (0.6173)
# Epoch: [44][25/275]	Batch Time 0.104 (0.170)	Data Load Time 0.003 (0.063)	Loss 0.4893 (0.5020)
# Epoch: [44][50/275]	Batch Time 0.105 (0.141)	Data Load Time 0.003 (0.034)	Loss 0.5059 (0.5075)
# Epoch: [44][75/275]	Batch Time 0.107 (0.132)	Data Load Time 0.002 (0.023)	Loss 0.4686 (0.5099)
# Epoch: [44][100/275]	Batch Time 0.097 (0.126)	Data Load Time 0.003 (0.018)	Loss 0.4778 (0.5067)
# Epoch: [44][125/275]	Batch Time 0.109 (0.123)	Data Load Time 0.003 (0.015)	Loss 0.4669 (0.5089)
# Epoch: [44][150/275]	Batch Time 0.114 (0.122)	Data Load Time 0.003 (0.013)	Loss 0.5069 (0.5105)
# Epoch: [44][175/275]	Batch Time 0.111 (0.121)	Data Load Time 0.004 (0.012)	Loss 0.4794 (0.5112)
# Epoch: [44][200/275]	Batch Time 0.118 (0.120)	Data Load Time 0.003 (0.011)	Loss 0.5644 (0.5111)
# Epoch: [44][225/275]	Batch Time 0.134 (0.119)	Data Load Time 0.002 (0.010)	Loss 0.5328 (0.5131)
# Epoch: [44][250/275]	Batch Time 0.082 (0.117)	Data Load Time 0.003 (0.009)	Loss 0.5329 (0.5130)
#
#
# Epoch: [45][0/275]	Batch Time 1.290 (1.290)	Data Load Time 1.198 (1.198)	Loss 0.5494 (0.5494)
# Epoch: [45][25/275]	Batch Time 0.096 (0.131)	Data Load Time 0.002 (0.048)	Loss 0.5197 (0.5194)
# ...
#
#
# Epoch: [85][0/275]	Batch Time 1.727 (1.727)	Data Load Time 1.614 (1.614)	Loss 0.4918 (0.4918)
# Epoch: [85][25/275]	Batch Time 0.113 (0.179)	Data Load Time 0.003 (0.065)	Loss 0.4585 (0.4939)
# Epoch: [85][50/275]	Batch Time 0.110 (0.152)	Data Load Time 0.003 (0.034)	Loss 0.5154 (0.5001)
# Epoch: [85][75/275]	Batch Time 0.133 (0.141)	Data Load Time 0.003 (0.024)	Loss 0.5669 (0.4999)
# Epoch: [85][100/275]	Batch Time 0.140 (0.138)	Data Load Time 0.002 (0.019)	Loss 0.4805 (0.5017)
# Epoch: [85][125/275]	Batch Time 0.104 (0.134)	Data Load Time 0.002 (0.016)	Loss 0.5320 (0.5027)
# Epoch: [85][150/275]	Batch Time 0.104 (0.131)	Data Load Time 0.003 (0.014)	Loss 0.4786 (0.5034)
# Epoch: [85][175/275]	Batch Time 0.123 (0.130)	Data Load Time 0.003 (0.012)	Loss 0.4907 (0.5032)
# Epoch: [85][200/275]	Batch Time 0.156 (0.129)	Data Load Time 0.003 (0.011)	Loss 0.4505 (0.5038)
# Epoch: [85][225/275]	Batch Time 0.143 (0.129)	Data Load Time 0.003 (0.010)	Loss 0.5179 (0.5026)
# Epoch: [85][250/275]	Batch Time 0.126 (0.128)	Data Load Time 0.003 (0.009)	Loss 0.5432 (0.5029)
#
#
# Epoch: [86][0/275]	Batch Time 1.774 (1.774)	Data Load Time 1.645 (1.645)	Loss 0.5315 (0.5315)
# Epoch: [86][25/275]	Batch Time 0.118 (0.187)	Data Load Time 0.002 (0.066)	Loss 0.5189 (0.5001)
# Epoch: [86][50/275]	Batch Time 0.147 (0.160)	Data Load Time 0.003 (0.036)	Loss 0.5626 (0.4975)
# Epoch: [86][75/275]	Batch Time 0.133 (0.145)	Data Load Time 0.003 (0.025)	Loss 0.4387 (0.5009)
# Epoch: [86][100/275]	Batch Time 0.127 (0.141)	Data Load Time 0.004 (0.019)	Loss 0.5275 (0.5030)
# Epoch: [86][125/275]	Batch Time 0.118 (0.138)	Data Load Time 0.003 (0.016)	Loss 0.5577 (0.5033)
# Epoch: [86][150/275]	Batch Time 0.169 (0.136)	Data Load Time 0.004 (0.014)	Loss 0.5555 (0.5047)
# Epoch: [86][175/275]	Batch Time 0.124 (0.135)	Data Load Time 0.003 (0.013)	Loss 0.5692 (0.5046)
# Epoch: [86][200/275]	Batch Time 0.113 (0.133)	Data Load Time 0.006 (0.011)	Loss 0.4502 (0.5045)
# Epoch: [86][225/275]	Batch Time 0.155 (0.132)	Data Load Time 0.005 (0.010)	Loss 0.4680 (0.5037)
# Epoch: [86][250/275]	Batch Time 0.128 (0.131)	Data Load Time 0.003 (0.010)	Loss 0.4880 (0.5033)
#
#
# Epoch: [87][0/275]	Batch Time 1.676 (1.676)	Data Load Time 1.545 (1.545)	Loss 0.5129 (0.5129)
# Epoch: [87][25/275]	Batch Time 0.118 (0.171)	Data Load Time 0.003 (0.062)	Loss 0.4847 (0.5033)
# Epoch: [87][50/275]	Batch Time 0.111 (0.139)	Data Load Time 0.002 (0.033)	Loss 0.4765 (0.5070)
# Epoch: [87][75/275]	Batch Time 0.142 (0.135)	Data Load Time 0.004 (0.023)	Loss 0.5425 (0.5036)
# Epoch: [87][100/275]	Batch Time 0.108 (0.129)	Data Load Time 0.002 (0.018)	Loss 0.4951 (0.5006)
# Epoch: [87][125/275]	Batch Time 0.093 (0.125)	Data Load Time 0.002 (0.015)	Loss 0.4938 (0.5021)
# Epoch: [87][150/275]	Batch Time 0.095 (0.122)	Data Load Time 0.002 (0.013)	Loss 0.5178 (0.5020)
# Epoch: [87][175/275]	Batch Time 0.111 (0.120)	Data Load Time 0.003 (0.012)	Loss 0.4791 (0.5027)
# Epoch: [87][200/275]	Batch Time 0.096 (0.120)	Data Load Time 0.002 (0.010)	Loss 0.4833 (0.5030)
# Epoch: [87][225/275]	Batch Time 0.106 (0.118)	Data Load Time 0.002 (0.010)	Loss 0.4802 (0.5042)
# Epoch: [87][250/275]	Batch Time 0.100 (0.117)	Data Load Time 0.002 (0.009)	Loss 0.5793 (0.5043)
#
#
# Epoch: [88][0/275]	Batch Time 1.397 (1.397)	Data Load Time 1.288 (1.288)	Loss 0.4715 (0.4715)
# Epoch: [88][25/275]	Batch Time 0.096 (0.147)	Data Load Time 0.003 (0.052)	Loss 0.5635 (0.5038)
# Epoch: [88][50/275]	Batch Time 0.099 (0.122)	Data Load Time 0.002 (0.028)	Loss 0.4794 (0.5074)
# Epoch: [88][75/275]	Batch Time 0.092 (0.115)	Data Load Time 0.003 (0.019)	Loss 0.5838 (0.5059)
# Epoch: [88][100/275]	Batch Time 0.101 (0.111)	Data Load Time 0.002 (0.015)	Loss 0.4797 (0.5050)
# Epoch: [88][125/275]	Batch Time 0.088 (0.108)	Data Load Time 0.002 (0.013)	Loss 0.5260 (0.5055)
# Epoch: [88][150/275]	Batch Time 0.089 (0.107)	Data Load Time 0.002 (0.011)	Loss 0.5030 (0.5063)
# Epoch: [88][175/275]	Batch Time 0.111 (0.106)	Data Load Time 0.002 (0.010)	Loss 0.4914 (0.5071)
# Epoch: [88][200/275]	Batch Time 0.108 (0.106)	Data Load Time 0.002 (0.009)	Loss 0.4988 (0.5060)
# Epoch: [88][225/275]	Batch Time 0.091 (0.106)	Data Load Time 0.003 (0.008)	Loss 0.4868 (0.5051)
# Epoch: [88][250/275]	Batch Time 0.110 (0.106)	Data Load Time 0.002 (0.008)	Loss 0.5033 (0.5050)
#
#
# Epoch: [89][0/275]	Batch Time 1.457 (1.457)	Data Load Time 1.362 (1.362)	Loss 0.5263 (0.5263)
# Epoch: [89][25/275]	Batch Time 0.100 (0.156)	Data Load Time 0.002 (0.055)	Loss 0.5151 (0.5082)
# Epoch: [89][50/275]	Batch Time 0.099 (0.128)	Data Load Time 0.003 (0.029)	Loss 0.4818 (0.5047)
# Epoch: [89][75/275]	Batch Time 0.100 (0.122)	Data Load Time 0.003 (0.020)	Loss 0.4630 (0.5059)
# Epoch: [89][100/275]	Batch Time 0.112 (0.118)	Data Load Time 0.002 (0.016)	Loss 0.5123 (0.5011)
# Epoch: [89][125/275]	Batch Time 0.133 (0.117)	Data Load Time 0.003 (0.013)	Loss 0.5167 (0.4999)
# Epoch: [89][150/275]	Batch Time 0.100 (0.115)	Data Load Time 0.002 (0.012)	Loss 0.5889 (0.5003)
# Epoch: [89][175/275]	Batch Time 0.090 (0.112)	Data Load Time 0.002 (0.010)	Loss 0.5189 (0.5020)
# Epoch: [89][200/275]	Batch Time 0.102 (0.110)	Data Load Time 0.002 (0.009)	Loss 0.4516 (0.5024)
# Epoch: [89][225/275]	Batch Time 0.086 (0.108)	Data Load Time 0.003 (0.009)	Loss 0.5626 (0.5029)
# Epoch: [89][250/275]	Batch Time 0.091 (0.106)	Data Load Time 0.002 (0.008)	Loss 0.4895 (0.5041)
#
#
# Epoch: [90][0/275]	Batch Time 1.447 (1.447)	Data Load Time 1.357 (1.357)	Loss 0.5252 (0.5252)
# Epoch: [90][25/275]	Batch Time 0.096 (0.153)	Data Load Time 0.002 (0.055)	Loss 0.5199 (0.5107)
# Epoch: [90][50/275]	Batch Time 0.103 (0.128)	Data Load Time 0.002 (0.029)	Loss 0.5080 (0.5116)
# Epoch: [90][75/275]	Batch Time 0.120 (0.121)	Data Load Time 0.003 (0.020)	Loss 0.4909 (0.5090)
# Epoch: [90][100/275]	Batch Time 0.095 (0.115)	Data Load Time 0.003 (0.016)	Loss 0.5560 (0.5074)
# Epoch: [90][125/275]	Batch Time 0.098 (0.111)	Data Load Time 0.002 (0.013)	Loss 0.4961 (0.5037)
# Epoch: [90][150/275]	Batch Time 0.093 (0.108)	Data Load Time 0.003 (0.011)	Loss 0.5313 (0.5055)
# Epoch: [90][175/275]	Batch Time 0.088 (0.106)	Data Load Time 0.002 (0.010)	Loss 0.5056 (0.5044)
# Epoch: [90][200/275]	Batch Time 0.093 (0.105)	Data Load Time 0.002 (0.009)	Loss 0.4890 (0.5041)
# Epoch: [90][225/275]	Batch Time 0.090 (0.103)	Data Load Time 0.003 (0.008)	Loss 0.4739 (0.5036)
# Epoch: [90][250/275]	Batch Time 0.103 (0.103)	Data Load Time 0.003 (0.008)	Loss 0.4836 (0.5041)
#
#
# Epoch: [91][0/275]	Batch Time 1.744 (1.744)	Data Load Time 1.616 (1.616)	Loss 0.4617 (0.4617)
# Epoch: [91][25/275]	Batch Time 0.119 (0.179)	Data Load Time 0.003 (0.065)	Loss 0.4273 (0.4779)
# Epoch: [91][50/275]	Batch Time 0.115 (0.140)	Data Load Time 0.003 (0.034)	Loss 0.4539 (0.4839)
# Epoch: [91][75/275]	Batch Time 0.090 (0.125)	Data Load Time 0.002 (0.024)	Loss 0.5050 (0.4927)
# Epoch: [91][100/275]	Batch Time 0.092 (0.117)	Data Load Time 0.002 (0.018)	Loss 0.4220 (0.4949)
# Epoch: [91][125/275]	Batch Time 0.090 (0.112)	Data Load Time 0.002 (0.015)	Loss 0.5984 (0.4996)
# Epoch: [91][150/275]	Batch Time 0.098 (0.109)	Data Load Time 0.002 (0.013)	Loss 0.4917 (0.5000)
# Epoch: [91][175/275]	Batch Time 0.113 (0.107)	Data Load Time 0.003 (0.012)	Loss 0.5207 (0.5013)
# Epoch: [91][200/275]	Batch Time 0.101 (0.107)	Data Load Time 0.002 (0.011)	Loss 0.5110 (0.5022)
# Epoch: [91][225/275]	Batch Time 0.101 (0.107)	Data Load Time 0.003 (0.010)	Loss 0.5312 (0.5015)
# Epoch: [91][250/275]	Batch Time 0.103 (0.107)	Data Load Time 0.002 (0.009)	Loss 0.4983 (0.5025)
#
#
# Epoch: [92][0/275]	Batch Time 1.374 (1.374)	Data Load Time 1.271 (1.271)	Loss 0.4983 (0.4983)
# Epoch: [92][25/275]	Batch Time 0.112 (0.151)	Data Load Time 0.003 (0.051)	Loss 0.5071 (0.5043)
# Epoch: [92][50/275]	Batch Time 0.094 (0.126)	Data Load Time 0.002 (0.027)	Loss 0.5609 (0.5064)
# Epoch: [92][75/275]	Batch Time 0.093 (0.116)	Data Load Time 0.003 (0.019)	Loss 0.5439 (0.5084)
# Epoch: [92][100/275]	Batch Time 0.096 (0.113)	Data Load Time 0.003 (0.015)	Loss 0.5273 (0.5072)
# Epoch: [92][125/275]	Batch Time 0.109 (0.111)	Data Load Time 0.002 (0.013)	Loss 0.5259 (0.5048)
# Epoch: [92][150/275]	Batch Time 0.096 (0.110)	Data Load Time 0.003 (0.011)	Loss 0.4817 (0.5039)
# Epoch: [92][175/275]	Batch Time 0.106 (0.110)	Data Load Time 0.002 (0.010)	Loss 0.5268 (0.5037)
# Epoch: [92][200/275]	Batch Time 0.092 (0.109)	Data Load Time 0.002 (0.009)	Loss 0.4287 (0.5034)
# Epoch: [92][225/275]	Batch Time 0.099 (0.108)	Data Load Time 0.002 (0.008)	Loss 0.5242 (0.5041)
# Epoch: [92][250/275]	Batch Time 0.101 (0.106)	Data Load Time 0.002 (0.008)	Loss 0.4714 (0.5043)
#
#
# Epoch: [93][0/275]	Batch Time 1.436 (1.436)	Data Load Time 1.346 (1.346)	Loss 0.4871 (0.4871)
# Epoch: [93][25/275]	Batch Time 0.083 (0.139)	Data Load Time 0.002 (0.054)	Loss 0.4741 (0.4957)
# Epoch: [93][50/275]	Batch Time 0.099 (0.117)	Data Load Time 0.002 (0.029)	Loss 0.4936 (0.5037)
# Epoch: [93][75/275]	Batch Time 0.090 (0.110)	Data Load Time 0.002 (0.020)	Loss 0.5395 (0.5051)
# Epoch: [93][100/275]	Batch Time 0.117 (0.109)	Data Load Time 0.003 (0.016)	Loss 0.5424 (0.5036)
# Epoch: [93][125/275]	Batch Time 0.118 (0.109)	Data Load Time 0.003 (0.013)	Loss 0.5254 (0.5031)
# Epoch: [93][150/275]	Batch Time 0.103 (0.109)	Data Load Time 0.003 (0.011)	Loss 0.4895 (0.5037)
# Epoch: [93][175/275]	Batch Time 0.109 (0.108)	Data Load Time 0.002 (0.010)	Loss 0.4570 (0.5038)
# Epoch: [93][200/275]	Batch Time 0.081 (0.107)	Data Load Time 0.002 (0.009)	Loss 0.5228 (0.5021)
# Epoch: [93][225/275]	Batch Time 0.106 (0.106)	Data Load Time 0.003 (0.008)	Loss 0.5031 (0.5029)
# Epoch: [93][250/275]	Batch Time 0.095 (0.105)	Data Load Time 0.002 (0.008)	Loss 0.4995 (0.5023)
#
#
# Epoch: [94][0/275]	Batch Time 1.417 (1.417)	Data Load Time 1.300 (1.300)	Loss 0.4951 (0.4951)
# Epoch: [94][25/275]	Batch Time 0.102 (0.146)	Data Load Time 0.003 (0.052)	Loss 0.5286 (0.4917)
# Epoch: [94][50/275]	Batch Time 0.114 (0.125)	Data Load Time 0.002 (0.028)	Loss 0.5223 (0.5003)
# Epoch: [94][75/275]	Batch Time 0.099 (0.117)	Data Load Time 0.003 (0.020)	Loss 0.5384 (0.5012)
# Epoch: [94][100/275]	Batch Time 0.122 (0.114)	Data Load Time 0.003 (0.015)	Loss 0.4916 (0.5004)
# Epoch: [94][125/275]	Batch Time 0.113 (0.112)	Data Load Time 0.003 (0.013)	Loss 0.4933 (0.5019)
# Epoch: [94][150/275]	Batch Time 0.095 (0.110)	Data Load Time 0.003 (0.011)	Loss 0.4882 (0.5021)
# Epoch: [94][175/275]	Batch Time 0.112 (0.108)	Data Load Time 0.002 (0.010)	Loss 0.5216 (0.5031)
# Epoch: [94][200/275]	Batch Time 0.093 (0.107)	Data Load Time 0.003 (0.009)	Loss 0.4933 (0.5024)
# Epoch: [94][225/275]	Batch Time 0.094 (0.106)	Data Load Time 0.002 (0.008)	Loss 0.5909 (0.5020)
# Epoch: [94][250/275]	Batch Time 0.092 (0.105)	Data Load Time 0.002 (0.008)	Loss 0.5163 (0.5033)
#
#
# Epoch: [95][0/275]	Batch Time 1.436 (1.436)	Data Load Time 1.335 (1.335)	Loss 0.4770 (0.4770)
# Epoch: [95][25/275]	Batch Time 0.109 (0.161)	Data Load Time 0.002 (0.054)	Loss 0.5471 (0.5075)
# Epoch: [95][50/275]	Batch Time 0.117 (0.137)	Data Load Time 0.002 (0.029)	Loss 0.5451 (0.5078)
# Epoch: [95][75/275]	Batch Time 0.113 (0.127)	Data Load Time 0.003 (0.020)	Loss 0.4895 (0.5066)
# Epoch: [95][100/275]	Batch Time 0.099 (0.121)	Data Load Time 0.002 (0.016)	Loss 0.5137 (0.5029)
# Epoch: [95][125/275]	Batch Time 0.103 (0.117)	Data Load Time 0.002 (0.013)	Loss 0.4994 (0.5025)
# Epoch: [95][150/275]	Batch Time 0.087 (0.114)	Data Load Time 0.003 (0.011)	Loss 0.5075 (0.5019)
# Epoch: [95][175/275]	Batch Time 0.090 (0.112)	Data Load Time 0.003 (0.010)	Loss 0.5039 (0.5036)
# Epoch: [95][200/275]	Batch Time 0.097 (0.110)	Data Load Time 0.002 (0.009)	Loss 0.5131 (0.5028)
# Epoch: [95][225/275]	Batch Time 0.087 (0.108)	Data Load Time 0.002 (0.008)	Loss 0.5250 (0.5030)
# Epoch: [95][250/275]	Batch Time 0.107 (0.107)	Data Load Time 0.003 (0.008)	Loss 0.5890 (0.5034)
#
#
# Epoch: [96][0/275]	Batch Time 2.313 (2.313)	Data Load Time 2.162 (2.162)	Loss 0.4803 (0.4803)
# Epoch: [96][25/275]	Batch Time 0.133 (0.207)	Data Load Time 0.003 (0.086)	Loss 0.5674 (0.5013)
# Epoch: [96][50/275]	Batch Time 0.108 (0.165)	Data Load Time 0.002 (0.045)	Loss 0.5001 (0.5002)
# Epoch: [96][75/275]	Batch Time 0.105 (0.150)	Data Load Time 0.003 (0.031)	Loss 0.4791 (0.5022)
# Epoch: [96][100/275]	Batch Time 0.111 (0.143)	Data Load Time 0.002 (0.024)	Loss 0.4278 (0.5012)
# Epoch: [96][125/275]	Batch Time 0.100 (0.138)	Data Load Time 0.002 (0.020)	Loss 0.4896 (0.5014)
# Epoch: [96][150/275]	Batch Time 0.099 (0.134)	Data Load Time 0.002 (0.017)	Loss 0.5561 (0.5026)
# Epoch: [96][175/275]	Batch Time 0.112 (0.131)	Data Load Time 0.003 (0.015)	Loss 0.5059 (0.5022)
# Epoch: [96][200/275]	Batch Time 0.090 (0.128)	Data Load Time 0.002 (0.014)	Loss 0.5508 (0.5021)
# Epoch: [96][225/275]	Batch Time 0.090 (0.125)	Data Load Time 0.003 (0.012)	Loss 0.4943 (0.5025)
# Epoch: [96][250/275]	Batch Time 0.132 (0.124)	Data Load Time 0.002 (0.011)	Loss 0.5196 (0.5035)
#
#
# Epoch: [97][0/275]	Batch Time 1.754 (1.754)	Data Load Time 1.660 (1.660)	Loss 0.4700 (0.4700)
# Epoch: [97][25/275]	Batch Time 0.145 (0.181)	Data Load Time 0.003 (0.067)	Loss 0.5278 (0.5092)
# Epoch: [97][50/275]	Batch Time 0.121 (0.149)	Data Load Time 0.002 (0.035)	Loss 0.4669 (0.5059)
# Epoch: [97][75/275]	Batch Time 0.110 (0.137)	Data Load Time 0.003 (0.025)	Loss 0.4646 (0.5039)
# Epoch: [97][100/275]	Batch Time 0.131 (0.131)	Data Load Time 0.002 (0.019)	Loss 0.5163 (0.5031)
# Epoch: [97][125/275]	Batch Time 0.102 (0.127)	Data Load Time 0.002 (0.016)	Loss 0.5584 (0.5031)
# Epoch: [97][150/275]	Batch Time 0.109 (0.125)	Data Load Time 0.002 (0.014)	Loss 0.4782 (0.5022)
# Epoch: [97][175/275]	Batch Time 0.128 (0.124)	Data Load Time 0.003 (0.012)	Loss 0.5048 (0.5021)
# Epoch: [97][200/275]	Batch Time 0.136 (0.124)	Data Load Time 0.003 (0.011)	Loss 0.4743 (0.5018)
# Epoch: [97][225/275]	Batch Time 0.120 (0.123)	Data Load Time 0.003 (0.010)	Loss 0.4740 (0.5030)
# Epoch: [97][250/275]	Batch Time 0.125 (0.123)	Data Load Time 0.002 (0.009)	Loss 0.4591 (0.5034)
#
#
# Epoch: [98][0/275]	Batch Time 1.569 (1.569)	Data Load Time 1.478 (1.478)	Loss 0.4852 (0.4852)
# Epoch: [98][25/275]	Batch Time 0.117 (0.170)	Data Load Time 0.002 (0.059)	Loss 0.5249 (0.4999)
# Epoch: [98][50/275]	Batch Time 0.101 (0.145)	Data Load Time 0.003 (0.032)	Loss 0.4556 (0.5060)
# Epoch: [98][75/275]	Batch Time 0.130 (0.138)	Data Load Time 0.003 (0.022)	Loss 0.5020 (0.5091)
# Epoch: [98][100/275]	Batch Time 0.107 (0.134)	Data Load Time 0.003 (0.018)	Loss 0.5309 (0.5078)
# Epoch: [98][125/275]	Batch Time 0.153 (0.133)	Data Load Time 0.003 (0.015)	Loss 0.5231 (0.5052)
# Epoch: [98][150/275]	Batch Time 0.142 (0.133)	Data Load Time 0.004 (0.013)	Loss 0.5194 (0.5039)
# Epoch: [98][175/275]	Batch Time 0.123 (0.131)	Data Load Time 0.003 (0.011)	Loss 0.4984 (0.5028)
# Epoch: [98][200/275]	Batch Time 0.114 (0.128)	Data Load Time 0.003 (0.010)	Loss 0.4813 (0.5025)
# Epoch: [98][225/275]	Batch Time 0.118 (0.127)	Data Load Time 0.003 (0.010)	Loss 0.4950 (0.5026)
# Epoch: [98][250/275]	Batch Time 0.138 (0.126)	Data Load Time 0.003 (0.009)	Loss 0.5226 (0.5021)
#
#
# Epoch: [99][0/275]	Batch Time 1.884 (1.884)	Data Load Time 1.754 (1.754)	Loss 0.5483 (0.5483)
# Epoch: [99][25/275]	Batch Time 0.126 (0.194)	Data Load Time 0.003 (0.070)	Loss 0.4937 (0.5033)
# Epoch: [99][50/275]	Batch Time 0.138 (0.161)	Data Load Time 0.003 (0.038)	Loss 0.5110 (0.4996)
# Epoch: [99][75/275]	Batch Time 0.132 (0.148)	Data Load Time 0.003 (0.026)	Loss 0.5367 (0.5029)
# Epoch: [99][100/275]	Batch Time 0.128 (0.140)	Data Load Time 0.004 (0.020)	Loss 0.5326 (0.5029)
# Epoch: [99][125/275]	Batch Time 0.120 (0.136)	Data Load Time 0.003 (0.017)	Loss 0.5171 (0.5036)
# Epoch: [99][150/275]	Batch Time 0.110 (0.134)	Data Load Time 0.004 (0.015)	Loss 0.5199 (0.5021)
# Epoch: [99][175/275]	Batch Time 0.111 (0.133)	Data Load Time 0.004 (0.013)	Loss 0.5435 (0.5021)
# Epoch: [99][200/275]	Batch Time 0.124 (0.132)	Data Load Time 0.004 (0.012)	Loss 0.4881 (0.5028)
# Epoch: [99][225/275]	Batch Time 0.104 (0.132)	Data Load Time 0.002 (0.011)	Loss 0.4783 (0.5033)
# Epoch: [99][250/275]	Batch Time 0.122 (0.130)	Data Load Time 0.003 (0.010)	Loss 0.4530 (0.5017)

# %%
def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

def fix_padding(scores_numpy, label_probs,  mask_numpy):
    #if len(scores_numpy) != len(mask_numpy):
    #    print("Error: len(scores_numpy) != len(mask_numpy)")
    #assert len(scores_numpy) == len(mask_numpy)
    #if len(label_probs) != len(mask_numpy):
    #    print("len(label_probs) != len(mask_numpy)")
    #assert len(label_probs) == len(mask_numpy)

    all_scores_no_padd = []
    all_labels_no_pad = []
    for i in range(len(mask_numpy)):
        all_scores_no_padd.append(scores_numpy[i][:mask_numpy[i]])
        all_labels_no_pad.append(label_probs[i][:mask_numpy[i]])

    assert len(all_scores_no_padd) == len(all_labels_no_pad)
    return all_scores_no_padd, all_labels_no_pad

def match_M(batch_scores_no_padd, batch_labels_no_pad):

    top_m = [1, 2, 3, 4]
    batch_num_m=[]
    batch_score_m=[]
    for m in top_m:
        intersects_lst = []
        # exact_lst = []
        score_lst = []
        ############################################### computing scores:
        for s in batch_scores_no_padd:
            if len(s) <=m:
                continue
            h = m
            # if len(s) > h:
            #     while (s[np.argsort(s)[-h]] == s[np.argsort(s)[-(h + 1)]] and h < (len(s) - 1)):
            #         h += 1

            s = np.asarray(s.cpu())
            #ind_score = np.argsort(s)[-h:]
            ind_score = sorted(range(len(s)), key = lambda sub: s[sub])[-h:]
            score_lst.append(ind_score)

        ############################################### computing labels:
        label_lst = []
        for l in batch_labels_no_pad:
            if len(l) <=m:
                continue
            # if it contains several top values with the same amount
            h = m
            l = l.cpu()
            if len(l) > h:
                while (l[np.argsort(l)[-h]] == l[np.argsort(l)[-(h + 1)]] and h < (len(l) - 1)):
                    h += 1
            l = np.asarray(l)
            ind_label = np.argsort(l)[-h:]
            label_lst.append(ind_label)

        ############################################### :

        for i in range(len(score_lst)):
            intersect = intersection(score_lst[i], label_lst[i])
            intersects_lst.append((len(intersect))/(min(m, len(score_lst[i]))))
            # sorted_score_lst = sorted(score_lst[i])
            # sorted_label_lst =  sorted(label_lst[i])
            # if sorted_score_lst==sorted_label_lst:
            #     exact_lst.append(1)
            # else:
            #     exact_lst.append(0)
        batch_num_m.append(len(score_lst))
        batch_score_m.append(sum(intersects_lst))
    return batch_num_m, batch_score_m


#Validation
num_m = [0, 0, 0, 0]
score_m = [0, 0, 0, 0]
with torch.no_grad():
    for i, (wmaps, cmaps_f, cmaps_b, cmarkers_f, cmarkers_b, tmaps, wmap_lengths, cmap_lengths, probs) in enumerate(val_loader):


            max_word_len = max(wmap_lengths.tolist())

            # Reduce batch's padded length to maximum in-batch sequence
            # This saves some compute on nn.Linear layers (RNNs are unaffected, since they don't compute over the pads)
            wmaps = wmaps[:, :max_word_len].to(device)
            probs = probs[:, :max_word_len].to(device)
            wmap_lengths = wmap_lengths.to(device)


            # Forward prop.
            scores, wmaps_sorted, probs_sorted, wmap_lengths_sorted, _ = model(wmaps, probs, wmap_lengths)
            lm_lengths = wmap_lengths_sorted - 1
            lm_lengths = lm_lengths.tolist()
            batch_scores_no_padd, batch_labels_no_pad = fix_padding(scores, probs_sorted, lm_lengths)
            #print(type(batch_scores_no_padd))
            batch_num_m, batch_score_m = match_M(batch_scores_no_padd, batch_labels_no_pad)
            num_m = [sum(i) for i in zip(num_m, batch_num_m)]
            score_m = [sum(i) for i in zip(score_m, batch_score_m)]
            
    m_score = [i/j for i,j in zip(score_m, num_m)]
    print(m_score)
# Out:
# [0.4642857142857143, 0.6724137931034483, 0.7481060606060607, 0.7878787878787878]
