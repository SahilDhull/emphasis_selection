# %% [markdown]
# <a href="https://colab.research.google.com/github/SahilDhull/emphasis_selection/blob/master/model/BiLSTM_and_Attention_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install config

# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
# Requirement already satisfied: config in /usr/local/lib/python3.6/dist-packages (0.4.2)

# %%
from google.colab import drive
drive.mount('/content/drive')

train_file = 'drive/My Drive/datasets/train.txt'
dev_file = 'drive/My Drive/datasets/dev.txt'
emb_file = 'drive/My Drive/datasets/glove.6B.100d.txt'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from collections import Counter
import codecs
import itertools
from functools import reduce
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init
from torch.nn.utils.rnn import pack_padded_sequence
import torch.utils.data as data_utils
import time
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from config import *
#from torchsummary import summary

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def read_words_tags(file, word_ind, tag_ind, prob_ind, caseless=True):
    
    with codecs.open(file, 'r', 'utf-8') as f:
        lines = f.readlines()
    #print(lines)
    words = []
    tags = []
    probs = []
    temp_w = []
    temp_t = []
    temp_p = []
    
    for line in lines:
        if not (line.isspace()):
            feats = line.strip().split()
            temp_w.append(feats[word_ind].lower() if caseless else feats[word_ind])
            temp_t.append(feats[tag_ind])
            temp_p.append((float)(feats[prob_ind]))
        elif len(temp_w) > 0:
            assert len(temp_w) == len(temp_t)
            words.append(temp_w)
            tags.append(temp_t)
            probs.append(temp_p)
            temp_w = []
            temp_t = []
            temp_p = []
            
    if len(temp_w) > 0:
        assert len(temp_w) == len(temp_t)
        words.append(temp_w)
        tags.append(temp_t)
        probs.append(temp_p)
            
    assert len(words) == len(tags) == len(probs)
    #print(probs)
    
    return words, tags, probs

# %%
# train_file = "datasets/train.txt"
# dev_file = "datasets/dev.txt"

word_index = 1
tag_index = 5
prob_index = 4

caseless=True

t_words , t_tags , t_probs = read_words_tags(train_file,word_index,tag_index,prob_index,caseless)
d_words , d_tags , d_probs = read_words_tags(dev_file,word_index,tag_index,prob_index,caseless)

# %%
def create_maps(words, tags, min_word_freq=5, min_char_freq=1):
    
    word_freq = Counter()
    char_freq = Counter()
    tag_map = set()
    for w, t in zip(words, tags):
        word_freq.update(w)
        char_freq.update(list(reduce(lambda x, y: list(x) + [' '] + list(y), w)))
        tag_map.update(t)
    #print(word_freq)
    
    word_map = {k: v + 1 for v, k in enumerate([w for w in word_freq.keys() if word_freq[w] > min_word_freq])}
    char_map = {k: v + 1 for v, k in enumerate([c for c in char_freq.keys() if char_freq[c] > min_char_freq])}
    tag_map = {k: v + 1 for v, k in enumerate(tag_map)}

    word_map['<pad>'] = 0
    word_map['<end>'] = len(word_map)
    word_map['<unk>'] = len(word_map)
    char_map['<pad>'] = 0
    char_map['<end>'] = len(char_map)
    char_map['<unk>'] = len(char_map)
    tag_map['<pad>'] = 0
    tag_map['<start>'] = len(tag_map)
    tag_map['<end>'] = len(tag_map)
    #print(word_map)
    
    return word_map, char_map, tag_map

# %%
min_word_freq=1
min_char_freq=1

word_map, char_map, tag_map = create_maps(t_words+d_words,t_tags+d_tags,min_word_freq, min_char_freq)

# %%
def create_input_tensors(words, tags, probs, word_map, char_map, tag_map):
   
    # Encode sentences into word maps with <end> at the end
    # [['dunston', 'checks', 'in', '<end>']] -> [[4670, 4670, 185, 4669]]
    wmaps = list(map(lambda s: list(map(lambda w: word_map.get(w, word_map['<unk>']), s)) + [word_map['<end>']], words))

    # Forward and backward character streams
    # [['d', 'u', 'n', 's', 't', 'o', 'n', ' ', 'c', 'h', 'e', 'c', 'k', 's', ' ', 'i', 'n', ' ']]
    chars_f = list(map(lambda s: list(reduce(lambda x, y: list(x) + [' '] + list(y), s)) + [' '], words))
    # [['n', 'i', ' ', 's', 'k', 'c', 'e', 'h', 'c', ' ', 'n', 'o', 't', 's', 'n', 'u', 'd', ' ']]
    chars_b = list(
        map(lambda s: list(reversed([' '] + list(reduce(lambda x, y: list(x) + [' '] + list(y), s)))), words))

    # Encode streams into forward and backward character maps with <end> at the end
    # [[29, 2, 12, 8, 7, 14, 12, 3, 6, 18, 1, 6, 21, 8, 3, 17, 12, 3, 60]]
    cmaps_f = list(
        map(lambda s: list(map(lambda c: char_map.get(c, char_map['<unk>']), s)) + [char_map['<end>']], chars_f))
    # [[12, 17, 3, 8, 21, 6, 1, 18, 6, 3, 12, 14, 7, 8, 12, 2, 29, 3, 60]]
    cmaps_b = list(
        map(lambda s: list(map(lambda c: char_map.get(c, char_map['<unk>']), s)) + [char_map['<end>']], chars_b))

    # Positions of spaces and <end> character
    # Words are predicted or encoded at these places in the language and tagging models respectively
    # [[7, 14, 17, 18]] are points after '...dunston', '...checks', '...in', '...<end>' respectively
    cmarkers_f = list(map(lambda s: [ind for ind in range(len(s)) if s[ind] == char_map[' ']] + [len(s) - 1], cmaps_f))
    # Reverse the markers for the backward stream before adding <end>, so the words of the f and b markers coincide
    # i.e., [[17, 9, 2, 18]] are points after '...notsnud', '...skcehc', '...ni', '...<end>' respectively
    cmarkers_b = list(
        map(lambda s: list(reversed([ind for ind in range(len(s)) if s[ind] == char_map[' ']])) + [len(s) - 1],
            cmaps_b))

    # Encode tags into tag maps with <end> at the end
    tmaps = list(map(lambda s: list(map(lambda t: tag_map[t], s)) + [tag_map['<end>']], tags))
    
    # Since we're using CRF scores of size (prev_tags, cur_tags), find indices of target sequence in the unrolled scores
    # This will be row_index (i.e. prev_tag) * n_columns (i.e. tagset_size) + column_index (i.e. cur_tag)
    #tmaps = list(map(lambda s: [tag_map['<start>'] * len(tag_map) + s[0]] + [s[i - 1] * len(tag_map) + s[i] for i in range(1, len(s))], tmaps))
    # Note - the actual tag indices can be recovered with tmaps % len(tag_map)

    # Pad, because need fixed length to be passed around by DataLoaders and other layers
    word_pad_len = max(list(map(lambda s: len(s), wmaps)))
    char_pad_len = max(list(map(lambda s: len(s), cmaps_f)))

    # Sanity check
    assert word_pad_len == max(list(map(lambda s: len(s), tmaps)))

    padded_wmaps = []
    padded_cmaps_f = []
    padded_cmaps_b = []
    padded_cmarkers_f = []
    padded_cmarkers_b = []
    padded_tmaps = []
    wmap_lengths = []
    cmap_lengths = []
    padded_probs = []

    for w, cf, cb, cmf, cmb, t,p in zip(wmaps, cmaps_f, cmaps_b, cmarkers_f, cmarkers_b, tmaps,probs):
        # Sanity  checks
        assert len(w) == len(cmf) == len(cmb) == len(t)
        assert len(cmaps_f) == len(cmaps_b)

        # Pad
        # A note -  it doesn't really matter what we pad with, as long as it's a valid index
        # i.e., we'll extract output at those pad points (to extract equal lengths), but never use them

        padded_wmaps.append(w + [word_map['<pad>']] * (word_pad_len - len(w)))
        padded_cmaps_f.append(cf + [char_map['<pad>']] * (char_pad_len - len(cf)))
        padded_cmaps_b.append(cb + [char_map['<pad>']] * (char_pad_len - len(cb)))

        # 0 is always a valid index to pad markers with (-1 is too but torch.gather has some issues with it)
        padded_cmarkers_f.append(cmf + [0] * (word_pad_len - len(w)))
        padded_cmarkers_b.append(cmb + [0] * (word_pad_len - len(w)))

        padded_tmaps.append(t + [tag_map['<pad>']] * (word_pad_len - len(t)))
        padded_probs.append(p + [0] * (word_pad_len - len(p)))

        wmap_lengths.append(len(w))
        cmap_lengths.append(len(cf))

        # Sanity check
        assert len(padded_wmaps[-1]) == len(padded_tmaps[-1]) == len(padded_cmarkers_f[-1]) == len(
            padded_cmarkers_b[-1]) == word_pad_len == len(padded_probs[-1])
        assert len(padded_cmaps_f[-1]) == len(padded_cmaps_b[-1]) == char_pad_len

    padded_wmaps = torch.LongTensor(padded_wmaps)
    padded_cmaps_f = torch.LongTensor(padded_cmaps_f)
    padded_cmaps_b = torch.LongTensor(padded_cmaps_b)
    padded_cmarkers_f = torch.LongTensor(padded_cmarkers_f)
    padded_cmarkers_b = torch.LongTensor(padded_cmarkers_b)
    padded_tmaps = torch.LongTensor(padded_tmaps)
    wmap_lengths = torch.LongTensor(wmap_lengths)
    cmap_lengths = torch.LongTensor(cmap_lengths)
    padded_probs = torch.FloatTensor(padded_probs)
    
    return padded_wmaps, padded_cmaps_f, padded_cmaps_b, padded_cmarkers_f, padded_cmarkers_b, padded_tmaps, wmap_lengths, cmap_lengths , padded_probs

# %%
batch_size = 10
workers = 1

padded_wmaps, padded_cmaps_f, padded_cmaps_b, padded_cmarkers_f, padded_cmarkers_b, padded_tmaps, wmap_lengths, cmap_lengths , padded_probs = create_input_tensors(t_words, t_tags,t_probs, word_map, char_map, tag_map)
#print(wmap_lengths)
t_inputs = data_utils.TensorDataset(padded_wmaps, padded_cmaps_f, padded_cmaps_b, padded_cmarkers_f, padded_cmarkers_b, padded_tmaps, wmap_lengths, cmap_lengths , padded_probs)
train_loader = torch.utils.data.DataLoader(t_inputs, batch_size = batch_size, shuffle=True, num_workers=workers, pin_memory=False)

padded_wmaps, padded_cmaps_f, padded_cmaps_b, padded_cmarkers_f, padded_cmarkers_b, padded_tmaps, wmap_lengths, cmap_lengths , padded_probs = create_input_tensors(d_words, d_tags,d_probs, word_map, char_map, tag_map)
d_inputs = data_utils.TensorDataset(padded_wmaps, padded_cmaps_f, padded_cmaps_b, padded_cmarkers_f, padded_cmarkers_b, padded_tmaps, wmap_lengths, cmap_lengths , padded_probs)
val_loader = torch.utils.data.DataLoader(d_inputs, batch_size = batch_size, shuffle=True, num_workers=workers, pin_memory=False)

# %%
def init_embedding(input_embedding):
    """
    Initialize embedding tensor with values from the uniform distribution.
    :param input_embedding: embedding tensor
    :return:
    """
    bias = np.sqrt(3.0 / input_embedding.size(1))
    nn.init.uniform_(input_embedding, -bias, bias)

def load_embeddings(emb_file, word_map, expand_vocab=True):
    """
    Load pre-trained embeddings for words in the word map.
    :param emb_file: file with pre-trained embeddings (in the GloVe format)
    :param word_map: word map
    :param expand_vocab: expand vocabulary of word map to vocabulary of pre-trained embeddings?
    :return: embeddings for words in word map, (possibly expanded) word map,
            number of words in word map that are in-corpus (subject to word frequency threshold)
    """
    with open(emb_file, 'r') as f:
        emb_len = len(f.readline().split(' ')) - 1

    print("Embedding length is %d." % emb_len)

    # Create tensor to hold embeddings for words that are in-corpus
    ic_embs = torch.FloatTensor(len(word_map), emb_len)
    init_embedding(ic_embs)

    if expand_vocab:
        print("You have elected to include embeddings that are out-of-corpus.")
        ooc_words = []
        ooc_embs = []
    else:
        print("You have elected NOT to include embeddings that are out-of-corpus.")

    # Read embedding file
    print("\nLoading embeddings...")
    for line in open(emb_file, 'r',encoding="utf8"):
        line = line.split(' ')
        emb_word = line[0]
        embedding = list(map(lambda t: float(t), filter(lambda n: n and not n.isspace(), line[1:])))

        if not expand_vocab and emb_word not in word_map:
            continue

        # If word is in train_vocab, store at the correct index (as in the word_map)
        if emb_word in word_map:
            ic_embs[word_map[emb_word]] = torch.FloatTensor(embedding)

        # If word is in dev or test vocab, store it and its embedding into lists
        elif expand_vocab:
            ooc_words.append(emb_word)
            ooc_embs.append(embedding)

    lm_vocab_size = len(word_map)  # keep track of lang. model's output vocab size (no out-of-corpus words)

    if expand_vocab:
        print("'word_map' is being updated accordingly.")
        for word in ooc_words:
            word_map[word] = len(word_map)
        ooc_embs = torch.FloatTensor(np.asarray(ooc_embs))
        embeddings = torch.cat([ic_embs, ooc_embs], 0)

    else:
        embeddings = ic_embs

    # Sanity check
    assert embeddings.size(0) == len(word_map)

    print("\nDone.\n Embedding vocabulary: %d\n Language Model vocabulary: %d.\n" % (len(word_map), lm_vocab_size))

    return embeddings, word_map, lm_vocab_size

# %%
# emb_file = glove_100

word_emb_dim = 100
expand_vocab = False

embeddings, word_map, lm_vocab_size = load_embeddings(emb_file, word_map,expand_vocab)
# Out:
# Embedding length is 100.
# You have elected NOT to include embeddings that are out-of-corpus.
#
# Loading embeddings...
#
# Done.
#  Embedding vocabulary: 2009
#  Language Model vocabulary: 2009.

# %%
class Attention(nn.Module):
    """Attention mechanism written by Gustavo Aguilar https://github.com/gaguilar"""
    def __init__(self,  hidden_size):
        super(Attention, self).__init__()
        self.da = hidden_size
        self.dh = hidden_size

        self.W = nn.Linear(self.dh, self.da)        # (feat_dim, attn_dim)
        self.v = nn.Linear(self.da, 1)              # (attn_dim, 1)

    def forward(self, inputs, mask):
        # Raw scores
        u = self.v(torch.tanh(self.W(inputs)))      # (batch, seq, hidden) -> (batch, seq, attn) -> (batch, seq, 1)

        # Masked softmax
        u = u.exp().to(device)                                 # exp to calculate softmax
        u = mask.unsqueeze(2).float().to(device) * u           # (batch, seq, 1) * (batch, seq, 1) to zerout out-of-mask numbers
        sums = torch.sum(u, dim=1, keepdim=True)    # now we are sure only in-mask values are in sum
        a = u / sums                                # the probability distribution only goes to in-mask values now

        # Weighted vectors
        z = inputs * a

        return  z,  a.view(inputs.size(0), inputs.size(1))


class LM_LSTM_Attention(nn.Module):

    def __init__(self, target_size, hidden_size, vocab_size, word_emb_dim, word_rnn_dim, dropout):
        
        super(LM_LSTM_Attention, self).__init__()

        self.target_size = target_size  # this is the size of the output vocab of the tagging model
        self.hidden_size = hidden_size

        self.wordset_size = lm_vocab_size  # this is the size of the input vocab (embedding layer) of the tagging model
        self.word_emb_dim = word_emb_dim
        self.word_rnn_dim = word_rnn_dim
        self.word_rnn_layers = 2

        self.dropout = nn.Dropout(p=dropout)

        self.word_embeds = nn.Embedding(self.wordset_size, self.word_emb_dim)  # word embedding layer
        self.word_blstm = nn.LSTM(self.word_emb_dim, self.word_rnn_dim, num_layers=self.word_rnn_layers, bidirectional=True, dropout=dropout)  # word BLSTM
        
        self.attention = Attention(self.word_rnn_dim*2)
        
        self.fc1 = nn.Linear(self.word_rnn_dim*2, self.hidden_size)  
        self.fc2 = nn.Linear(self.hidden_size, self.target_size)
        
    def init_word_embeddings(self, embeddings):
        """
        Initialize embeddings with pre-trained embeddings.
        :param embeddings: pre-trained embeddings
        """
        self.word_embeds.weight = nn.Parameter(embeddings)

    def fine_tune_word_embeddings(self, fine_tune=False):
        """
        Fine-tune embedding layer? (Not fine-tuning only makes sense if using pre-trained embeddings).
        :param fine_tune: Fine-tune?
        """
        for p in self.word_embeds.parameters():
            p.requires_grad = fine_tune

    def forward(self, wmaps, probs, wmap_lengths):
        
        self.batch_size = wmaps.size(0)
        self.word_pad_len = wmaps.size(1)

        # Sort by decreasing true word sequence length
        wmap_lengths, word_sort_ind = wmap_lengths.sort(dim=0, descending=True)
        wmaps = wmaps[word_sort_ind]
        probs = probs[word_sort_ind]
        
        # Embedding look-up for words
        w = self.word_embeds(wmaps)  # (batch_size, word_pad_len, word_emb_dim)
        w = self.dropout(w)

        # Pack padded sequence
        w = pack_padded_sequence(w, list(wmap_lengths), batch_first=True)  # packed sequence of word_emb_dim + 2 * char_rnn_dim, with real sequence lengths
        
        # LSTM
        w, _ = self.word_blstm(w)  # packed sequence of word_rnn_dim, with real sequence lengths

        # Unpack packed sequence
        w, _ = pad_packed_sequence(w, batch_first=True)  # (batch_size, max_word_len_in_batch, word_rnn_dim)
        w = self.dropout(w)
        
        mask = []
        for i in range(len(wmap_lengths)):
            mask_row = (np.concatenate([np.ones(wmap_lengths[i]),np.zeros(len(wmaps[i])-wmap_lengths[i])])).tolist()
            mask.append(mask_row)
        #Attention
        att_output, att_weights = self.attention(w, torch.from_numpy(np.asarray(mask)).float())
        
        # fc layers
        w = torch.relu(self.fc1(att_output)) 
        w = self.dropout(w)
        
        # final score
        scores = torch.sigmoid(self.fc2(w)) 
                
        return scores, wmaps, probs, wmap_lengths, word_sort_ind

# %%
word_rnn_dim = 512
dropout = 0.3
fine_tune_word_embeddings = False
fc1_output_dim = 20
    
model = LM_LSTM_Attention(1, fc1_output_dim, lm_vocab_size, word_emb_dim, word_rnn_dim, dropout).to(device)    # can change the hidden dim
print(model)
        
model.init_word_embeddings(embeddings.to(device))  # initialize embedding layer with pre-trained embeddings
model.fine_tune_word_embeddings(fine_tune_word_embeddings)  # fine-tune
optimizer = optim.Adam(params=filter(lambda p: p.requires_grad, model.parameters()), lr=0.0001)

loss_fn = nn.BCELoss().to(device)      # Cross Entropy Loss
# loss_fn = nn.KLDivLoss().to(device)      # KL
# Out:
# LM_LSTM_Attention(
#   (dropout): Dropout(p=0.3, inplace=False)
#   (word_embeds): Embedding(2009, 100)
#   (word_blstm): LSTM(100, 512, num_layers=2, dropout=0.3, bidirectional=True)
#   (attention): Attention(
#     (W): Linear(in_features=1024, out_features=1024, bias=True)
#     (v): Linear(in_features=1024, out_features=1, bias=True)
#   )
#   (fc1): Linear(in_features=1024, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
class AverageMeter(object):
    """
    Keeps track of most recent, average, sum, and count of a metric.
    """

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
def train(train_loader, model, loss_fn, optimizer, epoch, print_freq = 25):
    
    model.train()  # training mode enables dropout

    batch_time = AverageMeter()  # forward prop. + back prop. time per batch
    data_time = AverageMeter()  # data loading time per batch
    losses = AverageMeter()  # cross entropy loss
    f1s = AverageMeter()  # f1 score

    start = time.time()

    # Batches
    for i, (wmaps, cmaps_f, cmaps_b, cmarkers_f, cmarkers_b, tmaps, wmap_lengths, cmap_lengths, probs) in enumerate(train_loader):
        
        data_time.update(time.time() - start)
        max_word_len = max(wmap_lengths.tolist())

        # Reduce batch's padded length to maximum in-batch sequence
        # This saves some compute on nn.Linear layers (RNNs are unaffected, since they don't compute over the pads)
        wmaps = wmaps[:, :max_word_len].to(device)
        probs = probs[:, :max_word_len].to(device)
        wmap_lengths = wmap_lengths.to(device)
        
        
        # Forward prop.
        scores, wmaps_sorted, probs_sorted, wmap_lengths_sorted, _ = model(wmaps, probs, wmap_lengths)
               
        # We don't predict the next word at the pads or <end> tokens
        # We will only predict at [dunston, checks, in] among [dunston, checks, in, <end>, <pad>, <pad>, ...]
        # So, prediction lengths are word sequence lengths - 1
        lm_lengths = wmap_lengths_sorted - 1
        lm_lengths = lm_lengths.tolist()
        
        # loss
        probs_sorted.resize_(scores.size())  
        
        scores = pack_padded_sequence(scores, lm_lengths, batch_first=True).data
        targets = pack_padded_sequence(probs_sorted, lm_lengths, batch_first=True).data
        loss = loss_fn(scores,targets)

        # Back prop.
        optimizer.zero_grad()
        loss.backward()

#         grad_clip = True
#         if grad_clip is not None:
#             clip_gradient(optimizer, grad_clip)

        optimizer.step()

        # Keep track of metrics
        losses.update(loss.item(), sum(lm_lengths))
        batch_time.update(time.time() - start)

        start = time.time()

        # Print training status
        if i % print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Batch Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Data Load Time {data_time.val:.3f} ({data_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'.format(epoch, i, len(train_loader),
                                                          batch_time=batch_time,
                                                          data_time=data_time, loss=losses))

# %%
def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

def fix_padding(scores_numpy, label_probs,  mask_numpy):
    #if len(scores_numpy) != len(mask_numpy):
    #    print("Error: len(scores_numpy) != len(mask_numpy)")
    #assert len(scores_numpy) == len(mask_numpy)
    #if len(label_probs) != len(mask_numpy):
    #    print("len(label_probs) != len(mask_numpy)")
    #assert len(label_probs) == len(mask_numpy)

    all_scores_no_padd = []
    all_labels_no_pad = []
    for i in range(len(mask_numpy)):
        all_scores_no_padd.append(scores_numpy[i][:mask_numpy[i]])
        all_labels_no_pad.append(label_probs[i][:mask_numpy[i]])

    assert len(all_scores_no_padd) == len(all_labels_no_pad)
    return all_scores_no_padd, all_labels_no_pad

def match_M(batch_scores_no_padd, batch_labels_no_pad):

    top_m = [1, 2, 3, 4]
    batch_num_m=[]
    batch_score_m=[]
    for m in top_m:
        intersects_lst = []
        # exact_lst = []
        score_lst = []
        ############################################### computing scores:
        for s in batch_scores_no_padd:
            if len(s) <=m:
                continue
            h = m
            # if len(s) > h:
            #     while (s[np.argsort(s)[-h]] == s[np.argsort(s)[-(h + 1)]] and h < (len(s) - 1)):
            #         h += 1

            s = np.asarray(s.cpu())
            #ind_score = np.argsort(s)[-h:]
            ind_score = sorted(range(len(s)), key = lambda sub: s[sub])[-h:]
            score_lst.append(ind_score)

        ############################################### computing labels:
        label_lst = []
        for l in batch_labels_no_pad:
            if len(l) <=m:
                continue
            # if it contains several top values with the same amount
            h = m
            l = l.cpu()
            if len(l) > h:
                while (l[np.argsort(l)[-h]] == l[np.argsort(l)[-(h + 1)]] and h < (len(l) - 1)):
                    h += 1
            l = np.asarray(l)
            ind_label = np.argsort(l)[-h:]
            label_lst.append(ind_label)

        ############################################### :

        for i in range(len(score_lst)):
            intersect = intersection(score_lst[i], label_lst[i])
            intersects_lst.append((len(intersect))/(min(m, len(score_lst[i]))))
            # sorted_score_lst = sorted(score_lst[i])
            # sorted_label_lst =  sorted(label_lst[i])
            # if sorted_score_lst==sorted_label_lst:
            #     exact_lst.append(1)
            # else:
            #     exact_lst.append(0)
        batch_num_m.append(len(score_lst))
        batch_score_m.append(sum(intersects_lst))
    return batch_num_m, batch_score_m

# %%
epochs = 50
max_avg = 0
max_score = [0,0,0,0]

for epoch in range(0, epochs):

        # One epoch's training
        train(train_loader, model, loss_fn, optimizer, epoch)
#         print("\n")

        #Validation
        num_m = [0, 0, 0, 0]
        score_m = [0, 0, 0, 0]
        with torch.no_grad():
            for i, (wmaps, cmaps_f, cmaps_b, cmarkers_f, cmarkers_b, tmaps, wmap_lengths, cmap_lengths, probs) in enumerate(val_loader):


                    max_word_len = max(wmap_lengths.tolist())

                    # Reduce batch's padded length to maximum in-batch sequence
                    # This saves some compute on nn.Linear layers (RNNs are unaffected, since they don't compute over the pads)
                    wmaps = wmaps[:, :max_word_len].to(device)
                    probs = probs[:, :max_word_len].to(device)
                    wmap_lengths = wmap_lengths.to(device)


                    # Forward prop.
                    scores, wmaps_sorted, probs_sorted, wmap_lengths_sorted, _ = model(wmaps, probs, wmap_lengths)
                    lm_lengths = wmap_lengths_sorted - 1
                    lm_lengths = lm_lengths.tolist()
                    batch_scores_no_padd, batch_labels_no_pad = fix_padding(scores, probs_sorted, lm_lengths)
                    #print(type(batch_scores_no_padd))
                    batch_num_m, batch_score_m = match_M(batch_scores_no_padd, batch_labels_no_pad)
                    num_m = [sum(i) for i in zip(num_m, batch_num_m)]
                    score_m = [sum(i) for i in zip(score_m, batch_score_m)]

            m_score = [i/j for i,j in zip(score_m, num_m)]
            avg = 0
            for mm in m_score:
              avg = avg+mm
            if(avg>=max_avg):
              max_score = m_score.copy()
              max_avg = avg
            print("Validation Accuracy: ")
            print(m_score)
            print("\n")
# Out:
# Epoch: [0][0/275]	Batch Time 0.082 (0.082)	Data Load Time 0.054 (0.054)	Loss 0.4639 (0.4639)
# Epoch: [0][25/275]	Batch Time 0.025 (0.028)	Data Load Time 0.003 (0.005)	Loss 0.4586 (0.4618)
# Epoch: [0][50/275]	Batch Time 0.024 (0.025)	Data Load Time 0.003 (0.004)	Loss 0.4275 (0.4605)
# Epoch: [0][75/275]	Batch Time 0.023 (0.025)	Data Load Time 0.004 (0.004)	Loss 0.4776 (0.4594)
# Epoch: [0][100/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4429 (0.4558)
# Epoch: [0][125/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3624 (0.4526)
# Epoch: [0][150/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4630 (0.4490)
# Epoch: [0][175/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3944 (0.4475)
# Epoch: [0][200/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4506 (0.4479)
# Epoch: [0][225/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4429 (0.4473)
# Epoch: [0][250/275]	Batch Time 0.030 (0.024)	Data Load Time 0.011 (0.004)	Loss 0.4620 (0.4470)
# Validation Accuracy:
# [0.4923469387755102, 0.6790450928381963, 0.7395833333333335, 0.775]
#
#
# Epoch: [1][0/275]	Batch Time 0.069 (0.069)	Data Load Time 0.045 (0.045)	Loss 0.4112 (0.4112)
# Epoch: [1][25/275]	Batch Time 0.023 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4602 (0.4413)
# Epoch: [1][50/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4053 (0.4400)
# Epoch: [1][75/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3901 (0.4419)
# Epoch: [1][100/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4731 (0.4462)
# Epoch: [1][125/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3768 (0.4457)
# Epoch: [1][150/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4739 (0.4459)
# Epoch: [1][175/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3988 (0.4457)
# Epoch: [1][200/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4111 (0.4448)
# Epoch: [1][225/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.5121 (0.4447)
# Epoch: [1][250/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4648 (0.4457)
# Validation Accuracy:
# [0.5331632653061225, 0.6843501326259946, 0.752840909090909, 0.7734848484848484]
#
#
# Epoch: [2][0/275]	Batch Time 0.069 (0.069)	Data Load Time 0.045 (0.045)	Loss 0.4243 (0.4243)
# Epoch: [2][25/275]	Batch Time 0.022 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4534 (0.4323)
# Epoch: [2][50/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4079 (0.4320)
# Epoch: [2][75/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4310 (0.4398)
# Epoch: [2][100/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4445 (0.4401)
# Epoch: [2][125/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4370 (0.4408)
# Epoch: [2][150/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4858 (0.4436)
# Epoch: [2][175/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4526 (0.4452)
# Epoch: [2][200/275]	Batch Time 0.027 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4549 (0.4451)
# Epoch: [2][225/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4333 (0.4451)
# Epoch: [2][250/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4002 (0.4456)
# Validation Accuracy:
# [0.4923469387755102, 0.6856763925729443, 0.738636363636364, 0.7689393939393939]
#
#
# Epoch: [3][0/275]	Batch Time 0.070 (0.070)	Data Load Time 0.045 (0.045)	Loss 0.4841 (0.4841)
# Epoch: [3][25/275]	Batch Time 0.020 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.3942 (0.4406)
# Epoch: [3][50/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4792 (0.4471)
# Epoch: [3][75/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4509 (0.4479)
# Epoch: [3][100/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4571 (0.4469)
# Epoch: [3][125/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4360 (0.4463)
# Epoch: [3][150/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4756 (0.4466)
# Epoch: [3][175/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3683 (0.4445)
# Epoch: [3][200/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4438 (0.4446)
# Epoch: [3][225/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4101 (0.4451)
# Epoch: [3][250/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4214 (0.4452)
# Validation Accuracy:
# [0.5076530612244898, 0.6604774535809018, 0.747159090909091, 0.7613636363636364]
#
#
# Epoch: [4][0/275]	Batch Time 0.070 (0.070)	Data Load Time 0.048 (0.048)	Loss 0.5504 (0.5504)
# Epoch: [4][25/275]	Batch Time 0.022 (0.026)	Data Load Time 0.003 (0.005)	Loss 0.4748 (0.4354)
# Epoch: [4][50/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.5012 (0.4398)
# Epoch: [4][75/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4904 (0.4445)
# Epoch: [4][100/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4090 (0.4455)
# Epoch: [4][125/275]	Batch Time 0.020 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4732 (0.4452)
# Epoch: [4][150/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3927 (0.4450)
# Epoch: [4][175/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4376 (0.4435)
# Epoch: [4][200/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4802 (0.4435)
# Epoch: [4][225/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4581 (0.4435)
# Epoch: [4][250/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4026 (0.4443)
# Validation Accuracy:
# [0.5280612244897959, 0.6671087533156499, 0.7301136363636364, 0.7621212121212121]
#
#
# Epoch: [5][0/275]	Batch Time 0.078 (0.078)	Data Load Time 0.052 (0.052)	Loss 0.4157 (0.4157)
# Epoch: [5][25/275]	Batch Time 0.022 (0.026)	Data Load Time 0.003 (0.005)	Loss 0.4715 (0.4371)
# Epoch: [5][50/275]	Batch Time 0.025 (0.025)	Data Load Time 0.006 (0.004)	Loss 0.4474 (0.4421)
# Epoch: [5][75/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4382 (0.4408)
# Epoch: [5][100/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4829 (0.4444)
# Epoch: [5][125/275]	Batch Time 0.019 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4864 (0.4462)
# Epoch: [5][150/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4173 (0.4466)
# Epoch: [5][175/275]	Batch Time 0.020 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.5146 (0.4465)
# Epoch: [5][200/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4405 (0.4465)
# Epoch: [5][225/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4545 (0.4452)
# Epoch: [5][250/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4103 (0.4440)
# Validation Accuracy:
# [0.48214285714285715, 0.6724137931034483, 0.7462121212121214, 0.7636363636363637]
#
#
# Epoch: [6][0/275]	Batch Time 0.079 (0.079)	Data Load Time 0.053 (0.053)	Loss 0.4562 (0.4562)
# Epoch: [6][25/275]	Batch Time 0.022 (0.026)	Data Load Time 0.003 (0.006)	Loss 0.4316 (0.4415)
# Epoch: [6][50/275]	Batch Time 0.024 (0.025)	Data Load Time 0.004 (0.005)	Loss 0.3841 (0.4434)
# Epoch: [6][75/275]	Batch Time 0.024 (0.025)	Data Load Time 0.003 (0.004)	Loss 0.3963 (0.4427)
# Epoch: [6][100/275]	Batch Time 0.020 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4594 (0.4459)
# Epoch: [6][125/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4330 (0.4481)
# Epoch: [6][150/275]	Batch Time 0.021 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4549 (0.4470)
# Epoch: [6][175/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4303 (0.4465)
# Epoch: [6][200/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4840 (0.4465)
# Epoch: [6][225/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4007 (0.4452)
# Epoch: [6][250/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4646 (0.4445)
# Validation Accuracy:
# [0.4897959183673469, 0.6790450928381963, 0.7301136363636366, 0.7659090909090909]
#
#
# Epoch: [7][0/275]	Batch Time 0.066 (0.066)	Data Load Time 0.045 (0.045)	Loss 0.4452 (0.4452)
# Epoch: [7][25/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4764 (0.4497)
# Epoch: [7][50/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3610 (0.4501)
# Epoch: [7][75/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4319 (0.4500)
# Epoch: [7][100/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4159 (0.4463)
# Epoch: [7][125/275]	Batch Time 0.020 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4934 (0.4453)
# Epoch: [7][150/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4384 (0.4439)
# Epoch: [7][175/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4108 (0.4436)
# Epoch: [7][200/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4619 (0.4441)
# Epoch: [7][225/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4855 (0.4437)
# Epoch: [7][250/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3823 (0.4434)
# Validation Accuracy:
# [0.548469387755102, 0.6737400530503979, 0.7452651515151516, 0.775]
#
#
# Epoch: [8][0/275]	Batch Time 0.069 (0.069)	Data Load Time 0.046 (0.046)	Loss 0.4716 (0.4716)
# Epoch: [8][25/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4587 (0.4441)
# Epoch: [8][50/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4477 (0.4406)
# Epoch: [8][75/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4501 (0.4442)
# Epoch: [8][100/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4336 (0.4470)
# Epoch: [8][125/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.5159 (0.4471)
# Epoch: [8][150/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4682 (0.4445)
# Epoch: [8][175/275]	Batch Time 0.026 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3825 (0.4436)
# Epoch: [8][200/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4445 (0.4436)
# Epoch: [8][225/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.5012 (0.4433)
# Epoch: [8][250/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4361 (0.4440)
# Validation Accuracy:
# [0.4897959183673469, 0.6870026525198939, 0.7414772727272727, 0.775]
#
#
# Epoch: [9][0/275]	Batch Time 0.069 (0.069)	Data Load Time 0.046 (0.046)	Loss 0.5034 (0.5034)
# Epoch: [9][25/275]	Batch Time 0.024 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4324 (0.4499)
# Epoch: [9][50/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.5344 (0.4483)
# Epoch: [9][75/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4035 (0.4452)
# Epoch: [9][100/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4361 (0.4435)
# Epoch: [9][125/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4231 (0.4427)
# Epoch: [9][150/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4511 (0.4427)
# Epoch: [9][175/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3961 (0.4410)
# Epoch: [9][200/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.5153 (0.4413)
# Epoch: [9][225/275]	Batch Time 0.020 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4596 (0.4419)
# Epoch: [9][250/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4418 (0.4423)
# Validation Accuracy:
# [0.4897959183673469, 0.6551724137931034, 0.7357954545454547, 0.775]
#
#
# Epoch: [10][0/275]	Batch Time 0.070 (0.070)	Data Load Time 0.046 (0.046)	Loss 0.4174 (0.4174)
# Epoch: [10][25/275]	Batch Time 0.022 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4569 (0.4442)
# Epoch: [10][50/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4606 (0.4469)
# Epoch: [10][75/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3971 (0.4435)
# Epoch: [10][100/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4216 (0.4408)
# Epoch: [10][125/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.003)	Loss 0.4496 (0.4412)
# Epoch: [10][150/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.003)	Loss 0.4588 (0.4428)
# Epoch: [10][175/275]	Batch Time 0.026 (0.023)	Data Load Time 0.004 (0.003)	Loss 0.4196 (0.4428)
# Epoch: [10][200/275]	Batch Time 0.030 (0.023)	Data Load Time 0.008 (0.003)	Loss 0.4451 (0.4409)
# Epoch: [10][225/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4126 (0.4426)
# Epoch: [10][250/275]	Batch Time 0.020 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4716 (0.4420)
# Validation Accuracy:
# [0.4846938775510204, 0.6525198938992043, 0.7452651515151516, 0.7689393939393939]
#
#
# Epoch: [11][0/275]	Batch Time 0.071 (0.071)	Data Load Time 0.047 (0.047)	Loss 0.4413 (0.4413)
# Epoch: [11][25/275]	Batch Time 0.022 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.3860 (0.4394)
# Epoch: [11][50/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4698 (0.4361)
# Epoch: [11][75/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4245 (0.4374)
# Epoch: [11][100/275]	Batch Time 0.027 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4430 (0.4399)
# Epoch: [11][125/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4648 (0.4394)
# Epoch: [11][150/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4977 (0.4404)
# Epoch: [11][175/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4512 (0.4394)
# Epoch: [11][200/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4570 (0.4401)
# Epoch: [11][225/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4617 (0.4413)
# Epoch: [11][250/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4712 (0.4408)
# Validation Accuracy:
# [0.5076530612244898, 0.6631299734748011, 0.7395833333333336, 0.7575757575757576]
#
#
# Epoch: [12][0/275]	Batch Time 0.076 (0.076)	Data Load Time 0.052 (0.052)	Loss 0.4978 (0.4978)
# Epoch: [12][25/275]	Batch Time 0.024 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4032 (0.4407)
# Epoch: [12][50/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4541 (0.4433)
# Epoch: [12][75/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4121 (0.4405)
# Epoch: [12][100/275]	Batch Time 0.020 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4110 (0.4419)
# Epoch: [12][125/275]	Batch Time 0.020 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4697 (0.4432)
# Epoch: [12][150/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.5434 (0.4423)
# Epoch: [12][175/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4746 (0.4425)
# Epoch: [12][200/275]	Batch Time 0.024 (0.024)	Data Load Time 0.005 (0.004)	Loss 0.5005 (0.4415)
# Epoch: [12][225/275]	Batch Time 0.024 (0.024)	Data Load Time 0.005 (0.004)	Loss 0.4921 (0.4411)
# Epoch: [12][250/275]	Batch Time 0.024 (0.024)	Data Load Time 0.005 (0.004)	Loss 0.4465 (0.4418)
# Validation Accuracy:
# [0.4770408163265306, 0.6830238726790451, 0.7537878787878788, 0.7780303030303031]
#
#
# Epoch: [13][0/275]	Batch Time 0.078 (0.078)	Data Load Time 0.053 (0.053)	Loss 0.4713 (0.4713)
# Epoch: [13][25/275]	Batch Time 0.024 (0.026)	Data Load Time 0.004 (0.006)	Loss 0.5074 (0.4370)
# Epoch: [13][50/275]	Batch Time 0.023 (0.025)	Data Load Time 0.003 (0.004)	Loss 0.4900 (0.4405)
# Epoch: [13][75/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4855 (0.4432)
# Epoch: [13][100/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4405 (0.4453)
# Epoch: [13][125/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3935 (0.4426)
# Epoch: [13][150/275]	Batch Time 0.028 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3831 (0.4422)
# Epoch: [13][175/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4501 (0.4398)
# Epoch: [13][200/275]	Batch Time 0.026 (0.024)	Data Load Time 0.006 (0.004)	Loss 0.4160 (0.4400)
# Epoch: [13][225/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4247 (0.4414)
# Epoch: [13][250/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4892 (0.4416)
# Validation Accuracy:
# [0.5153061224489796, 0.6710875331564987, 0.7452651515151513, 0.7772727272727272]
#
#
# Epoch: [14][0/275]	Batch Time 0.067 (0.067)	Data Load Time 0.044 (0.044)	Loss 0.4680 (0.4680)
# Epoch: [14][25/275]	Batch Time 0.022 (0.027)	Data Load Time 0.003 (0.005)	Loss 0.4255 (0.4378)
# Epoch: [14][50/275]	Batch Time 0.028 (0.025)	Data Load Time 0.004 (0.004)	Loss 0.4245 (0.4357)
# Epoch: [14][75/275]	Batch Time 0.027 (0.025)	Data Load Time 0.005 (0.004)	Loss 0.5145 (0.4388)
# Epoch: [14][100/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4716 (0.4394)
# Epoch: [14][125/275]	Batch Time 0.026 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4567 (0.4388)
# Epoch: [14][150/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4058 (0.4406)
# Epoch: [14][175/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4704 (0.4406)
# Epoch: [14][200/275]	Batch Time 0.026 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4273 (0.4410)
# Epoch: [14][225/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4586 (0.4414)
# Epoch: [14][250/275]	Batch Time 0.020 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.5129 (0.4410)
# Validation Accuracy:
# [0.5127551020408163, 0.6604774535809018, 0.7376893939393941, 0.7734848484848484]
#
#
# Epoch: [15][0/275]	Batch Time 0.067 (0.067)	Data Load Time 0.043 (0.043)	Loss 0.4883 (0.4883)
# Epoch: [15][25/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.3801 (0.4348)
# Epoch: [15][50/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4462 (0.4439)
# Epoch: [15][75/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3919 (0.4421)
# Epoch: [15][100/275]	Batch Time 0.025 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4205 (0.4408)
# Epoch: [15][125/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4518 (0.4408)
# Epoch: [15][150/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.003)	Loss 0.4328 (0.4392)
# Epoch: [15][175/275]	Batch Time 0.029 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4081 (0.4395)
# Epoch: [15][200/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4546 (0.4397)
# Epoch: [15][225/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.003)	Loss 0.4726 (0.4394)
# Epoch: [15][250/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4572 (0.4411)
# Validation Accuracy:
# [0.4923469387755102, 0.669761273209549, 0.7291666666666667, 0.781060606060606]
#
#
# Epoch: [16][0/275]	Batch Time 0.067 (0.067)	Data Load Time 0.048 (0.048)	Loss 0.4849 (0.4849)
# Epoch: [16][25/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4396 (0.4474)
# Epoch: [16][50/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3735 (0.4407)
# Epoch: [16][75/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4521 (0.4390)
# Epoch: [16][100/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4808 (0.4433)
# Epoch: [16][125/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4979 (0.4424)
# Epoch: [16][150/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.5042 (0.4430)
# Epoch: [16][175/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4557 (0.4427)
# Epoch: [16][200/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4252 (0.4407)
# Epoch: [16][225/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4787 (0.4409)
# Epoch: [16][250/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4870 (0.4406)
# Validation Accuracy:
# [0.4923469387755102, 0.6644562334217506, 0.7291666666666665, 0.7598484848484849]
#
#
# Epoch: [17][0/275]	Batch Time 0.068 (0.068)	Data Load Time 0.047 (0.047)	Loss 0.4682 (0.4682)
# Epoch: [17][25/275]	Batch Time 0.025 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4452 (0.4451)
# Epoch: [17][50/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4385 (0.4407)
# Epoch: [17][75/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4306 (0.4428)
# Epoch: [17][100/275]	Batch Time 0.021 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4274 (0.4434)
# Epoch: [17][125/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4479 (0.4422)
# Epoch: [17][150/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4265 (0.4431)
# Epoch: [17][175/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4714 (0.4427)
# Epoch: [17][200/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4124 (0.4427)
# Epoch: [17][225/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4268 (0.4408)
# Epoch: [17][250/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4427 (0.4404)
# Validation Accuracy:
# [0.5, 0.6671087533156499, 0.7329545454545454, 0.7765151515151515]
#
#
# Epoch: [18][0/275]	Batch Time 0.069 (0.069)	Data Load Time 0.046 (0.046)	Loss 0.4246 (0.4246)
# Epoch: [18][25/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4627 (0.4433)
# Epoch: [18][50/275]	Batch Time 0.026 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4605 (0.4386)
# Epoch: [18][75/275]	Batch Time 0.020 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.5123 (0.4382)
# Epoch: [18][100/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3889 (0.4410)
# Epoch: [18][125/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4551 (0.4387)
# Epoch: [18][150/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4966 (0.4400)
# Epoch: [18][175/275]	Batch Time 0.024 (0.023)	Data Load Time 0.005 (0.004)	Loss 0.5032 (0.4416)
# Epoch: [18][200/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3637 (0.4401)
# Epoch: [18][225/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4604 (0.4409)
# Epoch: [18][250/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4538 (0.4400)
# Validation Accuracy:
# [0.49489795918367346, 0.6644562334217506, 0.7339015151515151, 0.7712121212121212]
#
#
# Epoch: [19][0/275]	Batch Time 0.068 (0.068)	Data Load Time 0.045 (0.045)	Loss 0.4394 (0.4394)
# Epoch: [19][25/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4536 (0.4460)
# Epoch: [19][50/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4680 (0.4385)
# Epoch: [19][75/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4316 (0.4366)
# Epoch: [19][100/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4234 (0.4372)
# Epoch: [19][125/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4349 (0.4365)
# Epoch: [19][150/275]	Batch Time 0.020 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4356 (0.4366)
# Epoch: [19][175/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4258 (0.4366)
# Epoch: [19][200/275]	Batch Time 0.019 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.5325 (0.4386)
# Epoch: [19][225/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4321 (0.4397)
# Epoch: [19][250/275]	Batch Time 0.025 (0.023)	Data Load Time 0.005 (0.004)	Loss 0.4402 (0.4387)
# Validation Accuracy:
# [0.4744897959183674, 0.6750663129973474, 0.7481060606060607, 0.7734848484848484]
#
#
# Epoch: [20][0/275]	Batch Time 0.068 (0.068)	Data Load Time 0.047 (0.047)	Loss 0.4157 (0.4157)
# Epoch: [20][25/275]	Batch Time 0.019 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4496 (0.4321)
# Epoch: [20][50/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4206 (0.4381)
# Epoch: [20][75/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4956 (0.4412)
# Epoch: [20][100/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4369 (0.4389)
# Epoch: [20][125/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4689 (0.4383)
# Epoch: [20][150/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3722 (0.4378)
# Epoch: [20][175/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.5024 (0.4410)
# Epoch: [20][200/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4132 (0.4408)
# Epoch: [20][225/275]	Batch Time 0.020 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.5067 (0.4398)
# Epoch: [20][250/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4876 (0.4399)
# Validation Accuracy:
# [0.5, 0.6724137931034483, 0.7547348484848485, 0.7742424242424243]
#
#
# Epoch: [21][0/275]	Batch Time 0.078 (0.078)	Data Load Time 0.053 (0.053)	Loss 0.3992 (0.3992)
# Epoch: [21][25/275]	Batch Time 0.023 (0.026)	Data Load Time 0.004 (0.006)	Loss 0.3873 (0.4342)
# Epoch: [21][50/275]	Batch Time 0.024 (0.025)	Data Load Time 0.003 (0.004)	Loss 0.4048 (0.4395)
# Epoch: [21][75/275]	Batch Time 0.023 (0.024)	Data Load Time 0.005 (0.004)	Loss 0.4332 (0.4415)
# Epoch: [21][100/275]	Batch Time 0.020 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4754 (0.4400)
# Epoch: [21][125/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4891 (0.4383)
# Epoch: [21][150/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4375 (0.4371)
# Epoch: [21][175/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4417 (0.4382)
# Epoch: [21][200/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4247 (0.4371)
# Epoch: [21][225/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.5138 (0.4380)
# Epoch: [21][250/275]	Batch Time 0.020 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4586 (0.4385)
# Validation Accuracy:
# [0.48214285714285715, 0.6631299734748011, 0.7395833333333333, 0.7681818181818182]
#
#
# Epoch: [22][0/275]	Batch Time 0.066 (0.066)	Data Load Time 0.044 (0.044)	Loss 0.4937 (0.4937)
# Epoch: [22][25/275]	Batch Time 0.023 (0.026)	Data Load Time 0.004 (0.005)	Loss 0.4267 (0.4394)
# Epoch: [22][50/275]	Batch Time 0.023 (0.025)	Data Load Time 0.005 (0.004)	Loss 0.4589 (0.4336)
# Epoch: [22][75/275]	Batch Time 0.024 (0.025)	Data Load Time 0.004 (0.004)	Loss 0.4171 (0.4381)
# Epoch: [22][100/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4191 (0.4376)
# Epoch: [22][125/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4251 (0.4401)
# Epoch: [22][150/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4292 (0.4397)
# Epoch: [22][175/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4070 (0.4392)
# Epoch: [22][200/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4545 (0.4392)
# Epoch: [22][225/275]	Batch Time 0.025 (0.024)	Data Load Time 0.005 (0.004)	Loss 0.4489 (0.4383)
# Epoch: [22][250/275]	Batch Time 0.020 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4283 (0.4393)
# Validation Accuracy:
# [0.5178571428571429, 0.6684350132625995, 0.7424242424242422, 0.7825757575757576]
#
#
# Epoch: [23][0/275]	Batch Time 0.073 (0.073)	Data Load Time 0.050 (0.050)	Loss 0.4340 (0.4340)
# Epoch: [23][25/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4385 (0.4433)
# Epoch: [23][50/275]	Batch Time 0.025 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3942 (0.4388)
# Epoch: [23][75/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3853 (0.4382)
# Epoch: [23][100/275]	Batch Time 0.025 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.3765 (0.4371)
# Epoch: [23][125/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4214 (0.4379)
# Epoch: [23][150/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.003)	Loss 0.4469 (0.4397)
# Epoch: [23][175/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.003)	Loss 0.4324 (0.4388)
# Epoch: [23][200/275]	Batch Time 0.026 (0.023)	Data Load Time 0.005 (0.003)	Loss 0.3976 (0.4372)
# Epoch: [23][225/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.003)	Loss 0.4253 (0.4378)
# Epoch: [23][250/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4366 (0.4379)
# Validation Accuracy:
# [0.5229591836734694, 0.6803713527851459, 0.7594696969696972, 0.7757575757575758]
#
#
# Epoch: [24][0/275]	Batch Time 0.072 (0.072)	Data Load Time 0.047 (0.047)	Loss 0.3989 (0.3989)
# Epoch: [24][25/275]	Batch Time 0.022 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.5243 (0.4359)
# Epoch: [24][50/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3785 (0.4362)
# Epoch: [24][75/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4532 (0.4381)
# Epoch: [24][100/275]	Batch Time 0.026 (0.023)	Data Load Time 0.007 (0.004)	Loss 0.4676 (0.4381)
# Epoch: [24][125/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4518 (0.4381)
# Epoch: [24][150/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.5469 (0.4366)
# Epoch: [24][175/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4528 (0.4380)
# Epoch: [24][200/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3830 (0.4374)
# Epoch: [24][225/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4179 (0.4377)
# Epoch: [24][250/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.003)	Loss 0.4454 (0.4372)
# Validation Accuracy:
# [0.5, 0.6618037135278515, 0.737689393939394, 0.7689393939393939]
#
#
# Epoch: [25][0/275]	Batch Time 0.074 (0.074)	Data Load Time 0.048 (0.048)	Loss 0.4016 (0.4016)
# Epoch: [25][25/275]	Batch Time 0.025 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4664 (0.4365)
# Epoch: [25][50/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3704 (0.4402)
# Epoch: [25][75/275]	Batch Time 0.020 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3911 (0.4404)
# Epoch: [25][100/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4894 (0.4410)
# Epoch: [25][125/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4090 (0.4430)
# Epoch: [25][150/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4516 (0.4443)
# Epoch: [25][175/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4317 (0.4408)
# Epoch: [25][200/275]	Batch Time 0.025 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4768 (0.4402)
# Epoch: [25][225/275]	Batch Time 0.020 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4294 (0.4398)
# Epoch: [25][250/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4585 (0.4384)
# Validation Accuracy:
# [0.5076530612244898, 0.669761273209549, 0.7490530303030298, 0.7636363636363637]
#
#
# Epoch: [26][0/275]	Batch Time 0.067 (0.067)	Data Load Time 0.044 (0.044)	Loss 0.4013 (0.4013)
# Epoch: [26][25/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3940 (0.4379)
# Epoch: [26][50/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4027 (0.4344)
# Epoch: [26][75/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4483 (0.4353)
# Epoch: [26][100/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4392 (0.4346)
# Epoch: [26][125/275]	Batch Time 0.020 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3906 (0.4347)
# Epoch: [26][150/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4791 (0.4365)
# Epoch: [26][175/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4390 (0.4366)
# Epoch: [26][200/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4381 (0.4375)
# Epoch: [26][225/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4413 (0.4362)
# Epoch: [26][250/275]	Batch Time 0.026 (0.023)	Data Load Time 0.005 (0.004)	Loss 0.4553 (0.4368)
# Validation Accuracy:
# [0.5025510204081632, 0.6750663129973474, 0.7405303030303029, 0.7757575757575758]
#
#
# Epoch: [27][0/275]	Batch Time 0.069 (0.069)	Data Load Time 0.046 (0.046)	Loss 0.5055 (0.5055)
# Epoch: [27][25/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4175 (0.4393)
# Epoch: [27][50/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3533 (0.4341)
# Epoch: [27][75/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4301 (0.4280)
# Epoch: [27][100/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.5046 (0.4323)
# Epoch: [27][125/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4424 (0.4330)
# Epoch: [27][150/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4874 (0.4340)
# Epoch: [27][175/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4919 (0.4374)
# Epoch: [27][200/275]	Batch Time 0.023 (0.023)	Data Load Time 0.005 (0.003)	Loss 0.4578 (0.4379)
# Epoch: [27][225/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4426 (0.4385)
# Epoch: [27][250/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4041 (0.4367)
# Validation Accuracy:
# [0.4897959183673469, 0.6803713527851459, 0.7414772727272726, 0.7795454545454545]
#
#
# Epoch: [28][0/275]	Batch Time 0.068 (0.068)	Data Load Time 0.044 (0.044)	Loss 0.4264 (0.4264)
# Epoch: [28][25/275]	Batch Time 0.022 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.5002 (0.4335)
# Epoch: [28][50/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4097 (0.4351)
# Epoch: [28][75/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4187 (0.4371)
# Epoch: [28][100/275]	Batch Time 0.020 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4483 (0.4387)
# Epoch: [28][125/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4473 (0.4384)
# Epoch: [28][150/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4405 (0.4408)
# Epoch: [28][175/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3709 (0.4405)
# Epoch: [28][200/275]	Batch Time 0.026 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4103 (0.4403)
# Epoch: [28][225/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4687 (0.4371)
# Epoch: [28][250/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4760 (0.4372)
# Validation Accuracy:
# [0.49744897959183676, 0.6671087533156499, 0.7386363636363638, 0.7757575757575758]
#
#
# Epoch: [29][0/275]	Batch Time 0.069 (0.069)	Data Load Time 0.047 (0.047)	Loss 0.5018 (0.5018)
# Epoch: [29][25/275]	Batch Time 0.022 (0.026)	Data Load Time 0.004 (0.005)	Loss 0.4442 (0.4476)
# Epoch: [29][50/275]	Batch Time 0.024 (0.025)	Data Load Time 0.003 (0.004)	Loss 0.3852 (0.4357)
# Epoch: [29][75/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4550 (0.4397)
# Epoch: [29][100/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4376 (0.4375)
# Epoch: [29][125/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3743 (0.4367)
# Epoch: [29][150/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4439 (0.4375)
# Epoch: [29][175/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3840 (0.4360)
# Epoch: [29][200/275]	Batch Time 0.021 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4261 (0.4365)
# Epoch: [29][225/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4401 (0.4372)
# Epoch: [29][250/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4801 (0.4367)
# Validation Accuracy:
# [0.4846938775510204, 0.6631299734748011, 0.7433712121212122, 0.7712121212121212]
#
#
# Epoch: [30][0/275]	Batch Time 0.069 (0.069)	Data Load Time 0.047 (0.047)	Loss 0.4216 (0.4216)
# Epoch: [30][25/275]	Batch Time 0.022 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.3682 (0.4241)
# Epoch: [30][50/275]	Batch Time 0.022 (0.025)	Data Load Time 0.003 (0.004)	Loss 0.4633 (0.4296)
# Epoch: [30][75/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3879 (0.4324)
# Epoch: [30][100/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4138 (0.4336)
# Epoch: [30][125/275]	Batch Time 0.021 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.5243 (0.4378)
# Epoch: [30][150/275]	Batch Time 0.023 (0.024)	Data Load Time 0.005 (0.004)	Loss 0.4465 (0.4381)
# Epoch: [30][175/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4408 (0.4373)
# Epoch: [30][200/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4098 (0.4371)
# Epoch: [30][225/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4441 (0.4364)
# Epoch: [30][250/275]	Batch Time 0.021 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4446 (0.4365)
# Validation Accuracy:
# [0.49744897959183676, 0.6671087533156499, 0.7443181818181818, 0.7795454545454545]
#
#
# Epoch: [31][0/275]	Batch Time 0.068 (0.068)	Data Load Time 0.045 (0.045)	Loss 0.4688 (0.4688)
# Epoch: [31][25/275]	Batch Time 0.025 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4022 (0.4277)
# Epoch: [31][50/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3782 (0.4318)
# Epoch: [31][75/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3881 (0.4301)
# Epoch: [31][100/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.5517 (0.4323)
# Epoch: [31][125/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4511 (0.4312)
# Epoch: [31][150/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4367 (0.4322)
# Epoch: [31][175/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4578 (0.4336)
# Epoch: [31][200/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4599 (0.4336)
# Epoch: [31][225/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4837 (0.4337)
# Epoch: [31][250/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4080 (0.4355)
# Validation Accuracy:
# [0.49744897959183676, 0.6737400530503979, 0.7386363636363636, 0.771969696969697]
#
#
# Epoch: [32][0/275]	Batch Time 0.080 (0.080)	Data Load Time 0.052 (0.052)	Loss 0.4550 (0.4550)
# Epoch: [32][25/275]	Batch Time 0.021 (0.026)	Data Load Time 0.003 (0.005)	Loss 0.4912 (0.4231)
# Epoch: [32][50/275]	Batch Time 0.026 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4314 (0.4269)
# Epoch: [32][75/275]	Batch Time 0.026 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4451 (0.4331)
# Epoch: [32][100/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4129 (0.4352)
# Epoch: [32][125/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.5089 (0.4352)
# Epoch: [32][150/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4299 (0.4361)
# Epoch: [32][175/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4354 (0.4358)
# Epoch: [32][200/275]	Batch Time 0.021 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4538 (0.4348)
# Epoch: [32][225/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4044 (0.4353)
# Epoch: [32][250/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3870 (0.4356)
# Validation Accuracy:
# [0.5, 0.6763925729442971, 0.7376893939393941, 0.7689393939393939]
#
#
# Epoch: [33][0/275]	Batch Time 0.069 (0.069)	Data Load Time 0.045 (0.045)	Loss 0.4465 (0.4465)
# Epoch: [33][25/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4223 (0.4277)
# Epoch: [33][50/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4103 (0.4325)
# Epoch: [33][75/275]	Batch Time 0.026 (0.023)	Data Load Time 0.006 (0.004)	Loss 0.4268 (0.4349)
# Epoch: [33][100/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4282 (0.4361)
# Epoch: [33][125/275]	Batch Time 0.026 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4702 (0.4350)
# Epoch: [33][150/275]	Batch Time 0.026 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3980 (0.4343)
# Epoch: [33][175/275]	Batch Time 0.026 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4815 (0.4350)
# Epoch: [33][200/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4622 (0.4341)
# Epoch: [33][225/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4935 (0.4340)
# Epoch: [33][250/275]	Batch Time 0.027 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4233 (0.4345)
# Validation Accuracy:
# [0.5102040816326531, 0.6631299734748011, 0.7357954545454544, 0.7681818181818182]
#
#
# Epoch: [34][0/275]	Batch Time 0.068 (0.068)	Data Load Time 0.046 (0.046)	Loss 0.4859 (0.4859)
# Epoch: [34][25/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4482 (0.4271)
# Epoch: [34][50/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.5255 (0.4292)
# Epoch: [34][75/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4702 (0.4269)
# Epoch: [34][100/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4036 (0.4285)
# Epoch: [34][125/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4544 (0.4309)
# Epoch: [34][150/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4135 (0.4337)
# Epoch: [34][175/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4386 (0.4351)
# Epoch: [34][200/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4164 (0.4357)
# Epoch: [34][225/275]	Batch Time 0.025 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4323 (0.4354)
# Epoch: [34][250/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4145 (0.4347)
# Validation Accuracy:
# [0.5127551020408163, 0.6777188328912467, 0.7490530303030304, 0.7757575757575758]
#
#
# Epoch: [35][0/275]	Batch Time 0.073 (0.073)	Data Load Time 0.048 (0.048)	Loss 0.3920 (0.3920)
# Epoch: [35][25/275]	Batch Time 0.026 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.3790 (0.4286)
# Epoch: [35][50/275]	Batch Time 0.023 (0.024)	Data Load Time 0.005 (0.004)	Loss 0.4266 (0.4317)
# Epoch: [35][75/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4073 (0.4314)
# Epoch: [35][100/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4580 (0.4320)
# Epoch: [35][125/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4393 (0.4321)
# Epoch: [35][150/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4710 (0.4319)
# Epoch: [35][175/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3726 (0.4328)
# Epoch: [35][200/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4392 (0.4332)
# Epoch: [35][225/275]	Batch Time 0.020 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4676 (0.4346)
# Epoch: [35][250/275]	Batch Time 0.020 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4742 (0.4353)
# Validation Accuracy:
# [0.5178571428571429, 0.6724137931034483, 0.743371212121212, 0.7795454545454545]
#
#
# Epoch: [36][0/275]	Batch Time 0.073 (0.073)	Data Load Time 0.049 (0.049)	Loss 0.4948 (0.4948)
# Epoch: [36][25/275]	Batch Time 0.023 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4572 (0.4394)
# Epoch: [36][50/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3635 (0.4313)
# Epoch: [36][75/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4054 (0.4322)
# Epoch: [36][100/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.5048 (0.4336)
# Epoch: [36][125/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4156 (0.4347)
# Epoch: [36][150/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4014 (0.4330)
# Epoch: [36][175/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4075 (0.4340)
# Epoch: [36][200/275]	Batch Time 0.027 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4879 (0.4350)
# Epoch: [36][225/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4501 (0.4349)
# Epoch: [36][250/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3824 (0.4363)
# Validation Accuracy:
# [0.49744897959183676, 0.6843501326259946, 0.7386363636363636, 0.7613636363636364]
#
#
# Epoch: [37][0/275]	Batch Time 0.065 (0.065)	Data Load Time 0.044 (0.044)	Loss 0.4543 (0.4543)
# Epoch: [37][25/275]	Batch Time 0.025 (0.026)	Data Load Time 0.004 (0.005)	Loss 0.4019 (0.4324)
# Epoch: [37][50/275]	Batch Time 0.024 (0.025)	Data Load Time 0.003 (0.004)	Loss 0.4343 (0.4313)
# Epoch: [37][75/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4276 (0.4336)
# Epoch: [37][100/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4419 (0.4369)
# Epoch: [37][125/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4515 (0.4366)
# Epoch: [37][150/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3934 (0.4347)
# Epoch: [37][175/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4336 (0.4348)
# Epoch: [37][200/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4472 (0.4340)
# Epoch: [37][225/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4032 (0.4326)
# Epoch: [37][250/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4623 (0.4331)
# Validation Accuracy:
# [0.5076530612244898, 0.6737400530503979, 0.7291666666666671, 0.771969696969697]
#
#
# Epoch: [38][0/275]	Batch Time 0.069 (0.069)	Data Load Time 0.047 (0.047)	Loss 0.5066 (0.5066)
# Epoch: [38][25/275]	Batch Time 0.021 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4572 (0.4309)
# Epoch: [38][50/275]	Batch Time 0.022 (0.025)	Data Load Time 0.003 (0.004)	Loss 0.4518 (0.4336)
# Epoch: [38][75/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4036 (0.4312)
# Epoch: [38][100/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4478 (0.4325)
# Epoch: [38][125/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4511 (0.4340)
# Epoch: [38][150/275]	Batch Time 0.026 (0.024)	Data Load Time 0.005 (0.004)	Loss 0.3940 (0.4358)
# Epoch: [38][175/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4207 (0.4353)
# Epoch: [38][200/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4323 (0.4353)
# Epoch: [38][225/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4695 (0.4349)
# Epoch: [38][250/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4139 (0.4345)
# Validation Accuracy:
# [0.5, 0.6631299734748011, 0.7367424242424243, 0.7696969696969697]
#
#
# Epoch: [39][0/275]	Batch Time 0.070 (0.070)	Data Load Time 0.047 (0.047)	Loss 0.4555 (0.4555)
# Epoch: [39][25/275]	Batch Time 0.021 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4392 (0.4267)
# Epoch: [39][50/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4520 (0.4360)
# Epoch: [39][75/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4329 (0.4418)
# Epoch: [39][100/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4580 (0.4373)
# Epoch: [39][125/275]	Batch Time 0.021 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.5276 (0.4369)
# Epoch: [39][150/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.5126 (0.4340)
# Epoch: [39][175/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4025 (0.4342)
# Epoch: [39][200/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4447 (0.4339)
# Epoch: [39][225/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4914 (0.4330)
# Epoch: [39][250/275]	Batch Time 0.021 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4365 (0.4331)
# Validation Accuracy:
# [0.49489795918367346, 0.6777188328912467, 0.7490530303030304, 0.7787878787878788]
#
#
# Epoch: [40][0/275]	Batch Time 0.067 (0.067)	Data Load Time 0.046 (0.046)	Loss 0.3861 (0.3861)
# Epoch: [40][25/275]	Batch Time 0.021 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.5116 (0.4378)
# Epoch: [40][50/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3908 (0.4330)
# Epoch: [40][75/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4200 (0.4403)
# Epoch: [40][100/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4271 (0.4359)
# Epoch: [40][125/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4168 (0.4347)
# Epoch: [40][150/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4575 (0.4356)
# Epoch: [40][175/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4482 (0.4335)
# Epoch: [40][200/275]	Batch Time 0.026 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4347 (0.4343)
# Epoch: [40][225/275]	Batch Time 0.021 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4223 (0.4338)
# Epoch: [40][250/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4064 (0.4338)
# Validation Accuracy:
# [0.5102040816326531, 0.6618037135278515, 0.7348484848484849, 0.7681818181818182]
#
#
# Epoch: [41][0/275]	Batch Time 0.073 (0.073)	Data Load Time 0.048 (0.048)	Loss 0.4440 (0.4440)
# Epoch: [41][25/275]	Batch Time 0.024 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4382 (0.4380)
# Epoch: [41][50/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4130 (0.4293)
# Epoch: [41][75/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4105 (0.4312)
# Epoch: [41][100/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4352 (0.4315)
# Epoch: [41][125/275]	Batch Time 0.021 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4738 (0.4309)
# Epoch: [41][150/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3899 (0.4336)
# Epoch: [41][175/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4223 (0.4344)
# Epoch: [41][200/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4742 (0.4342)
# Epoch: [41][225/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3577 (0.4331)
# Epoch: [41][250/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4525 (0.4345)
# Validation Accuracy:
# [0.48214285714285715, 0.6710875331564987, 0.7414772727272729, 0.7666666666666667]
#
#
# Epoch: [42][0/275]	Batch Time 0.073 (0.073)	Data Load Time 0.049 (0.049)	Loss 0.4981 (0.4981)
# Epoch: [42][25/275]	Batch Time 0.023 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4751 (0.4471)
# Epoch: [42][50/275]	Batch Time 0.027 (0.024)	Data Load Time 0.005 (0.004)	Loss 0.4368 (0.4441)
# Epoch: [42][75/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4600 (0.4363)
# Epoch: [42][100/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4109 (0.4312)
# Epoch: [42][125/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3673 (0.4344)
# Epoch: [42][150/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3954 (0.4343)
# Epoch: [42][175/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4332 (0.4338)
# Epoch: [42][200/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4457 (0.4337)
# Epoch: [42][225/275]	Batch Time 0.026 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4473 (0.4329)
# Epoch: [42][250/275]	Batch Time 0.020 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4234 (0.4338)
# Validation Accuracy:
# [0.49744897959183676, 0.6644562334217506, 0.7282196969696969, 0.7560606060606061]
#
#
# Epoch: [43][0/275]	Batch Time 0.066 (0.066)	Data Load Time 0.044 (0.044)	Loss 0.4432 (0.4432)
# Epoch: [43][25/275]	Batch Time 0.024 (0.025)	Data Load Time 0.004 (0.005)	Loss 0.4227 (0.4175)
# Epoch: [43][50/275]	Batch Time 0.021 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4817 (0.4301)
# Epoch: [43][75/275]	Batch Time 0.025 (0.024)	Data Load Time 0.005 (0.004)	Loss 0.4471 (0.4291)
# Epoch: [43][100/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4590 (0.4320)
# Epoch: [43][125/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4269 (0.4294)
# Epoch: [43][150/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.5071 (0.4319)
# Epoch: [43][175/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4406 (0.4322)
# Epoch: [43][200/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4872 (0.4321)
# Epoch: [43][225/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3722 (0.4317)
# Epoch: [43][250/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.3391 (0.4319)
# Validation Accuracy:
# [0.5178571428571429, 0.6790450928381963, 0.7537878787878788, 0.7803030303030303]
#
#
# Epoch: [44][0/275]	Batch Time 0.073 (0.073)	Data Load Time 0.046 (0.046)	Loss 0.4278 (0.4278)
# Epoch: [44][25/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4279 (0.4303)
# Epoch: [44][50/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3864 (0.4332)
# Epoch: [44][75/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4343 (0.4366)
# Epoch: [44][100/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4153 (0.4377)
# Epoch: [44][125/275]	Batch Time 0.023 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3867 (0.4357)
# Epoch: [44][150/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4285 (0.4351)
# Epoch: [44][175/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.003)	Loss 0.4125 (0.4347)
# Epoch: [44][200/275]	Batch Time 0.028 (0.023)	Data Load Time 0.005 (0.003)	Loss 0.3617 (0.4345)
# Epoch: [44][225/275]	Batch Time 0.025 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4154 (0.4342)
# Epoch: [44][250/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.003)	Loss 0.4789 (0.4333)
# Validation Accuracy:
# [0.5076530612244898, 0.6551724137931034, 0.7244318181818182, 0.7727272727272727]
#
#
# Epoch: [45][0/275]	Batch Time 0.075 (0.075)	Data Load Time 0.052 (0.052)	Loss 0.4394 (0.4394)
# Epoch: [45][25/275]	Batch Time 0.023 (0.026)	Data Load Time 0.003 (0.005)	Loss 0.4844 (0.4351)
# Epoch: [45][50/275]	Batch Time 0.023 (0.025)	Data Load Time 0.003 (0.004)	Loss 0.4255 (0.4339)
# Epoch: [45][75/275]	Batch Time 0.022 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4489 (0.4319)
# Epoch: [45][100/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4424 (0.4310)
# Epoch: [45][125/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4491 (0.4314)
# Epoch: [45][150/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3898 (0.4304)
# Epoch: [45][175/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4304 (0.4291)
# Epoch: [45][200/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.5654 (0.4313)
# Epoch: [45][225/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4401 (0.4319)
# Epoch: [45][250/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4704 (0.4322)
# Validation Accuracy:
# [0.5, 0.6631299734748011, 0.7376893939393938, 0.7818181818181819]
#
#
# Epoch: [46][0/275]	Batch Time 0.067 (0.067)	Data Load Time 0.044 (0.044)	Loss 0.4101 (0.4101)
# Epoch: [46][25/275]	Batch Time 0.025 (0.025)	Data Load Time 0.004 (0.005)	Loss 0.4374 (0.4355)
# Epoch: [46][50/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.3987 (0.4346)
# Epoch: [46][75/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.5197 (0.4344)
# Epoch: [46][100/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4853 (0.4335)
# Epoch: [46][125/275]	Batch Time 0.028 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4084 (0.4345)
# Epoch: [46][150/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4041 (0.4332)
# Epoch: [46][175/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4187 (0.4335)
# Epoch: [46][200/275]	Batch Time 0.023 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4079 (0.4342)
# Epoch: [46][225/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4099 (0.4341)
# Epoch: [46][250/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3985 (0.4328)
# Validation Accuracy:
# [0.5153061224489796, 0.6551724137931034, 0.7320075757575758, 0.7689393939393939]
#
#
# Epoch: [47][0/275]	Batch Time 0.071 (0.071)	Data Load Time 0.047 (0.047)	Loss 0.4460 (0.4460)
# Epoch: [47][25/275]	Batch Time 0.020 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.4605 (0.4430)
# Epoch: [47][50/275]	Batch Time 0.023 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.3788 (0.4302)
# Epoch: [47][75/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4791 (0.4291)
# Epoch: [47][100/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4505 (0.4297)
# Epoch: [47][125/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4280 (0.4295)
# Epoch: [47][150/275]	Batch Time 0.025 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4279 (0.4304)
# Epoch: [47][175/275]	Batch Time 0.027 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3873 (0.4322)
# Epoch: [47][200/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4249 (0.4318)
# Epoch: [47][225/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4332 (0.4326)
# Epoch: [47][250/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.5117 (0.4321)
# Validation Accuracy:
# [0.5127551020408163, 0.6591511936339522, 0.7414772727272727, 0.7765151515151515]
#
#
# Epoch: [48][0/275]	Batch Time 0.067 (0.067)	Data Load Time 0.045 (0.045)	Loss 0.4504 (0.4504)
# Epoch: [48][25/275]	Batch Time 0.024 (0.024)	Data Load Time 0.003 (0.005)	Loss 0.3656 (0.4173)
# Epoch: [48][50/275]	Batch Time 0.024 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4183 (0.4251)
# Epoch: [48][75/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4955 (0.4286)
# Epoch: [48][100/275]	Batch Time 0.025 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.4446 (0.4292)
# Epoch: [48][125/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4386 (0.4326)
# Epoch: [48][150/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4196 (0.4324)
# Epoch: [48][175/275]	Batch Time 0.021 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4390 (0.4324)
# Epoch: [48][200/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4148 (0.4333)
# Epoch: [48][225/275]	Batch Time 0.025 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4171 (0.4340)
# Epoch: [48][250/275]	Batch Time 0.022 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.3625 (0.4321)
# Validation Accuracy:
# [0.48214285714285715, 0.6591511936339522, 0.7329545454545456, 0.775]
#
#
# Epoch: [49][0/275]	Batch Time 0.068 (0.068)	Data Load Time 0.045 (0.045)	Loss 0.4933 (0.4933)
# Epoch: [49][25/275]	Batch Time 0.024 (0.025)	Data Load Time 0.003 (0.005)	Loss 0.4247 (0.4334)
# Epoch: [49][50/275]	Batch Time 0.022 (0.024)	Data Load Time 0.003 (0.004)	Loss 0.5005 (0.4352)
# Epoch: [49][75/275]	Batch Time 0.026 (0.024)	Data Load Time 0.004 (0.004)	Loss 0.4420 (0.4346)
# Epoch: [49][100/275]	Batch Time 0.020 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4330 (0.4319)
# Epoch: [49][125/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4522 (0.4334)
# Epoch: [49][150/275]	Batch Time 0.021 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4427 (0.4319)
# Epoch: [49][175/275]	Batch Time 0.023 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4834 (0.4316)
# Epoch: [49][200/275]	Batch Time 0.024 (0.023)	Data Load Time 0.003 (0.004)	Loss 0.4072 (0.4320)
# Epoch: [49][225/275]	Batch Time 0.024 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.4529 (0.4318)
# Epoch: [49][250/275]	Batch Time 0.022 (0.023)	Data Load Time 0.004 (0.004)	Loss 0.5085 (0.4317)
# Validation Accuracy:
# [0.49744897959183676, 0.6830238726790451, 0.7585227272727273, 0.7825757575757576]

# %%
print(max_score)
# Out:
# [0.5331632653061225, 0.6843501326259946, 0.752840909090909, 0.7734848484848484]
